# %% [markdown]
# # German Text Summary with the tranlated CNN Daily Mail Dataset
# and T5 from Huggingface Pytorch

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
import torch
import re
import time

# %%
BATCH_SIZE = 4

SHUFFEL_SIZE = 1024

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate = 3e-5

EPOCHS = 5

log_interval = 200

model_size = "t5-base"

# %%
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Define Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained(model_size)
model = T5ForConditionalGeneration.from_pretrained(model_size).to(device)

task_specific_params = model.config.task_specific_params
if task_specific_params is not None:
    model.config.update(task_specific_params.get("summarization", {}))
    

optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.0001)

# %% [markdown]
# ## Read the tranlated German Dataset

# %%
def get_translated_ds(name):
    article_path = "../data/%s/articles_german" % name
    highlights_path = "../data/%s/highlights_german" % name

    articles = [x.rstrip() for x in open(article_path).readlines()]
    highlights = [x.rstrip() for x in open(highlights_path).readlines()]
    
    assert len(articles) == len(highlights)
    return articles, highlights

# %%
train_x, train_y = get_translated_ds("train")
test_x, test_y = get_translated_ds("test")
val_x, val_y = get_translated_ds("val")

# %% [markdown]
# ## Show some Dataset Example

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(train_x))
    print("\n--------")
    print(train_x[rand_int][:1500])
    print()
    print(train_y[rand_int])
# Out:
# --------
# 120617; (CNN) - Ein unerwartetes und plötzliches Rampenlicht auf die Special Olympics, eine Organisation, die seit über 40 Jahren Menschen mit intellektuellen Behinderungen dient und ehrt, kommt weniger als zwei Wochen bevor die gemeinnützige Organisation eine neue Kampagne lanciert: Spread the Word to the End the Word. Special Olympics führt eine Kampagne durch, um die Verwendung des "R-Wortes" zu stoppen. Der 31. März wird zu einem "nationalen Tag des Bewusstseins" erklärt, ein Aufruf an die Amerikaner, ihre Verwendung des Wortes "verzögern" oder, wie die Organisation es vorziehen würde, des "R-Wortes" anzuerkennen und zu überdenken. "Die meisten Menschen betrachten dieses Wort nicht als Hassrede, aber genau so fühlt es sich für Millionen von Menschen mit intellektuellen Behinderungen, ihre Familien und Freunde an", heißt es in einer Erklärung über die Kampagne. "Dieses Wort ist genauso grausam und beleidigend wie jede andere Verunglimpfung". Der Vorstoß für mehr Respekt wird von jungen Menschen angeführt, die unter http: / / www.r-word.org / Versprechen oder Gelübde sammeln, das Wort nicht zu verwenden, und Online-Diskussionen darüber führen, wie sich Menschen für diese Sache engagieren können. Bisher haben sich landesweit bereits 300 Schulen verpflichtet, am 31. März Kundgebungen abzuhalten, sagte Special Olympics-Präsident und CEO J. sagte Brady Lum. Eine aggressive Print- und Online-Kampagne, die sich an Menschen zwischen 18 und 30 richtet, wird folgen, sagte Kirsten Su
#
# 120617; Die Amerikaner werden herausgefordert, ihre Verwendung von "R-Wort" oder "Verzögerung" in Betracht zu ziehen Aufmerksamkeit kommt kurz vor dem Wahlkampf: Verbreiten Sie das Wort, um das Wort zu beenden. Obamas Auftritt in der "Tonight Show" enthielt einen direkten Bezug zu Special Olympics. Der Präsident und CEO von Special Olympics bezeichnet die ganze Aufmerksamkeit als "lehrbaren Moment".
#
# --------
# 63102; Gareth Bale bewahrte Wales mit einem sehenswerten Freistoßtor neun Minuten vor Schluss vor der Schmach des Remis beim Elftal-Fürstentum Andorra und löste eine Raseninvasion der mitgereisten Fans aus. Der Star von Real Madrid traf mit einem fulminanten Schuss ins Netz und schickte die überschwänglichen Anhänger nach dem Sturz über eine Werbebande zum Feiern zurück auf ihre Plätze. Zuvor hatte er mit einem wuchtigen Kopfball einen Strafstoß aus Andorra egalisiert, ihr erstes Pflichtspieltor seit mehr als vier Jahren. Scrollen Sie nach unten für Video. Matchwinner: Gareth Bale zirkelte einen 25-Yard-Freistoß neun Minuten vor Schluss an Andorras Torhüter Ferran Pol vorbei ins Netz. Ausgleich: Bale vereitelte Ildefons Limas Auftakt mit einem Tor in der 22. Minute gegen die europäischen Elfen. Jubel: Bale wird von den walisischen Teamkollegen Simon Church (ganz rechts) und Lewis Nyatanga (links) nach seinem Tor beglückwünscht. Kapitän fantastisch: Andorra-Kapitän Lima verärgerte die Chancenverwertung, indem er nach nur sechs Minuten gegen Chris Colemans Seite traf. Seltener Treffer: Andorra feiert nach Limas erstem Pflichtspieltor für sein Land seit September 2010. Torschützen: Bale und Andorra-Kapitän Lima schafften es beide, in der EM-Qualifikation für ihre jeweiligen Seiten auf dem Spielberichtsbogen zu stehen.Ruhe: Kapitän Ashley Williams war unter den Spielern Die 3G-Oberfläche würde unangenehme Rollen verursachen und schwarze Gummikugeln versprühen, wenn der Ball aufsp
#
# 63102; Real Madrids Star Gareth Bale rettete den Sieg, indem er den späten Siegtreffer gegen die europäischen Elfen Andorra erzielte. Ildefons Lima verblüffte Wales mit seinem Tor vom Elfmeterpunkt schon nach sechs Minuten. Andorra erzielte sein erstes Pflichtspieltor seit September 2010 gegen die Mannschaft von Chris Coleman. Chris Coleman war mit dem Zustand des Platzes im Camp d 'Esports in Katalonien nicht zufrieden. Der walisische Mittelfeldakteur Aaron Ramsey musste aufgrund der Beschaffenheit des Untergrundes verletzt vom Platz.
#
# --------
# 209006; (CNN) -- Selbstmord sollte NIEMALS von den Medien als Mittel dargestellt werden, um seine Probleme zu lösen oder zu entkommen (im Gegensatz zum Twitter-Post der Academy of Motion Picture Arts and Sciences ist der Geist nicht frei, der Schmerz des Geistes ist nun auf ein sehr großes Publikum verteilt). Obwohl ich nicht weiß und niemand weiß, ob Robin Williams "frei" ist, ist er tot, und sein Verlust hat uns alle verwüstet. Selbstmord muss als tödliches Ergebnis diskutiert werden, das in den meisten Fällen vermeidbar ist und durch schwere Krankheiten und / oder extreme psychische Qualen verursacht wird. Als ich am Montag von Williams 'Selbstmord erfuhr, hat es mir den Wind aus den Segeln genommen. Sicher, ich bin Präsident der American Association of Suicidology und daher wachsam gegenüber der Berichterstattung in den Medien über Selbstmord. Ich spreche jeden Tag über Selbstmord, aber wie die meisten von Ihnen ist meine Verbindung zu Williams persönlich. Ich komme aus Boulder, Colorado, und nachdem ich weggezogen war, schaltete ich die Wiederholung von "Mork & Mindy" jedes Mal ein, wenn ich Heimweh hatte oder allein war. Robin Williams 'Darstellung eines verrückten Außerirdischen, der gerade versucht, es in diese Welt zu schaffen, bot Trost, Lachen und wunderbare Erinnerungen. Sein Tod ist auf jeden Fall ein zutiefst trauriges Ereignis. Dass er durch Selbstmord gestorben ist (eine Todesursache, die ich fast jeden Tag zu verhindern versuche), macht seinen Tod für mich nu
#
# 209006; Bill Schmitz: Medien sollten Suizid niemals als Flucht vor Problemen darstellen. Es ist oft vermeidbar ". Oscar-Preisträger Robin Williams twitterte:" Genie, du bist frei ". Falsch. Schmitz: Es ist unbekannt, ob Promi-Suizid Nachahmer verursacht; Erwachsene müssen verantwortungsvoll mit dem Thema umgehen. Schmitz: Williams tragischer Tod eine Möglichkeit, Menschen die Warnsignale des Suizids beizubringen, offener Dialog.
#
# --------
# 54113; Getötet: Der achtjährige Imani Green war auf einem Familienurlaub in Jamaika und wurde erschossen, nachdem ein Angreifer in einem Lebensmittelgeschäft das Feuer eröffnet hatte.Acht Verdächtige wurden gestern Abend im Zusammenhang mit dem Mord an der britischen Schülerin Imani Green in Jamaika intensiv von der Polizei verhört. Die Behörden der Insel zeigten sich zuversichtlich, den Mord an der Achtjährigen aufzuklären, bei der es sich vermutlich um ein unschuldiges Opfer von Gangstern handelt, die einen Revierkrieg um einen illegalen Lotteriebetrug führen. Imani, die an der schwächenden Blutstörung Sichelzellenanämie litt, war für einen längeren Urlaub in der Karibik, um die Symptome ihres Zustandes zu lindern. Die Jugendliche aus Balham im Süden Londons wurde in Kopf und Schulter geschossen, als ein maskierter Bewaffneter in dem von ihrem Cousin betriebenen Geschäft und der Bar am Straßenrand das Feuer eröffnete. Die Polizei teilte mit, die Verdächtigen, allesamt Männer unter 35 Jahren, würden nach Razzien auf Anwesen in der Nähe der Schießerei in Duncans, einer Stadt an der Nordwestküste der Insel, nach Hinweisen aus der Öffentlichkeit "intensiv verhört". Ein Polizeisprecher sagte: "In den letzten 24 Stunden wurden acht Personen in Gewahrsam genommen und wir sind zuversichtlich, dass wir bald einen Durchbruch erzielen werden". Imanis Großmutter Sandra Fisher begrüßte die Festnahmen. Frau Fisher, 54, sagte: "Ich bin zufrieden mit unserer Gemeinschaft, weil sie die Info
#
# 54113; Imani Green, aus London, erschossen am Freitagabend in Duncans, Trelawny Parish. Mädchen im Winterurlaub mit Mutter Donna, 47, und Schwester Jamila, 19. Struck in den Kopf durch eine Kugel aus 9mm-Pistole und traf in der Schulter von Sekunde zu Sekunde. Betrug beinhaltet Tricks. Amerikaner zu denken, sie hätten die Lotterie gewonnen.
#
# --------
# 228759; Durch. Post Foreign Service. VERÖFFENTLICHT:. 02: 34 EST, 10. Oktober 2012. |. UPDATED:. 02: 35 EST, 10. Oktober 2012. Die Spanier sind aufgerufen, angesichts der anhaltenden Wirtschaftskrise des Landes Lebensmittelpakete an ihre verarmten Pendants zu liefern. Spaniens Rotes Kreuz startet heute einen drastischen Appell über 30 Millionen Euro - ein Schritt, der in den letzten Jahren für die Hilfe für die von Hungersnöten heimgesuchten afrikanischen Nationen und das vom Erdbeben verwüstete Haiti reserviert war. Es ist das erste Mal, dass sich die Organisation bei ihrer jährlichen Kampagne ausschließlich auf die Hilfe für die Menschen im eigenen Land konzentriert und in den nächsten zwei Jahren 2,3 Millionen "extrem gefährdete" Bürger mit lebenswichtigen Lebensmitteln versorgen wird. Rezession: Arbeitslose Männer und Frauen stehen Schlange vor einem Jobcenter in Madrid, als das spanische Rote Kreuz seine erste Spendenaktion zur Unterstützung der eigenen Bevölkerung ankündigt. Die Zahl der Bedürftigen ist bereits dramatisch gestiegen - von 1,5 Millionen im Jahr 2010 auf 2 Millionen im Jahr 2011. Familien sind aufgerufen, im Rahmen des jährlichen Dia de la Banderita (Tag der kleinen Flagge) des Roten Kreuzes Geld für die Lebensmittelpakete zu spenden. Nudeln, Reis, Olivenöl, Gemüse und Fischkonserven werden an Kinder unter der Armutsgrenze, Rentner, Obdachlose und Langzeitarbeitslose geliefert. Eine Werbung, die im nationalen Fernsehen ausgestrahlt werden soll, zeigt eine
#
# 228759; Internationale Hilfsorganisation startet Spendenaufruf in Höhe von 30 Millionen Euro. Stifter des diesjährigen Spendentages Dia de la Banderita werden spanische Mitbürger sein.

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(test_x))
    print("\n--------")
    print(test_x[rand_int][:1500])
    print()
    print(test_y[rand_int])
# Out:
# --------
# 1591; Ein ehemaliger TSA-Agent behauptet, dass Tasten jeden Tag an Sicherheitskontrollpunkten in den Vereinigten Staaten passieren und Mitarbeiter routinemäßig die Regeln beugen, um Passagiere in ihre Hände zu bekommen. Jason Edward Harrington, der sechs Jahre lang mit der Regierungsbehörde zusammengearbeitet hat, fügte hinzu, dass Screenshots oft attraktive Reisende zur Seite ziehen, so dass sie sie unangemessen berühren können und Taschenkontrollen bei Menschen durchführen, die ihnen einfach nicht gefallen. Seine Kommentare folgen auf Enthüllungen, wonach zwei TSA-Mitarbeiter gefeuert wurden, weil sie Körperscanner in Denver manipuliert hatten, um Männer vor dem Einsteigen in ihre Flüge zu tätscheln. In einem Beitrag für die Zeitschrift TIME sagte er, der Fall sei verstörend, gab aber zu, dass er nicht überrascht worden sei. Vorwürfe: Jason Edward Harrington, der sechs Jahre lang mit der TSA zusammengearbeitet hat, behauptet, dass Taschen an Sicherheitskontrollen im ganzen Land an der Tagesordnung sind und sagte, dass Mitarbeiter "die Regeln beugen", damit sie Passagiere unangemessen berühren könnten (Aktenbild) "Im Laufe meiner sechs Jahre bei der TSA war der Einsatz von Regeln und Überwachungsinstrumenten zum Missbrauch von Passagieren ein täglicher Kontrollpunkt", sagte er. Und während es leicht ist, die ganze Schuld den beiden unappetitlichen Screenern in die Schuhe zu schieben, die jetzt nicht mehr bei der Behörde sind, ist das vielleicht größere Problem ein systemisch
#
# 1591; Jason Edward Harrington arbeitete sechs Jahre für die Regierungsbehörde. Besagtes Personal zog attraktive Menschen zur Seite, damit sie sie berühren konnten. Führte auch Taschenkontrollen bei Passagieren durch, die ihnen nicht gefielen. Behauptungen nach Enthüllung Agentur feuerte zwei Mitarbeiter in Denver. Das Paar manipulierte Körperscanner, um männliche Passagiere begrapschen konnte.
#
# --------
# 2555; Vijay Chokal-Ingam behauptet, er habe sich 1998 als Schwarzer ausgegeben, als er sich an medizinischen Fakultäten bewarb, weil er glaubte, bessere Chancen auf Akzeptanz zu haben. Nachdem Mindy Kaling <unk> s älterer Bruder über seine Erfahrungen als Schwarzer berichtet hatte, um sich an medizinischen Fakultäten zu bewerben, sagte er, dass seine Schwester seine Handlungen nicht gutheiße. In seinem Blog Almost Black erklärte Vijay Chokal-Ingam, dass niemand aus seiner Familie sein Buch gutheiße, in dem er kontrovers behauptet, erst Ende der 1990er Jahre in die medizinische Fakultät aufgenommen worden zu sein, weil er sich als Schwarzer ausgegeben habe. "Meine Schwester Mindy Kaling (Vera Mindy Chokalingam) vom Mindy Project und Hängt jeder ohne mich ab? missbilligt mein Buch sehr", schrieb er. Sie sagte sogar: "Dieses Buch wird Schande über unsere Familie bringen". Der Rest meiner Familie ist mit dem Buch nicht einverstanden. Trotzdem respektieren sie mein Recht, mit meiner Karriere meine eigenen Entscheidungen zu treffen ", fügte er hinzu. Chokal-Ingam sagt in seinem Blog, er habe das Gefühl gehabt, sein Aussehen ändern zu müssen, um in die St. Louis University School of Medicine aufgenommen zu werden, und attackiert die Affirmative Action-Politik in den Vereinigten Staaten heftig. "Ich war entschlossen, Arzt zu werden, und ich wusste, dass die Zulassungsstandards für bestimmte Minderheiten im Rahmen der Affirmative Action, sagen wir, weniger streng waren". schrieb Choka
#
# 2555; Vijay Chokal-Ingam behauptet, er habe sich als Schwarzer ausgegeben und sei 1998 in die medizinische Fakultät der St. Louis University School of Medicine aufgenommen worden. Er entschied, dass er bessere Chancen hätte, die medizinische Fakultät zu besuchen, wenn er schwarzer als indisch-amerikanischer Mann wäre. Erzählt von seinen Erfahrungen in seinem eigenen Blog Almost Black und kritisiert Affirmative Action. Er behauptet, er habe sich den Kopf rasiert, seine "langen indischen Wimpern" gestutzt und sei der Organisation Schwarzer Studenten beigetreten. Chokal-Ingam sagt, dass seine jüngere Schwester Mindy Kaling "stark missbilligt" und seine Familie "nicht mit dem Buch einverstanden ist".
#
# --------
# 3016; Auf dem Platz hat Chelsea in dieser Saison seine Ziele erreicht... und daneben haben Eden Hazard und drei seiner Teamkollegen der Blues dasselbe getan. Hazard und Nathan Ake lieferten sich bei der Fußball-Herausforderung von Audi ein Kopf-an-Kopf-Rennen mit Loic Remy und Willian. In Runde eins feuern die Chelsea-Stars Bälle aus Nahdistanz in den Kofferraum eines Autos, Hazard und Ake sichern mit einem 5: 3-Sieg die Punkte. Eine der Herausforderungen für die Chelsea-Spieler bestand darin, Bälle aus großer Entfernung in Cabrio-Audi zu versenken. 17-Tore-Mann Eden Hazard und Youngster Nathan Ake traten gegen die Teamkollegen der Blues, Loic Remy und Willian, an. Von dort aus ging es auf einen provisorischen Tennisplatz, wo das Netz durch einen 127.000 Pfund teuren Audi R8 V10 plus ersetzt wird und die Spieler darüber spielen müssen. Wieder sind es 17-Tore-Mann Hazard und sein Partner Ake, die die Trümpfe in der Hand halten und nach den ersten beiden Runden mit 6: 0 in Führung gehen. Im letzten Spiel werden die meisten Punkte gewonnen, da die Spieler aus großer Entfernung schießen, um ihre Fußbälle durch das Dach eines Cabrio-Audi zu versenken. Hazard stellt sich neben einem £127.000 R8 V10 plus Audi, der bei einer Herausforderung die Rolle des Tennisnetzes spielte. Bei der letzten Herausforderung schossen die Spieler aus großer Entfernung auf Autos, wobei Remy und Willian gewannen. Hazard wirft Fußbälle auf seinen Teamkollegen Ake, der versucht, sie in den Kofferraum eines
#
# 3016; Vier Chelsea-Stars nahmen an der Fußball-Challenge von Audi teil, bei der es um verschiedene Herausforderungen im Zusammenhang mit den teuren Autos ging. Eden Hazard und Nathan Ake standen Willian und Loic Remy im Video gegenüber. Willian zertrümmerte versehentlich den Außenspiegel eines Audi. HIER KLICKEN für alle aktuellen Chelsea-News.
#
# --------
# 756; Vor ein paar Jahren verkaufte Gemma Collins Gebrauchtwagen in Romford, aber es scheint, dass ihr eigentliches Talent darin besteht, Kleidung zu entwerfen. Der 34-jährige Star von The Only Way Is Essex hat seine aktualisierte Modelinie für den Plus-Size-Einzelhändler Evans auf den Markt gebracht. Sie stellte die Kollektion heute Abend in einem der Flagship Stores der High-Street-Kette in Manchester vor. Scrollen Sie nach unten für ein Video. Gemma Collins hat heute im Laden der Kette in Manchester mehrere Ergänzungen ihres Evans-Sortiments vorgestellt. Gemma, die ihr beliebtes Sortiment um sieben neue kurvenschmeichelnde Oberteile und Kleider erweitert hat, sah aus wie ein Hauch frischer Frühlingsluft in einer floralen Nummer aus ihrer Kollektion. Der Star kombinierte das geraffte blau-rosa Kleid mit einem Paar schlichter schwarzer Stilettos und einer goldenen Bräune. Im Gespräch mit FEMAIL gestern vor der Markteinführung enthüllte Gemma, dass ein großer Teil ihres Triumphes darin besteht, üppige Frauen zu mehr Selbstbewusstsein zu inspirieren. Sie sagte: "Ich habe einmal einen Spruch gehört:" Ich bin eine Sanduhr, nur mit mehr Sand ", und ich liebe das. Ich glaube, das bringt mich auf den Punkt, da ich Kurven habe und meine Form liebe ". Der Star sah in einer blauen Blumenzahl aus der Kollektion sehr sommerlich aus. Neu hinzugekommen sind farbenfrohe Swingtops und Blusen sowie ein Paar florale Kimonos mit Fransen; alles in den gleichen schmeichelhaften Schnitten, die ihr
#
# 756; Gemma Collins, 34, brachte heute mehrere Ergänzungen ihres Evans-Sortiments auf den Markt. Der Star nickte dem sommerlichen Wetter in einem floralen Kleid zu. Neu in der Kollektion sind ein LBD mit Spitze und eine Reihe floraler Kimonos.
#
# --------
# 7918; Eric Abidal glaubt, dass sein Ex-Klub Barcelona das Potenzial hat, mit dem Gewinn von La Liga, Champions League und Copa del Rey in dieser Saison das berühmte Triple zu holen. Die Mannschaft von Luis Enrique zog an Paris Saint-Germain vorbei und steht in der Champions League im Halbfinale, während sie auch in der La Liga ganz oben steht und im Finale der Copa del Rey auf Athletic Bilbao trifft. Abidal war ein integraler Bestandteil von Pep Guardiolas brillantem Barcelona-Team, das 2009 sechs Trophäen gewann, und er glaubt, dass der Verein auf dem Weg sein könnte, diese Höhen wieder zu erklimmen. Neymar traf doppelt, als Barcelona PSG mit 2: 0 (5: 1 auf agg) besiegte und ins Halbfinale der Champions League einzog. Barcelona gewann 2009 das Triple und der ehemalige Abwehrspieler Eric Abidal (rechts) sagt, die aktuelle Ernte sei auf dem Weg. Abidal, der im vergangenen Jahr in den Ruhestand ging, sprach bei der Vorstellung der Eric-Abidal-Stiftung in Katalonien. "Es ist möglich, eine Verdreifachung zu erreichen, aber im Fußball ist es sehr kompliziert". sagte Abidal. Man kann den Pokal, die Liga und die Champions League gewinnen, aber es dauert nur eine Minute, bis etwas schief geht. Ich würde mir wünschen, dass Barca wieder das Niveau erreicht, das sie hatten, als wir 2009 sechs Titel gewannen, und ich denke, sie sind auf diesem Weg. Mit der Mentalität, die sie haben, hart zu arbeiten und es von einem Tag auf den anderen anzunehmen, können sie diese Ziele erreichen. Barcel
#
# 7918; Barcelona bis ins Champions-League-Halbfinale nach dem Sieg gegen PSG. Eric Abidal sagt, dass die aktuelle Ernte die Klasse der Triumphe von 2009 nachahmen kann. Verteidiger war integraler Bestandteil des Teams, das das Triple unter Pep Guardiola gewann. Abidal bei der Vorstellung der Eric Abidal Foundation in Katalonien. Lionel Messi, Luis Suarez und Neymar sind die besten Barca-Stürmer aller Zeiten.

# %% [markdown]
# ## Define Pytorch Dataset

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, articles, highlights):
        self.x = articles
        self.y = highlights
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index]), max_length=512, return_tensors="pt", pad_to_max_length=True)
        y = tokenizer.encode(self.transfrom(self.y[index]), max_length=150, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1), y.view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
train_ds = MyDataset(train_x, train_y) 
val_ds = MyDataset(val_x, val_y)
test_ds = MyDataset(test_x, test_y)

# %%
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
x, x_mask, y = next(iter(val_loader))
x.shape, x_mask.shape, y.shape
# Out:
# (torch.Size([4, 512]), torch.Size([4, 512]), torch.Size([4, 150]))

# %% [markdown]
# ## Define Step function

# %%
pad_token_id = tokenizer.pad_token_id
def step(inputs_ids, attention_mask, y):
    y_ids = y[:, :-1].contiguous()
    lm_labels = y[:, 1:].clone()
    lm_labels[y[:, 1:] == pad_token_id] = -100
    output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
    return output[0] # loss

# %% [markdown]
# ## Train

# %%
train_loss = []
val_loss = []
for epoch in range(EPOCHS):
    model.train() 
    start_time = time.time()
    for i, (inputs_ids, attention_mask, y) in enumerate(train_loader):
        inputs_ids = inputs_ids.to(device)
        attention_mask = attention_mask.to(device)
        y = y.to(device)
        
        
        optimizer.zero_grad()
        loss = step(inputs_ids, attention_mask, y)
        train_loss.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
            
        if (i + 1) % log_interval == 0:
            with torch.no_grad():
                x, x_mask, y = next(iter(val_loader))
                x = x.to(device)
                x_mask = x_mask.to(device)
                y = y.to(device)
                
                v_loss = step(x, x_mask, y)
                v_loss = v_loss.item()
                
                
                elapsed = time.time() - start_time
                print('| epoch {:3d} | [{:5d}/{:5d}] | '
                  'ms/batch {:5.2f} | '
                  'loss {:5.2f} | val loss {:5.2f}'.format(
                    epoch, i, len(train_loader),
                    elapsed * 1000 / log_interval,
                    loss.item(), v_loss))
                start_time = time.time()
                val_loss.append(v_loss)
# Out:
# | epoch   0 | [  199/71779] | ms/batch 330.42 | loss  2.47 | val loss  2.36
# | epoch   0 | [  399/71779] | ms/batch 335.57 | loss  2.05 | val loss  2.20
# | epoch   0 | [  599/71779] | ms/batch 326.07 | loss  2.22 | val loss  2.13
# | epoch   0 | [  799/71779] | ms/batch 324.17 | loss  2.61 | val loss  2.05
# | epoch   0 | [  999/71779] | ms/batch 325.72 | loss  2.32 | val loss  1.94
# | epoch   0 | [ 1199/71779] | ms/batch 326.15 | loss  2.35 | val loss  1.88
# | epoch   0 | [ 1399/71779] | ms/batch 325.92 | loss  2.38 | val loss  1.92
# | epoch   0 | [ 1599/71779] | ms/batch 321.90 | loss  2.26 | val loss  1.87
# | epoch   0 | [ 1799/71779] | ms/batch 323.25 | loss  2.26 | val loss  1.88
# | epoch   0 | [ 1999/71779] | ms/batch 323.06 | loss  2.46 | val loss  1.89
# | epoch   0 | [ 2199/71779] | ms/batch 324.19 | loss  1.64 | val loss  1.80
# | epoch   0 | [ 2399/71779] | ms/batch 325.02 | loss  2.24 | val loss  1.86
# | epoch   0 | [ 2599/71779] | ms/batch 324.96 | loss  1.74 | val loss  1.77
# | epoch   0 | [ 2799/71779] | ms/batch 323.71 | loss  2.31 | val loss  1.84
# | epoch   0 | [ 2999/71779] | ms/batch 322.88 | loss  1.39 | val loss  1.82
# | epoch   0 | [ 3199/71779] | ms/batch 322.98 | loss  2.30 | val loss  1.83
# | epoch   0 | [ 3399/71779] | ms/batch 326.34 | loss  2.06 | val loss  1.80
# | epoch   0 | [ 3599/71779] | ms/batch 329.51 | loss  2.74 | val loss  1.79
# | epoch   0 | [ 3799/71779] | ms/batch 324.70 | loss  2.19 | val loss  1.83
# | epoch   0 | [ 3999/71779] | ms/batch 324.75 | loss  2.11 | val loss  1.88
# | epoch   0 | [ 4199/71779] | ms/batch 323.30 | loss  2.30 | val loss  1.83
# | epoch   0 | [ 4399/71779] | ms/batch 322.98 | loss  2.42 | val loss  1.81
# | epoch   0 | [ 4599/71779] | ms/batch 322.84 | loss  2.12 | val loss  1.81
# | epoch   0 | [ 4799/71779] | ms/batch 323.01 | loss  1.98 | val loss  1.82
# | epoch   0 | [ 4999/71779] | ms/batch 323.62 | loss  2.35 | val loss  1.76
# | epoch   0 | [ 5199/71779] | ms/batch 322.44 | loss  1.85 | val loss  1.84
# | epoch   0 | [ 5399/71779] | ms/batch 322.97 | loss  1.53 | val loss  1.89
# | epoch   0 | [ 5599/71779] | ms/batch 323.87 | loss  1.99 | val loss  1.74
# | epoch   0 | [ 5799/71779] | ms/batch 325.08 | loss  2.21 | val loss  1.82
# | epoch   0 | [ 5999/71779] | ms/batch 325.69 | loss  1.71 | val loss  1.86
# | epoch   0 | [ 6199/71779] | ms/batch 323.44 | loss  2.09 | val loss  1.86
# | epoch   0 | [ 6399/71779] | ms/batch 323.48 | loss  2.24 | val loss  1.83
# | epoch   0 | [ 6599/71779] | ms/batch 323.16 | loss  2.38 | val loss  1.87
# | epoch   0 | [ 6799/71779] | ms/batch 325.56 | loss  1.78 | val loss  1.86
# | epoch   0 | [ 6999/71779] | ms/batch 323.40 | loss  2.08 | val loss  1.81
# | epoch   0 | [ 7199/71779] | ms/batch 324.03 | loss  1.86 | val loss  1.86
# | epoch   0 | [ 7399/71779] | ms/batch 324.34 | loss  2.10 | val loss  1.92
# | epoch   0 | [ 7599/71779] | ms/batch 323.37 | loss  2.18 | val loss  1.84
# | epoch   0 | [ 7799/71779] | ms/batch 323.95 | loss  2.12 | val loss  1.86
# | epoch   0 | [ 7999/71779] | ms/batch 327.27 | loss  2.84 | val loss  1.87
# | epoch   0 | [ 8199/71779] | ms/batch 325.68 | loss  2.44 | val loss  1.96
# | epoch   0 | [ 8399/71779] | ms/batch 325.80 | loss  2.19 | val loss  1.97
# | epoch   0 | [ 8599/71779] | ms/batch 325.35 | loss  2.07 | val loss  1.94
# | epoch   0 | [ 8799/71779] | ms/batch 324.77 | loss  2.22 | val loss  1.95
# | epoch   0 | [ 8999/71779] | ms/batch 322.55 | loss  2.62 | val loss  1.97
# | epoch   0 | [ 9199/71779] | ms/batch 323.65 | loss  2.16 | val loss  2.02
# | epoch   0 | [ 9399/71779] | ms/batch 324.73 | loss  2.02 | val loss  2.01
# | epoch   0 | [ 9599/71779] | ms/batch 325.34 | loss  2.11 | val loss  1.94
# | epoch   0 | [ 9799/71779] | ms/batch 325.47 | loss  2.60 | val loss  1.97
# | epoch   0 | [ 9999/71779] | ms/batch 324.30 | loss  1.74 | val loss  1.97
# | epoch   0 | [10199/71779] | ms/batch 326.69 | loss  3.18 | val loss  2.03
# | epoch   0 | [10399/71779] | ms/batch 326.98 | loss  2.46 | val loss  2.04
# | epoch   0 | [10599/71779] | ms/batch 326.71 | loss  2.20 | val loss  1.93
# | epoch   0 | [10799/71779] | ms/batch 325.25 | loss  2.41 | val loss  2.09
# | epoch   0 | [10999/71779] | ms/batch 325.15 | loss  2.28 | val loss  1.97
# | epoch   0 | [11199/71779] | ms/batch 324.54 | loss  2.54 | val loss  2.04
# | epoch   0 | [11399/71779] | ms/batch 326.02 | loss  2.80 | val loss  2.06
# | epoch   0 | [11599/71779] | ms/batch 327.21 | loss  2.34 | val loss  2.00
# | epoch   0 | [11799/71779] | ms/batch 323.47 | loss  2.27 | val loss  2.03
# | epoch   0 | [11999/71779] | ms/batch 324.57 | loss  1.98 | val loss  2.08
# | epoch   0 | [12199/71779] | ms/batch 327.30 | loss  2.68 | val loss  2.11
# | epoch   0 | [12399/71779] | ms/batch 325.41 | loss  2.27 | val loss  2.05
# | epoch   0 | [12599/71779] | ms/batch 327.04 | loss  2.27 | val loss  2.06
# | epoch   0 | [12799/71779] | ms/batch 324.87 | loss  2.66 | val loss  2.04
# | epoch   0 | [12999/71779] | ms/batch 324.85 | loss  2.77 | val loss  2.11
# | epoch   0 | [13199/71779] | ms/batch 325.63 | loss  2.38 | val loss  2.12
# | epoch   0 | [13399/71779] | ms/batch 323.56 | loss  2.39 | val loss  2.16
# | epoch   0 | [13599/71779] | ms/batch 322.91 | loss  2.59 | val loss  2.19
# | epoch   0 | [13799/71779] | ms/batch 324.22 | loss  2.77 | val loss  2.14
# | epoch   0 | [13999/71779] | ms/batch 325.32 | loss  2.18 | val loss  2.12
# | epoch   0 | [14199/71779] | ms/batch 326.88 | loss  2.60 | val loss  2.27
# | epoch   0 | [14399/71779] | ms/batch 324.17 | loss  2.47 | val loss  2.21
# | epoch   0 | [14599/71779] | ms/batch 325.16 | loss  2.57 | val loss  2.17
# | epoch   0 | [14799/71779] | ms/batch 327.31 | loss  3.04 | val loss  2.26
# | epoch   0 | [14999/71779] | ms/batch 336.65 | loss  2.12 | val loss  2.33
# | epoch   0 | [15199/71779] | ms/batch 324.32 | loss  2.57 | val loss  2.24
# | epoch   0 | [15399/71779] | ms/batch 325.78 | loss  2.10 | val loss  2.29
# | epoch   0 | [15599/71779] | ms/batch 324.93 | loss  2.79 | val loss  2.30
# | epoch   0 | [15799/71779] | ms/batch 326.61 | loss  2.17 | val loss  2.26
# | epoch   0 | [15999/71779] | ms/batch 326.09 | loss  2.65 | val loss  2.28
# | epoch   0 | [16199/71779] | ms/batch 325.43 | loss  2.32 | val loss  2.26
# | epoch   0 | [16399/71779] | ms/batch 324.99 | loss  2.51 | val loss  2.24
# | epoch   0 | [16599/71779] | ms/batch 324.10 | loss  2.72 | val loss  2.26
# | epoch   0 | [16799/71779] | ms/batch 327.72 | loss  2.53 | val loss  2.29
# | epoch   0 | [16999/71779] | ms/batch 332.96 | loss  3.14 | val loss  2.34
# | epoch   0 | [17199/71779] | ms/batch 331.67 | loss  3.05 | val loss  2.32
# | epoch   0 | [17399/71779] | ms/batch 324.33 | loss  1.82 | val loss  2.37
# | epoch   0 | [17599/71779] | ms/batch 324.33 | loss  2.97 | val loss  2.28
# | epoch   0 | [17799/71779] | ms/batch 324.58 | loss  3.08 | val loss  2.31
# | epoch   0 | [17999/71779] | ms/batch 325.00 | loss  2.28 | val loss  2.41
# | epoch   0 | [18199/71779] | ms/batch 324.29 | loss  2.42 | val loss  2.38
# | epoch   0 | [18399/71779] | ms/batch 325.59 | loss  2.77 | val loss  2.32
# | epoch   0 | [18599/71779] | ms/batch 328.11 | loss  3.25 | val loss  2.36
# | epoch   0 | [18799/71779] | ms/batch 327.92 | loss  2.60 | val loss  2.42
# | epoch   0 | [18999/71779] | ms/batch 325.65 | loss  2.61 | val loss  2.41
# | epoch   0 | [19199/71779] | ms/batch 326.13 | loss  2.94 | val loss  2.37
# | epoch   0 | [19399/71779] | ms/batch 324.71 | loss  2.57 | val loss  2.47
# | epoch   0 | [19599/71779] | ms/batch 325.06 | loss  2.05 | val loss  2.40
# | epoch   0 | [19799/71779] | ms/batch 325.49 | loss  2.68 | val loss  2.50
# | epoch   0 | [19999/71779] | ms/batch 325.74 | loss  2.74 | val loss  2.45
# | epoch   0 | [20199/71779] | ms/batch 325.95 | loss  2.42 | val loss  2.44
# | epoch   0 | [20399/71779] | ms/batch 325.64 | loss  2.70 | val loss  2.51
# | epoch   0 | [20599/71779] | ms/batch 326.50 | loss  3.25 | val loss  2.51
# | epoch   0 | [20799/71779] | ms/batch 323.89 | loss  3.16 | val loss  2.35
# | epoch   0 | [20999/71779] | ms/batch 325.34 | loss  3.26 | val loss  2.48
# | epoch   0 | [21199/71779] | ms/batch 324.67 | loss  2.89 | val loss  2.44
# | epoch   0 | [21399/71779] | ms/batch 325.11 | loss  3.13 | val loss  2.51
# | epoch   0 | [21599/71779] | ms/batch 324.64 | loss  2.65 | val loss  2.52
# | epoch   0 | [21799/71779] | ms/batch 323.85 | loss  3.27 | val loss  2.47
# | epoch   0 | [21999/71779] | ms/batch 326.98 | loss  3.40 | val loss  2.53
# | epoch   0 | [22199/71779] | ms/batch 326.39 | loss  2.72 | val loss  2.45
# | epoch   0 | [22399/71779] | ms/batch 324.89 | loss  2.48 | val loss  2.46
# | epoch   0 | [22599/71779] | ms/batch 325.60 | loss  2.84 | val loss  2.54
# | epoch   0 | [22799/71779] | ms/batch 325.64 | loss  3.22 | val loss  2.49
# | epoch   0 | [22999/71779] | ms/batch 325.53 | loss  3.16 | val loss  2.59
# | epoch   0 | [23199/71779] | ms/batch 325.90 | loss  2.95 | val loss  2.56
# | epoch   0 | [23399/71779] | ms/batch 324.86 | loss  2.95 | val loss  2.57
# | epoch   0 | [23599/71779] | ms/batch 326.53 | loss  3.35 | val loss  2.52
# | epoch   0 | [23799/71779] | ms/batch 329.70 | loss  2.95 | val loss  2.56
# | epoch   0 | [23999/71779] | ms/batch 325.92 | loss  2.60 | val loss  2.56
# | epoch   0 | [24199/71779] | ms/batch 326.80 | loss  2.72 | val loss  2.60
# | epoch   0 | [24399/71779] | ms/batch 324.33 | loss  2.76 | val loss  2.59
# | epoch   0 | [24599/71779] | ms/batch 325.24 | loss  2.34 | val loss  2.51
# | epoch   0 | [24799/71779] | ms/batch 324.92 | loss  2.06 | val loss  2.59
# | epoch   0 | [24999/71779] | ms/batch 325.84 | loss  2.66 | val loss  2.58
# | epoch   0 | [25199/71779] | ms/batch 327.08 | loss  2.89 | val loss  2.58
# | epoch   0 | [25399/71779] | ms/batch 325.23 | loss  2.64 | val loss  2.54
# | epoch   0 | [25599/71779] | ms/batch 326.28 | loss  2.29 | val loss  2.63
# | epoch   0 | [25799/71779] | ms/batch 326.05 | loss  2.66 | val loss  2.57
# | epoch   0 | [25999/71779] | ms/batch 325.33 | loss  2.92 | val loss  2.51
# | epoch   0 | [26199/71779] | ms/batch 324.63 | loss  3.46 | val loss  2.65
# | epoch   0 | [26399/71779] | ms/batch 326.75 | loss  3.16 | val loss  2.58
# | epoch   0 | [26599/71779] | ms/batch 325.21 | loss  3.23 | val loss  2.65
# | epoch   0 | [26799/71779] | ms/batch 324.74 | loss  2.94 | val loss  2.62
# | epoch   0 | [26999/71779] | ms/batch 326.00 | loss  3.12 | val loss  2.63
# | epoch   0 | [27199/71779] | ms/batch 325.82 | loss  3.39 | val loss  2.66
# | epoch   0 | [27399/71779] | ms/batch 325.89 | loss  3.11 | val loss  2.70
# | epoch   0 | [27599/71779] | ms/batch 325.08 | loss  3.46 | val loss  2.67
# | epoch   0 | [27799/71779] | ms/batch 324.16 | loss  2.81 | val loss  2.67
# | epoch   0 | [27999/71779] | ms/batch 324.49 | loss  2.49 | val loss  2.63
# | epoch   0 | [28199/71779] | ms/batch 327.78 | loss  2.64 | val loss  2.71
# | epoch   0 | [28399/71779] | ms/batch 325.80 | loss  2.72 | val loss  2.67
# | epoch   0 | [28599/71779] | ms/batch 322.48 | loss  3.22 | val loss  2.63
# | epoch   0 | [28799/71779] | ms/batch 324.39 | loss  2.85 | val loss  2.72
# | epoch   0 | [28999/71779] | ms/batch 325.30 | loss  3.01 | val loss  2.66
# | epoch   0 | [29199/71779] | ms/batch 326.21 | loss  3.47 | val loss  2.67
# | epoch   0 | [29399/71779] | ms/batch 337.52 | loss  3.46 | val loss  2.70
# | epoch   0 | [29599/71779] | ms/batch 328.39 | loss  2.92 | val loss  2.68
# | epoch   0 | [29799/71779] | ms/batch 325.76 | loss  3.22 | val loss  2.61
# | epoch   0 | [29999/71779] | ms/batch 329.48 | loss  3.10 | val loss  2.74
# | epoch   0 | [30199/71779] | ms/batch 328.05 | loss  2.62 | val loss  2.70
# | epoch   0 | [30399/71779] | ms/batch 325.70 | loss  3.23 | val loss  2.72
# | epoch   0 | [30599/71779] | ms/batch 325.06 | loss  3.12 | val loss  2.78
# | epoch   0 | [30799/71779] | ms/batch 326.38 | loss  2.64 | val loss  2.68
# | epoch   0 | [30999/71779] | ms/batch 324.96 | loss  3.22 | val loss  2.68
# | epoch   0 | [31199/71779] | ms/batch 323.70 | loss  3.32 | val loss  2.72
# | epoch   0 | [31399/71779] | ms/batch 323.37 | loss  3.10 | val loss  2.72
# | epoch   0 | [31599/71779] | ms/batch 325.06 | loss  3.19 | val loss  2.74
# | epoch   0 | [31799/71779] | ms/batch 326.18 | loss  3.15 | val loss  2.64
# | epoch   0 | [31999/71779] | ms/batch 333.00 | loss  2.94 | val loss  2.69
# | epoch   0 | [32199/71779] | ms/batch 325.35 | loss  2.86 | val loss  2.73
# | epoch   0 | [32399/71779] | ms/batch 324.66 | loss  3.34 | val loss  2.73
# | epoch   0 | [32599/71779] | ms/batch 325.59 | loss  3.07 | val loss  2.73
# | epoch   0 | [32799/71779] | ms/batch 327.51 | loss  3.23 | val loss  2.61
# | epoch   0 | [32999/71779] | ms/batch 324.58 | loss  2.47 | val loss  2.77
# | epoch   0 | [33199/71779] | ms/batch 326.70 | loss  2.78 | val loss  2.65
# | epoch   0 | [33399/71779] | ms/batch 325.60 | loss  3.40 | val loss  2.82
# | epoch   0 | [33599/71779] | ms/batch 326.72 | loss  3.22 | val loss  2.63
# | epoch   0 | [33799/71779] | ms/batch 328.92 | loss  3.24 | val loss  2.79
# | epoch   0 | [33999/71779] | ms/batch 326.82 | loss  2.65 | val loss  2.79
# | epoch   0 | [34199/71779] | ms/batch 327.91 | loss  3.75 | val loss  2.75
# | epoch   0 | [34399/71779] | ms/batch 330.88 | loss  3.39 | val loss  2.64
# | epoch   0 | [34599/71779] | ms/batch 326.96 | loss  3.42 | val loss  2.78
# | epoch   0 | [34799/71779] | ms/batch 332.39 | loss  2.98 | val loss  2.72
# | epoch   0 | [34999/71779] | ms/batch 335.96 | loss  3.29 | val loss  2.75
# | epoch   0 | [35199/71779] | ms/batch 326.55 | loss  2.78 | val loss  2.79
# | epoch   0 | [35399/71779] | ms/batch 323.91 | loss  3.33 | val loss  2.78
# | epoch   0 | [35599/71779] | ms/batch 328.75 | loss  3.08 | val loss  2.75
# | epoch   0 | [35799/71779] | ms/batch 325.47 | loss  2.40 | val loss  2.83
# | epoch   0 | [35999/71779] | ms/batch 327.70 | loss  2.75 | val loss  2.76
# | epoch   0 | [36199/71779] | ms/batch 329.53 | loss  2.71 | val loss  2.84
# | epoch   0 | [36399/71779] | ms/batch 327.08 | loss  3.11 | val loss  2.79
# | epoch   0 | [36599/71779] | ms/batch 329.40 | loss  3.06 | val loss  2.75
# | epoch   0 | [36799/71779] | ms/batch 327.43 | loss  3.23 | val loss  2.72
# | epoch   0 | [36999/71779] | ms/batch 329.18 | loss  3.06 | val loss  2.80
# | epoch   0 | [37199/71779] | ms/batch 325.34 | loss  2.96 | val loss  2.73
# | epoch   0 | [37399/71779] | ms/batch 327.07 | loss  3.54 | val loss  2.77
# | epoch   0 | [37599/71779] | ms/batch 327.48 | loss  2.65 | val loss  2.82
# | epoch   0 | [37799/71779] | ms/batch 329.97 | loss  3.19 | val loss  2.75
# | epoch   0 | [37999/71779] | ms/batch 325.22 | loss  2.60 | val loss  2.81
# | epoch   0 | [38199/71779] | ms/batch 327.12 | loss  3.12 | val loss  2.76
# | epoch   0 | [38399/71779] | ms/batch 329.97 | loss  2.04 | val loss  2.80
# | epoch   0 | [38599/71779] | ms/batch 328.71 | loss  3.42 | val loss  2.84
# | epoch   0 | [38799/71779] | ms/batch 326.09 | loss  2.84 | val loss  2.78
# | epoch   0 | [38999/71779] | ms/batch 327.97 | loss  3.14 | val loss  2.94
# | epoch   0 | [39199/71779] | ms/batch 342.05 | loss  3.27 | val loss  2.92
# | epoch   0 | [39399/71779] | ms/batch 331.06 | loss  3.83 | val loss  2.88
# | epoch   0 | [39599/71779] | ms/batch 330.22 | loss  2.97 | val loss  2.92
# | epoch   0 | [39799/71779] | ms/batch 327.74 | loss  3.58 | val loss  2.87
# | epoch   0 | [39999/71779] | ms/batch 327.69 | loss  3.76 | val loss  2.91
# | epoch   0 | [40199/71779] | ms/batch 325.53 | loss  3.46 | val loss  2.84
# | epoch   0 | [40399/71779] | ms/batch 328.84 | loss  3.15 | val loss  2.91
# | epoch   0 | [40599/71779] | ms/batch 334.71 | loss  3.04 | val loss  2.93
# | epoch   0 | [40799/71779] | ms/batch 326.72 | loss  3.46 | val loss  2.91
# | epoch   0 | [40999/71779] | ms/batch 325.57 | loss  2.63 | val loss  2.93
# | epoch   0 | [41199/71779] | ms/batch 330.63 | loss  3.28 | val loss  2.90
# | epoch   0 | [41399/71779] | ms/batch 329.38 | loss  2.92 | val loss  2.81
# | epoch   0 | [41599/71779] | ms/batch 329.06 | loss  2.59 | val loss  2.95
# | epoch   0 | [41799/71779] | ms/batch 325.51 | loss  3.35 | val loss  2.95
# | epoch   0 | [41999/71779] | ms/batch 325.40 | loss  3.11 | val loss  2.95
# | epoch   0 | [42199/71779] | ms/batch 327.92 | loss  2.71 | val loss  2.93
# | epoch   0 | [42399/71779] | ms/batch 328.63 | loss  3.45 | val loss  2.94
# | epoch   0 | [42599/71779] | ms/batch 324.20 | loss  3.00 | val loss  2.95
# | epoch   0 | [42799/71779] | ms/batch 327.71 | loss  3.33 | val loss  2.96
# | epoch   0 | [42999/71779] | ms/batch 324.84 | loss  2.72 | val loss  2.94
# | epoch   0 | [43199/71779] | ms/batch 324.71 | loss  3.49 | val loss  3.07
# | epoch   0 | [43399/71779] | ms/batch 324.87 | loss  3.72 | val loss  2.92
# | epoch   0 | [43599/71779] | ms/batch 326.27 | loss  3.24 | val loss  2.90
# | epoch   0 | [43799/71779] | ms/batch 329.10 | loss  2.74 | val loss  2.86
# | epoch   0 | [43999/71779] | ms/batch 326.55 | loss  3.32 | val loss  2.90
# | epoch   0 | [44199/71779] | ms/batch 325.72 | loss  3.53 | val loss  2.92
# | epoch   0 | [44399/71779] | ms/batch 324.11 | loss  3.12 | val loss  2.84
# | epoch   0 | [44599/71779] | ms/batch 324.49 | loss  3.15 | val loss  3.03
# | epoch   0 | [44799/71779] | ms/batch 324.83 | loss  3.20 | val loss  2.85
# | epoch   0 | [44999/71779] | ms/batch 330.46 | loss  3.26 | val loss  2.85
# | epoch   0 | [45199/71779] | ms/batch 327.01 | loss  3.28 | val loss  2.86
# | epoch   0 | [45399/71779] | ms/batch 332.98 | loss  3.40 | val loss  2.89
# | epoch   0 | [45599/71779] | ms/batch 327.17 | loss  3.09 | val loss  2.98
# | epoch   0 | [45799/71779] | ms/batch 324.36 | loss  4.11 | val loss  3.00
# | epoch   0 | [45999/71779] | ms/batch 324.01 | loss  3.12 | val loss  2.92
# | epoch   0 | [46199/71779] | ms/batch 323.18 | loss  3.80 | val loss  3.00
# | epoch   0 | [46399/71779] | ms/batch 325.08 | loss  2.57 | val loss  2.90
# | epoch   0 | [46599/71779] | ms/batch 326.04 | loss  3.29 | val loss  2.86
# | epoch   0 | [46799/71779] | ms/batch 327.21 | loss  3.09 | val loss  2.95
# | epoch   0 | [46999/71779] | ms/batch 326.76 | loss  3.84 | val loss  2.99
# | epoch   0 | [47199/71779] | ms/batch 325.38 | loss  3.05 | val loss  3.02
# | epoch   0 | [47399/71779] | ms/batch 325.76 | loss  2.82 | val loss  2.89
# | epoch   0 | [47599/71779] | ms/batch 327.51 | loss  3.15 | val loss  3.02
# | epoch   0 | [47799/71779] | ms/batch 325.97 | loss  3.63 | val loss  2.92
# | epoch   0 | [47999/71779] | ms/batch 328.71 | loss  2.84 | val loss  2.89
# | epoch   0 | [48199/71779] | ms/batch 326.51 | loss  3.43 | val loss  2.93
# | epoch   0 | [48399/71779] | ms/batch 327.18 | loss  3.48 | val loss  2.99
# | epoch   0 | [48599/71779] | ms/batch 326.06 | loss  3.47 | val loss  2.92
# | epoch   0 | [48799/71779] | ms/batch 327.33 | loss  3.29 | val loss  2.94
# | epoch   0 | [48999/71779] | ms/batch 328.68 | loss  3.16 | val loss  2.92
# | epoch   0 | [49199/71779] | ms/batch 324.73 | loss  3.31 | val loss  2.95
# | epoch   0 | [49399/71779] | ms/batch 326.77 | loss  3.46 | val loss  3.01
# | epoch   0 | [49599/71779] | ms/batch 327.99 | loss  3.59 | val loss  2.99
# | epoch   0 | [49799/71779] | ms/batch 334.99 | loss  3.90 | val loss  2.97
# | epoch   0 | [49999/71779] | ms/batch 334.66 | loss  3.36 | val loss  2.97
# | epoch   0 | [50199/71779] | ms/batch 331.84 | loss  3.10 | val loss  2.99
# | epoch   0 | [50399/71779] | ms/batch 329.11 | loss  3.35 | val loss  3.01
# | epoch   0 | [50599/71779] | ms/batch 331.87 | loss  3.52 | val loss  2.91
# | epoch   0 | [50799/71779] | ms/batch 329.02 | loss  3.66 | val loss  2.95
# | epoch   0 | [50999/71779] | ms/batch 333.00 | loss  3.92 | val loss  2.97
# | epoch   0 | [51199/71779] | ms/batch 333.95 | loss  3.36 | val loss  2.98
# | epoch   0 | [51399/71779] | ms/batch 335.78 | loss  3.18 | val loss  3.02
# | epoch   0 | [51599/71779] | ms/batch 328.14 | loss  3.23 | val loss  3.09
# | epoch   0 | [51799/71779] | ms/batch 324.98 | loss  3.14 | val loss  3.03
# | epoch   0 | [51999/71779] | ms/batch 330.93 | loss  3.23 | val loss  2.99
# | epoch   0 | [52199/71779] | ms/batch 327.27 | loss  3.21 | val loss  2.97
# | epoch   0 | [52399/71779] | ms/batch 326.73 | loss  3.22 | val loss  3.02
# | epoch   0 | [52599/71779] | ms/batch 326.54 | loss  3.78 | val loss  2.95
# | epoch   0 | [52799/71779] | ms/batch 326.06 | loss  3.79 | val loss  3.00
# | epoch   0 | [52999/71779] | ms/batch 326.62 | loss  3.45 | val loss  2.93
# | epoch   0 | [53199/71779] | ms/batch 328.04 | loss  3.03 | val loss  2.90
# | epoch   0 | [53399/71779] | ms/batch 325.07 | loss  3.35 | val loss  2.93
# | epoch   0 | [53599/71779] | ms/batch 324.72 | loss  3.47 | val loss  3.02
# | epoch   0 | [53799/71779] | ms/batch 325.66 | loss  3.57 | val loss  3.05
# | epoch   0 | [53999/71779] | ms/batch 330.08 | loss  3.52 | val loss  2.94
# | epoch   0 | [54199/71779] | ms/batch 327.29 | loss  3.02 | val loss  3.08
# | epoch   0 | [54399/71779] | ms/batch 326.12 | loss  3.54 | val loss  3.01
# | epoch   0 | [54599/71779] | ms/batch 325.47 | loss  3.57 | val loss  2.98
# | epoch   0 | [54799/71779] | ms/batch 325.88 | loss  3.09 | val loss  2.98
# | epoch   0 | [54999/71779] | ms/batch 328.16 | loss  3.04 | val loss  3.01
# | epoch   0 | [55199/71779] | ms/batch 327.38 | loss  3.37 | val loss  2.92
# | epoch   0 | [55399/71779] | ms/batch 324.42 | loss  3.56 | val loss  3.07
# | epoch   0 | [55599/71779] | ms/batch 324.97 | loss  2.96 | val loss  2.95
# | epoch   0 | [55799/71779] | ms/batch 324.62 | loss  3.18 | val loss  2.97
# | epoch   0 | [55999/71779] | ms/batch 324.88 | loss  2.77 | val loss  2.97
# | epoch   0 | [56199/71779] | ms/batch 324.77 | loss  3.80 | val loss  3.04
# | epoch   0 | [56399/71779] | ms/batch 325.97 | loss  3.50 | val loss  3.01
# | epoch   0 | [56599/71779] | ms/batch 327.50 | loss  3.43 | val loss  3.06
# | epoch   0 | [56799/71779] | ms/batch 326.02 | loss  3.15 | val loss  3.00
# | epoch   0 | [56999/71779] | ms/batch 325.46 | loss  3.74 | val loss  3.07
# | epoch   0 | [57199/71779] | ms/batch 324.51 | loss  3.04 | val loss  3.11
# | epoch   0 | [57399/71779] | ms/batch 325.00 | loss  3.09 | val loss  3.08
# | epoch   0 | [57599/71779] | ms/batch 325.12 | loss  4.01 | val loss  3.10
# | epoch   0 | [57799/71779] | ms/batch 324.29 | loss  3.29 | val loss  3.16
# | epoch   0 | [57999/71779] | ms/batch 327.66 | loss  3.87 | val loss  3.04
# | epoch   0 | [58199/71779] | ms/batch 327.63 | loss  2.91 | val loss  3.05
# | epoch   0 | [58399/71779] | ms/batch 327.20 | loss  3.18 | val loss  3.00
# | epoch   0 | [58599/71779] | ms/batch 326.99 | loss  3.84 | val loss  2.99
# | epoch   0 | [58799/71779] | ms/batch 326.45 | loss  3.28 | val loss  3.07
# | epoch   0 | [58999/71779] | ms/batch 327.91 | loss  2.93 | val loss  3.07
# | epoch   0 | [59199/71779] | ms/batch 327.11 | loss  3.65 | val loss  2.91
# | epoch   0 | [59399/71779] | ms/batch 327.25 | loss  2.96 | val loss  2.98
# | epoch   0 | [59599/71779] | ms/batch 325.76 | loss  3.51 | val loss  3.04
# | epoch   0 | [59799/71779] | ms/batch 326.76 | loss  3.54 | val loss  3.00
# | epoch   0 | [59999/71779] | ms/batch 326.43 | loss  3.66 | val loss  2.98
# | epoch   0 | [60199/71779] | ms/batch 327.79 | loss  3.54 | val loss  3.05
# | epoch   0 | [60399/71779] | ms/batch 327.61 | loss  3.07 | val loss  3.04
# | epoch   0 | [60599/71779] | ms/batch 326.65 | loss  3.21 | val loss  3.11
# | epoch   0 | [60799/71779] | ms/batch 326.29 | loss  2.85 | val loss  2.99
# | epoch   0 | [60999/71779] | ms/batch 326.51 | loss  2.92 | val loss  3.05
# | epoch   0 | [61199/71779] | ms/batch 326.25 | loss  3.88 | val loss  3.08
# | epoch   0 | [61399/71779] | ms/batch 327.17 | loss  3.86 | val loss  2.97
# | epoch   0 | [61599/71779] | ms/batch 326.99 | loss  3.26 | val loss  3.09
# | epoch   0 | [61799/71779] | ms/batch 326.08 | loss  3.01 | val loss  3.04
# | epoch   0 | [61999/71779] | ms/batch 326.07 | loss  3.02 | val loss  3.01
# | epoch   0 | [62199/71779] | ms/batch 326.10 | loss  3.19 | val loss  3.04
# | epoch   0 | [62399/71779] | ms/batch 325.27 | loss  3.53 | val loss  3.04
# | epoch   0 | [62599/71779] | ms/batch 325.71 | loss  3.32 | val loss  3.09
# | epoch   0 | [62799/71779] | ms/batch 323.26 | loss  3.02 | val loss  3.04
# | epoch   0 | [62999/71779] | ms/batch 325.58 | loss  2.94 | val loss  2.99
# | epoch   0 | [63199/71779] | ms/batch 325.78 | loss  3.14 | val loss  3.07
# | epoch   0 | [63399/71779] | ms/batch 330.40 | loss  3.40 | val loss  3.00
# | epoch   0 | [63599/71779] | ms/batch 339.44 | loss  3.35 | val loss  3.04
# | epoch   0 | [63799/71779] | ms/batch 337.17 | loss  4.04 | val loss  3.04
# | epoch   0 | [63999/71779] | ms/batch 327.20 | loss  3.02 | val loss  2.96
# | epoch   0 | [64199/71779] | ms/batch 325.99 | loss  3.57 | val loss  3.01
# | epoch   0 | [64399/71779] | ms/batch 325.78 | loss  2.87 | val loss  3.05
# | epoch   0 | [64599/71779] | ms/batch 326.23 | loss  3.44 | val loss  3.04
# | epoch   0 | [64799/71779] | ms/batch 327.15 | loss  3.59 | val loss  3.02
# | epoch   0 | [64999/71779] | ms/batch 326.83 | loss  3.19 | val loss  2.97
# | epoch   0 | [65199/71779] | ms/batch 325.66 | loss  3.59 | val loss  3.07
# | epoch   0 | [65399/71779] | ms/batch 323.43 | loss  3.06 | val loss  3.06
# | epoch   0 | [65599/71779] | ms/batch 321.69 | loss  2.92 | val loss  2.93
# | epoch   0 | [65799/71779] | ms/batch 327.13 | loss  3.35 | val loss  3.08
# | epoch   0 | [65999/71779] | ms/batch 323.91 | loss  3.93 | val loss  3.06
# | epoch   0 | [66199/71779] | ms/batch 325.47 | loss  3.55 | val loss  3.08
# | epoch   0 | [66399/71779] | ms/batch 325.11 | loss  3.50 | val loss  3.06
# | epoch   0 | [66599/71779] | ms/batch 325.06 | loss  3.31 | val loss  3.07
# | epoch   0 | [66799/71779] | ms/batch 325.17 | loss  3.40 | val loss  3.07
# | epoch   0 | [66999/71779] | ms/batch 325.58 | loss  3.03 | val loss  3.05
# | epoch   0 | [67199/71779] | ms/batch 325.58 | loss  3.58 | val loss  3.12
# | epoch   0 | [67399/71779] | ms/batch 324.63 | loss  3.61 | val loss  2.98
# | epoch   0 | [67599/71779] | ms/batch 324.38 | loss  3.47 | val loss  3.03
# | epoch   0 | [67799/71779] | ms/batch 326.20 | loss  3.21 | val loss  3.06
# | epoch   0 | [67999/71779] | ms/batch 323.19 | loss  3.69 | val loss  2.99
# | epoch   0 | [68199/71779] | ms/batch 322.91 | loss  3.96 | val loss  3.12
# | epoch   0 | [68399/71779] | ms/batch 323.35 | loss  3.54 | val loss  2.99
# | epoch   0 | [68599/71779] | ms/batch 323.23 | loss  3.45 | val loss  3.12
# | epoch   0 | [68799/71779] | ms/batch 323.70 | loss  2.93 | val loss  3.09
# | epoch   0 | [68999/71779] | ms/batch 326.45 | loss  3.04 | val loss  3.07
# | epoch   0 | [69199/71779] | ms/batch 326.63 | loss  3.19 | val loss  3.03
# | epoch   0 | [69399/71779] | ms/batch 326.81 | loss  2.82 | val loss  3.01
# | epoch   0 | [69599/71779] | ms/batch 324.81 | loss  3.59 | val loss  3.09
# | epoch   0 | [69799/71779] | ms/batch 326.93 | loss  4.10 | val loss  3.05
# | epoch   0 | [69999/71779] | ms/batch 326.85 | loss  2.92 | val loss  3.07
# | epoch   0 | [70199/71779] | ms/batch 324.39 | loss  3.56 | val loss  3.11
# | epoch   0 | [70399/71779] | ms/batch 325.58 | loss  3.38 | val loss  3.11
# | epoch   0 | [70599/71779] | ms/batch 324.50 | loss  3.26 | val loss  3.09
# | epoch   0 | [70799/71779] | ms/batch 326.18 | loss  3.16 | val loss  3.08
# | epoch   0 | [70999/71779] | ms/batch 326.99 | loss  4.32 | val loss  3.01
# | epoch   0 | [71199/71779] | ms/batch 329.04 | loss  3.93 | val loss  3.00
# | epoch   0 | [71399/71779] | ms/batch 325.79 | loss  3.38 | val loss  3.03
# | epoch   0 | [71599/71779] | ms/batch 325.34 | loss  3.14 | val loss  3.18
# | epoch   1 | [  199/71779] | ms/batch 325.18 | loss  3.19 | val loss  3.06
# | epoch   1 | [  399/71779] | ms/batch 325.07 | loss  3.06 | val loss  3.07
# | epoch   1 | [  599/71779] | ms/batch 327.46 | loss  3.13 | val loss  2.99
# | epoch   1 | [  799/71779] | ms/batch 323.81 | loss  3.60 | val loss  3.04
# | epoch   1 | [  999/71779] | ms/batch 325.80 | loss  3.50 | val loss  3.11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1bcc326f2abf> in <module>
#      11
#      12         optimizer.zero_grad()
# ---> 13         loss = step(inputs_ids, attention_mask, y)
#      14         train_loss.append(loss.item())
#      15         loss.backward()
#
# <ipython-input-13-bebc04e33992> in step(inputs_ids, attention_mask, y)
#       4     lm_labels = y[:, 1:].clone()
#       5     lm_labels[y[:, 1:] == pad_token_id] = -100
# ----> 6     output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
#       7     return output[0] # loss
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/transformers/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_outputs, decoder_input_ids, decoder_attention_mask, decoder_past_key_value_states, use_cache, lm_labels, inputs_embeds, decoder_inputs_embeds, head_mask)
#    1073
#    1074         # Decode
# -> 1075         decoder_outputs = self.decoder(
#    1076             input_ids=decoder_input_ids,
#    1077             attention_mask=decoder_attention_mask,
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/transformers/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, past_key_value_states, use_cache)
#     699
#     700         # ourselves in which case we just need to make it broadcastable to all heads.
# --> 701         extended_attention_mask = self.get_extended_attention_mask(attention_mask, input_shape, self.device)
#     702
#     703         if self.is_decoder and encoder_attention_mask is not None:
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/transformers/modeling_utils.py in get_extended_attention_mask(self, attention_mask, input_shape, device)
#     154                 batch_size, seq_length = input_shape
#     155                 seq_ids = torch.arange(seq_length, device=device)
# --> 156                 causal_mask = seq_ids[None, None, :].repeat(batch_size, seq_length, 1) <= seq_ids[None, :, None]
#     157                 # causal and attention masks must have same type with pytorch version < 1.3
#     158                 causal_mask = causal_mask.to(attention_mask.dtype)
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/torch/tensor.py in wrapped(*args, **kwargs)
#      26     def wrapped(*args, **kwargs):
#      27         try:
# ---> 28             return f(*args, **kwargs)
#      29         except TypeError:
#      30             return NotImplemented
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate

# %%
from rouge_score import rouge_scorer
from rouge_score import scoring

class RougeScore:
    '''
    mostly from https://github.com/google-research/text-to-text-transfer-transformer/blob/master/t5/evaluation/metrics.py 
    '''
    
    def __init__(self, score_keys=None)-> None:
        super().__init__()
        if score_keys is None:  
            self.score_keys = ["rouge1", "rouge2", "rougeLsum"]
        
        self.scorer = rouge_scorer.RougeScorer(self.score_keys)
        self.aggregator = scoring.BootstrapAggregator()
        
        
    @staticmethod
    def prepare_summary(summary):
            # Make sure the summary is not bytes-type
            # Add newlines between sentences so that rougeLsum is computed correctly.
            summary = summary.replace(" . ", " .\n")
            return summary
    
    def __call__(self, target, prediction):
        """Computes rouge score.''
        Args:
        targets: string
        predictions: string
        """

        target = self.prepare_summary(target)
        prediction = self.prepare_summary(prediction)
        
        self.aggregator.add_scores(self.scorer.score(target=target, prediction=prediction))

        return 
    
    def reset_states(self):
        self.rouge_list = []

    def result(self):
        result = self.aggregator.aggregate()
        
        for key in self.score_keys:
            score_text = "%s = %.2f, 95%% confidence [%.2f, %.2f]"%(
                key,
                result[key].mid.fmeasure*100,
                result[key].low.fmeasure*100,
                result[key].high.fmeasure*100
            )
            print(score_text)
        
        return {key: result[key].mid.fmeasure*100 for key in self.score_keys}

# %%
rouge_score = RougeScore()
predictions = []
for i, (input_ids, attention_mask, y) in enumerate(test_loader):
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)
    y = y.to(device)
        
    summaries = model.generate(input_ids=input_ids, attention_mask=attention_mask)
    pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summaries]
    real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in y]
    for pred_sent, real_sent in zip(pred, real):
        rouge_score(pred_sent, real_sent)
        predictions.append(str("pred sentence: " + pred_sent + "\n\n real sentence: " + real_sent))
    if i > 40:
        break
    
rouge_score.result()
# Out:
# rouge1 = 21.60, 95% confidence [20.65, 22.56]
# rouge2 = 4.72, 95% confidence [4.19, 5.25]
# rougeLsum = 12.84, 95% confidence [12.27, 13.34]
# {'rouge1': 21.601131331699854,
#  'rouge2': 4.72085075525385,
#  'rougeLsum': 12.835751381295408}

# %%
for pred in predictions[:10]:
    print("------")
    print(pred)
    print("------")
# Out:
# ------
# pred sentence: cynthia und faa, krakral platz. flugzeuge von flugflugzeugzeugen, die die armlehne, ob ein derart steste platz in der ffährdete. die armarmarmarmlelehne ernsteren problemen, dass die gesundheit und sicherheit gefähndet wurde, während es nicht nicht nicht nur nur unangeangegriffen. er schrumrumte, dass er von der stötet wurde. sie sagt, er sei sei ein fluggesellschaften, um die detrote flugbebebeteckt. der flug der ddächtigte den platz, um flugfächte zu hausen. "icht", sagt, dass sie sie in den flug
#
#  real sentence: 0; experten bezweifeln, ob überfüllte flugzeuge passagiere gefährden. die us-verbraucherberatungsgruppe sagt, dass mindestabstände vorgeschrieben werden müssen. sicherheitstests in flugzeugen mit mehr beinfreiheit als von fluggesellschaften angeboten, werden durchgeführt.
# ------
# ------
# pred sentence: rahul kumar, 17, kletterte über den zaun des kamla nehrtes zoos in ahmedabad, rannte, schriete auf die löwengegehege töte. kukukumar kumte in der nähe des gehegergerettet werden, nachdem er geretteten, er sei sei gesges. nahhüte und schlugte die polizess. er wurde von er in opfers schlielieben schötenten, als schottete zu lölölösen. schraustöten zufolge, dass er die zerzerzer schschrie, die zötete t
#
#  real sentence: 1; betrunkener teenager kletterte in löwengehege eines zoos in westindien: rahul kumar, 17, lief auf tiere zu und schrie: "heute töte ich einen löwen!" glücklicherweise stürzte er in einen wassergraben, bevor er die löwen erreichte und wurde gerettet.
# ------
# ------
# pred sentence: tougiugiugie stuart pearce im februar zu unternehmen, seit er stuart hat sich sich auf den play-off-plätzen unterzeichnen. eigentanni hat in den letzten wochen abgelöst hat. kühnen, seit der clubbesvertrag hat die clubbebesitzeritzer hat ein vertrag bei arbeit am city city city ground beeindruckt. hat hat der clubclub hat den vertrag in den play play play. er hat zwei zwei zweijahresvertrag bei nottingham einigen wochen abgesprungen. sühnensvertragsvertrag auf einigen vertrag. teilttinghamingham hat auf dem vertrag zu seinen vertrag auf dem city ground 's hat man man man hat einen neuen neuen neuen vertrag im febr febr febrdman pearcen im febrtingham
#
#  real sentence: 2; nottingham forest steht kurz vor der vertragsverlängerung von dougie freedman, der im februar die nachfolge des ehemaligen managers stuart pearce angetreten hatte und den club seitdem auf den neunten tabellenplatz geführt hat.
# ------
# ------
# pred sentence: stürmt von seinem tor, als juanannororora-torhüter neto torortet konkurrenz um den fiororententina-stürme beim beispielspiels in spaniena gebracht wurde, als simonmon mignognognolet. neto sagt, dass es klubs im juventuventuar für neto zu entscheidung getroffen wurde, aber jujujuan iturbetört wurde. er wurde im märz niedersgt, ermitmitmittigungigungigung getroffen, aber aber er erlitt. der reihereihereihennstorahüte vereinbarung treffen gespielt. stefano castagna, während der der saison hat er
#
#  real sentence: 3; fiorentina-torhüter neto wurde mit liverpool und arsenal in verbindung gebracht. neto kam 2011 vom brasilianischen erstligisten atletico paranaense zu fiorentina und wird laut seinem agenten auch von psg und spanischen clubs gesucht.
# ------
# ------
# pred sentence: diane sawyer für einen tödlichen frauen. der ehemalige olympionpionpionesawsaw tv-star. april, 65, wird im letzten jahr in kardashashashians in armenien. kardasdashian karderderder steckte, während er sich in den kündigte alten alten jahr. kris, als er er aus der jahren, ras aufgrund ihrer schweigen küte. er sagt, dass er in einem jahr auf kkulationen von apfelnnägelgelgels zu eigen, aapfel. gerüchtenn, die näggglaubte er seien zu einem rückrückrückt werden. wuchs
#
#  real sentence: 4; das interview mit dem reality-tv-star, 69, wird am freitag, den 24. april ausgestrahlt, inmitten anhaltender spekulationen über seinen wechsel zu einer frau und nach seiner verwicklung in einen tödlichen autounfall im februar. das interview wird auch einer von diane sawyers ersten fernsehauftritten nach dem plötzlichen tod ihres mannes im vergangenen jahr sein.
# ------
# ------
# pred sentence: schwimmmmmmte sich in ringwood, hampshire, stürzte schwein schwürzte. die schwes schwininen, die besatzung von schwimmerimmern. schwatenten schwimmen schrettung der schwichte, das das schwiven schwandand, um die anruf geretteettet werden, um um es zu einer spezizialeinheit der krankenhaus ziehen. er wurde in fernfernferne schwalaleinheiten und leinen. spferd ssex, um eine spezialschläge, das nach einem swimmingpool. ham gergerettetes aus dem swimmingpool in hamhampferdetshireshire, um strostrotttung von hamsex
#
#  real sentence: 5; riesenschwein fiel in den swimmingpool seines hauses in ringwood, hampshire. es bedurfte der anstrengungen eines teams von feuerwehrleuten, um es aus dem wasser zu ziehen. auch ein eigensinniges pferd musste aus einem swimmingpool in sussex gerettet werden.
# ------
# ------
# pred sentence: bbc-radia-radiossrates hörte durchschnittliche hörer in den letzten drei monaten des jahres 2014 lediglich stunden pro woche, die die menschen in der er zeit des letzten stunden hören, die zahlen hörten. die militärfen höres 2013 hat die hörung des hauses in den niedergang in den fall zu hören. zwangsangriffe, ny hall hall hört. er sagt, dass die mmmutter hörhörer hörter hören und seinen stimmen der wettbewerb hört, dass nstretrete zuhören. der polizei hören hören in den den tüte. mänänsstabc, obc
#
#  real sentence: 6; in den letzten drei monaten des jahres 2014 verbrachte der durchschnittliche hörer zehn stunden pro woche mit tuning. das waren 14% weniger als zehn jahre zuvor, als die menschen 11,6 stunden lang einschalteten. der bbc trust hat firmen den weg geebnet, sich in einem product-placement-experiment in lifestyleprogramme auf dem world news-kanal einzukaufen. zum beispiel könnten verlage dafür bezahlen, dass ihre bücher auf talking books rezensiert werden. der bbc trust wird das programm in einem jahr überprüfen.
# ------
# ------
# pred sentence: jodie cameron burs kimmy kimkimkim 's beste freundundin kimmel in "jj.jjj, mary-kate und lori ollin, teilte nete netflix ollasate. katet mm. sanner sagetanner behauptet, dass es bob safate, lore loughlin oopfer hat. die schwestland und mutter und wütte die geschichte von kumflix mit lorlori holland, dave aloughtet.. er hat die südd.. die serie hat eine eine "fulfulfulll house" fand, die tan
#
#  real sentence: 7; die show werde mit einem einstündigen special zurückkehren, gefolgt von einem spin-off, sagte star john stamos, der die show am montagabend auf "jimmy kimmel live" ankündigte.
# ------
# ------
# pred sentence: evans, die 29-jährige heiligeiligeilige baze des snookerverband mutter aus dudley, am am donnerstag in der weltmeister, am donnerdley. der wm-qualqualifikationsspiels gegen doherty. ervans hat die frauen im sport sport. die männnädiger kritisierte spieler erlitte den wmmty, der 1997 hat eine wwm. schochotiker und holtikerikeriker, die erschütterte, die letzte uhr hat, holholty zu seinen sieg. envans in allen spiels, forderte er den wettwettwetter. gnäderte hathat sich während des krankenhaus
#
#  real sentence: 8; reanne evans traf in der wm-qualifikation auf ken doherty. doherty gewann 1997 die weltmeisterschaft. evans verlor den ersten frame 71-15 gegen doherty. doch der gebürtige dudley kämpfte sich zurück und führte 4-3. ken doherty gelang es jedoch, einen packenden wettkampf mit 10-8 zu beenden.
# ------
# ------
# pred sentence: das oxford crown court hörte, wie sie sie sexuell zu missbrauchen zwischen zwischen 13 jahren verurteilt und neun jahre. die mädchen beurteilt die mänänner wurde in sozialen medien lockten, die von der bande auf partys von ahmed-sule genommen. opfer forderte sich in strafen, sie schuldig gesprochen. ereignete in den wohnungen in der wohnung der frauen, ooxxfordfordford haftstrafe und neu: "eine freunde", sagt, dass die polizei schuldig, die vor gericht. mutter. es ist ein kind, die handlungen zu schuldigen. "fii zoe erlitte mm
#
#  real sentence: 9; wegen sexuellen missbrauchs von kindern muss die bande insgesamt 31 jahre ins gefängnis. die taten ereigneten sich in autos, wäldern oder in den wohnungen der angeklagten in banbury. opfer wurden zu partys gelockt, die über soziale medien organisiert wurden, und dann missbraucht. mädchen im alter zwischen 13 und 16 jahren wurden von der bande zwischen 2009 und 2014 ausgebeutet.
# ------

# %%
result_path = "../data/result_german_t5_base.txt"
for pred in predictions:
    with open(result_path, "a") as file:
        file.write(pred + "\n")

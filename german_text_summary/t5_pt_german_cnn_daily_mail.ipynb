# %% [markdown]
# # German Text Summary with the tranlated CNN Daily Mail Dataset
# and T5 from Huggingface Pytorch

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
import torch
import re
import time

# %%
BATCH_SIZE = 16

SHUFFEL_SIZE = 1024

# device = "cpu"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate = 3e-5

first_run = False

# %%
print(device)
# Out:
# cuda:0

# %%
def write_data(iter_dataset, name, path="data/"):
    
    articles_file = Path(path + name + "/article").open("w")
    highlights_file = Path(path + name + "/highlights").open("w")

    for item in iter_dataset:
        articles_file.write(item["article"].decode("utf-8") + "\n")
        articles_file.flush()
        highlights_file.write(item["highlights"].decode("utf-8").replace("\n", " ") + "\n")
        highlights_file.flush()

if first_run:
    cnn_dailymail = tfds.load(name="cnn_dailymail")
    
    train_tfds = cnn_dailymail['train']
    test_tfds = cnn_dailymail['test']
    val_tfds = cnn_dailymail['validation']
    
    train_ds_iter = tfds.as_numpy(train_tfds)
    val_ds_iter = tfds.as_numpy(val_tfds)
    test_ds_iter = tfds.as_numpy(test_tfds)
    
    write_data(train_ds_iter, "train")
    write_data(test_ds_iter, "test")
    write_data(val_ds_iter, "val")

# %% [markdown]
# ## Define Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small').to(device)

task_specific_params = model.config.task_specific_params
if task_specific_params is not None:
    model.config.update(task_specific_params.get("summarization", {}))
    

optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.0001)

# %% [markdown]
# ## Read the tranlated German Dataset

# %%
name = "train"

article_path = "../data/%s/articles_german" % name
highlights_path = "../data/%s/highlights_german" % name

articles = [x.rstrip() for x in open(article_path).readlines()]
highlights = [x.rstrip() for x in open(highlights_path).readlines()]

len_articles = len(articles)

def get_dict_data(list_input):
    ret_dict = {}
    for input_item in list_input:
        data_point = input_item.split(";")
        data_id = data_point[0]
        data = ""
        for item in data_point[1:]:
            data += item
        ret_dict[int(data_id)] = data.strip()
    return ret_dict
    
articles = get_dict_data(articles)
highlights = get_dict_data(highlights)

# %%
cleaned_articles = []
cleaned_highlights = []

for i in range(len_articles):
    if i in articles.keys() and i in highlights.keys():
        cleaned_articles.append(articles[i])
        cleaned_highlights.append(highlights[i])
#     else:
#         print(i)

# %%
assert len(cleaned_articles) == len(cleaned_highlights)

val_size = int(len(cleaned_articles)*0.1)
train_x = cleaned_articles[val_size:] 
train_y = cleaned_highlights[val_size:] 
val_x = cleaned_articles[:val_size] 
val_y = cleaned_highlights[:val_size]

# %% [markdown]
# ## Show some Dataset Example

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(train_x))
    print("\n--------")
    print(train_x[rand_int][:1500])
    print()
    print(train_y[rand_int])
# Out:
# --------
# Von Helen Pow. VERÖFFENTLICHT:. 11: 09 EST, 23. Juli 2013. |. UPDATED:. 12: 20 EST, 23. Juli 2013. Tragisch: Paul Franklin Dart, rechts im Bild mit Freunden, versuchte den Schützen zu beruhigen, als er in den Kopf geschossen wurde. Ein verheirateter Armeeveteran wurde vor den Augen seiner Frau und seines Stiefsohnes während einer jährlichen Raftingtour mit der Familie am Samstag erschossen, nachdem ein Verwandter am Flussufer uriniert hatte, was den Grundbesitzer in Rage brachte. James Robert Crocker, 59, konfrontierte die Gruppe von Familie und Freunden mit einer 9 mm Handfeuerwaffe, nachdem sie eine kurze Pause an einer Kiesbar in Meramex eingelegt hatten, und einer der Nachtschwärmer ging in den Wald, um sich zu befreien. Nach einem kurzen Streit darüber, ob die Kiesbar privates oder öffentliches Eigentum war, schoss Crocker Paul Franklin Dart, 48, aus nur wenigen Metern Entfernung in den Kopf, während seine Frau Loretta und ihr Sohn Josh Kling, 24, entsetzt zuschauten. Dart, ein gewerkschaftlicher Tischler aus Robertsville, starb in einem Krankenwagen auf dem Weg ins Krankenhaus weniger als fünf Stunden, nachdem er die jährliche Reise angetreten hatte, die die Gruppe in den letzten fünf Jahren jeden Sommer organisiert hatte. "Ich sah zu, wie er ins Gesicht geschossen wurde und hinfiel", schluchzte Loretta Dart am Montag in einem Telefoninterview mit The St. Louis Dispatch. "Ich sah zu, wie mein Mann verblutete. Er war ein wunderbarer Mann. Das hat er nicht verdient ". Cro
#
# James Robert Crocker, 59, schoss Paul Franklin Dart, 48, am Samstag gegen 14.00 Uhr aus nur wenigen Metern Entfernung in den Kopf. Dart und seine Familie und Freunde hielten an einer Kiesbar am Boden von Crockers Grundstück für eine Pause während einer jährlichen schwimmenden Reise an. Crocker näherte sich mit einer Handfeuerwaffe und forderte sie auf, sein Land zu verlassen, aber die Gruppe weigerte sich und behauptete, es sei öffentliches Eigentum. Der Streit eskalierte und Crocker erschoss Dart, als der unbewaffnete Mann versuchte, ihn zu beruhigen.
#
# --------
# Er hat sich bereits Wolverines Krallen und Magnetos Schwerkraft widersetzenden Stiefeln hingegeben. Jetzt hat der britische Erfinder Colin Furze seinen jüngsten Versuch enthüllt, sich X-Men-Superkräfte zu verschaffen - mit einem Flammenwerfer am Handgelenk. Er kann bis zu 12 Meter lange Flammen erzeugen. Scrollen Sie für ein Video nach unten. Colin Furze demonstriert den am Handgelenk montierten Flammenwerfer. Das System ist in einem Rucksack mit Bedienelementen an jedem Handgelenk montiert. Propangasflaschen, die für eine Blasbrenner verwendet werden, liefern das Gas. Es wird verwendet, um ein Reservoir zu füllen, das es ermöglicht, eine viel größere Flamme zu erzeugen. Um das System zu bedienen, betätigt der Träger zunächst sein Handgelenk, um eine Pilotflamme zu entzünden, dann sein anderes Handgelenk, um das Gas anzuzünden. Colin Furze, ein 34-jähriger Klempner aus Lincolnshire, sagte, der Feuerwerfer sei eine natürliche Wahl für diesen dritten Versuch gewesen, sich X-Men-Befugnisse zu geben. "Ich musste nur Pyro machen, weil ich anscheinend eine Verbindung zum Feuer habe", sagte er. "Nachdem sie mit einigen Special-Effects-Jungs an einem TV-Piloten gearbeitet hatten, zeigten sie mir eine großartige Möglichkeit, ein gasbetriebenes Gerät zu entwickeln, das sicher und kontrollierbar war. "Das Ergebnis ist ein echter Superheld - so nah, wie ich nur kommen konnte". Um das System zu bedienen, betätigt der Träger zunächst sein Handgelenk, um eine Pilotflamme zu entzünden, dann
#
# Colin Furze, 34, aus Lincolnshire, hat bereits Wolverines Krallen und Magnetos Schwerkraft trotzende Stiefel erschaffen. Verwendet Propan aus einer Pusteblume. Am Handgelenk montierte Steuerelemente erlauben es, es bis zu 12 Fuß abzufeuern.
#
# --------
# Labour unternimmt eine konzertierte Anstrengung, Nick Clegg bei den Wahlen im nächsten Jahr zu enthaupten, um die Chancen auf eine zweite liberal-konservative Koalition zunichte zu machen. Die Partei glaubt, den Posten des Vizepremiers einnehmen zu können, nachdem ihm eine aktuelle Umfrage nur einen knappen Vorsprung von drei Punkten verschafft hatte. Tom Watson, Ed Miliband 's ehemaliger Wahlkoordinator, sagte: "Dieser Sitz ist für Labour gewinnbar. Labour unternimmt eine konzertierte Anstrengung, Nick Clegg
ichen Erleichterung. Als er mit einer Handvoll spärlich bekleideter Mädchen tanzte, konnte seine Co-Moderatorin Davina McCall nicht anders, als mitzumachen. Zum Entsetzen von Dermot begann die 44-Jährige, ihre Schritte zum Party Rock von LMFAO zu zeigen. Sofort sprang er auf und brüllte: "Wow, wow". Sie hat Sex-Appeal! Die Moderatorin hat, sehr zum Entsetzen Dermots, einen Tohuwabohu: "War das zu viel?" Er entgegnete: "Es ist, als würde meine Schwester sich umziehen. Das stimmt nicht ". Später, als David Walliams vorgestellt wurde, um über sein Schwimmen in der Themse für Sport Relief im letzten Jahr zu sprechen, fragte er sie: "Was haben Sie sich dabei gedacht?" Sie gab zu: "Meine Kinder hätten es geahnt!" Thema: Der Star trug ein komplett rotes Ensemble mit Federschmuck und roten Jeans. Unterbrechen Sie mich nicht! Dermot genoss seine Tanznummer mit den atemberaubenden Sport Relief Mädchen. Fans machten sich auf Twitter über sie lustig. Tanzkünste, mit einem Scherz: "Ich glaube, i
#
# £50.447.197 kamen bisher für Sport Relief zusammen.

# %% [markdown]
# ## Define Pytorch Dataset

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, articles, highlights):
        self.x = articles
        self.y = highlights
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index]), max_length=512, return_tensors="pt", pad_to_max_length=True)
        y = tokenizer.encode(self.transfrom(self.y[index]), max_length=150, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1), y.view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
train_ds, val_ds = MyDataset(train_x, train_y), MyDataset(val_x, val_y)

# %%
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE)
# test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE)

# %% [markdown]
# ## Define Step function

# %%
pad_token_id = tokenizer.pad_token_id
def step(inputs_ids, attention_mask, y):
    y_ids = y[:, :-1].contiguous()
    lm_labels = y[:, 1:].clone()
    lm_labels[y[:, 1:] == pad_token_id] = -100
    output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
    return output[0] # loss

# %% [markdown]
# ## Train

# %%
EPOCHS = 1
log_interval = 200
train_loss = []
val_loss = []
for epoch in range(EPOCHS):
    model.train() 
    start_time = time.time()
    for i, (inputs_ids, attention_mask, y) in enumerate(train_loader):
        inputs_ids = inputs_ids.to(device)
        attention_mask = attention_mask.to(device)
        y = y.to(device)
        
        
        optimizer.zero_grad()
        loss = step(inputs_ids, attention_mask, y)
        train_loss.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
            
        if (i + 1) % log_interval == 0:
            with torch.no_grad():
                x, x_mask, y = next(iter(val_loader))
                x = x.to(device)
                x_mask = x_mask.to(device)
                y = y.to(device)
                
                v_loss = step(x, x_mask, y)
                v_loss = v_loss.item()
                
                
                elapsed = time.time() - start_time
                print('| epoch {:3d} | [{:5d}/{:5d}] | '
                  'ms/batch {:5.2f} | '
                  'loss {:5.2f} | val loss {:5.2f}'.format(
                    epoch, i, len(train_loader),
                    elapsed * 1000 / log_interval,
                    loss.item(), v_loss))
                start_time = time.time()
                val_loss.append(v_loss)
# Out:
# | epoch   0 | [  199/ 6053] | ms/batch 412.28 | loss  3.16 | val loss  3.19
# | epoch   0 | [  399/ 6053] | ms/batch 409.88 | loss  2.98 | val loss  3.05
# | epoch   0 | [  599/ 6053] | ms/batch 409.04 | loss  3.07 | val loss  2.99
# | epoch   0 | [  799/ 6053] | ms/batch 411.56 | loss  3.05 | val loss  2.92
# | epoch   0 | [  999/ 6053] | ms/batch 409.91 | loss  2.45 | val loss  2.89
# | epoch   0 | [ 1199/ 6053] | ms/batch 412.41 | loss  2.58 | val loss  2.87
# | epoch   0 | [ 1399/ 6053] | ms/batch 416.77 | loss  2.53 | val loss  2.84
# | epoch   0 | [ 1599/ 6053] | ms/batch 419.44 | loss  2.44 | val loss  2.83
# | epoch   0 | [ 1799/ 6053] | ms/batch 415.85 | loss  2.69 | val loss  2.78
# | epoch   0 | [ 1999/ 6053] | ms/batch 415.14 | loss  2.66 | val loss  2.79
# | epoch   0 | [ 2199/ 6053] | ms/batch 415.83 | loss  2.87 | val loss  2.77
# | epoch   0 | [ 2399/ 6053] | ms/batch 408.96 | loss  2.88 | val loss  2.76
# | epoch   0 | [ 2599/ 6053] | ms/batch 413.58 | loss  2.56 | val loss  2.77
# | epoch   0 | [ 2799/ 6053] | ms/batch 411.86 | loss  2.76 | val loss  2.76
# | epoch   0 | [ 2999/ 6053] | ms/batch 415.74 | loss  2.47 | val loss  2.77
# | epoch   0 | [ 3199/ 6053] | ms/batch 406.31 | loss  2.35 | val loss  2.73
# | epoch   0 | [ 3399/ 6053] | ms/batch 408.99 | loss  2.75 | val loss  2.74
# | epoch   0 | [ 3599/ 6053] | ms/batch 411.86 | loss  2.57 | val loss  2.66
# | epoch   0 | [ 3799/ 6053] | ms/batch 407.71 | loss  2.42 | val loss  2.70
# | epoch   0 | [ 3999/ 6053] | ms/batch 410.69 | loss  2.72 | val loss  2.69
# | epoch   0 | [ 4199/ 6053] | ms/batch 410.94 | loss  2.60 | val loss  2.70
# | epoch   0 | [ 4399/ 6053] | ms/batch 417.70 | loss  2.97 | val loss  2.70
# | epoch   0 | [ 4599/ 6053] | ms/batch 412.70 | loss  2.38 | val loss  2.70
# | epoch   0 | [ 4799/ 6053] | ms/batch 416.54 | loss  2.73 | val loss  2.69
# | epoch   0 | [ 4999/ 6053] | ms/batch 417.04 | loss  2.50 | val loss  2.70
# | epoch   0 | [ 5199/ 6053] | ms/batch 413.42 | loss  2.55 | val loss  2.65
# | epoch   0 | [ 5399/ 6053] | ms/batch 411.87 | loss  2.64 | val loss  2.61
# | epoch   0 | [ 5599/ 6053] | ms/batch 410.76 | loss  2.55 | val loss  2.67
# | epoch   0 | [ 5799/ 6053] | ms/batch 410.85 | loss  2.37 | val loss  2.67
# | epoch   0 | [ 5999/ 6053] | ms/batch 410.30 | loss  2.28 | val loss  2.67

# %% [markdown]
# ## Evaluate

# %%
from rouge_score import rouge_scorer
from rouge_score import scoring

class RougeScore:
    '''
    mostly from https://github.com/google-research/text-to-text-transfer-transformer/blob/master/t5/evaluation/metrics.py 
    '''
    
    def __init__(self, score_keys=None)-> None:
        super().__init__()
        if score_keys is None:  
            self.score_keys = ["rouge1", "rouge2", "rougeLsum"]
        
        self.scorer = rouge_scorer.RougeScorer(self.score_keys)
        self.aggregator = scoring.BootstrapAggregator()
        
        
    @staticmethod
    def prepare_summary(summary):
            # Make sure the summary is not bytes-type
            # Add newlines between sentences so that rougeLsum is computed correctly.
            summary = summary.replace(" . ", " .\n")
            return summary
    
    def __call__(self, target, prediction):
        """Computes rouge score.''
        Args:
        targets: string
        predictions: string
        """

        target = self.prepare_summary(target)
        prediction = self.prepare_summary(prediction)
        
        self.aggregator.add_scores(self.scorer.score(target=target, prediction=prediction))

        return 
    
    def reset_states(self):
        self.rouge_list = []

    def result(self):
        result = self.aggregator.aggregate()
        
        for key in self.score_keys:
            score_text = "%s = %.2f, 95%% confidence [%.2f, %.2f]"%(
                key,
                result[key].mid.fmeasure*100,
                result[key].low.fmeasure*100,
                result[key].high.fmeasure*100
            )
            print(score_text)
        
        return {key: result[key].mid.fmeasure*100 for key in self.score_keys}

# %%
rouge_score = RougeScore()
predictions = []
for i, (input_ids, attention_mask, y) in enumerate(val_loader):
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)
    y = y.to(device)
        
    summaries = model.generate(input_ids=input_ids, attention_mask=attention_mask)
    pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summaries]
    real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in y]
    for pred_sent, real_sent in zip(pred, real):
        rouge_score(pred_sent, real_sent)
        predictions.append(str("pred sentence: " + pred_sent + "\n\n real sentence: " + real_sent))
    if i > 40:
        break
    
rouge_score.result()
# Out:
# rouge1 = 28.10, 95% confidence [27.34, 28.86]
# rouge2 = 9.60, 95% confidence [9.00, 10.18]
# rougeLsum = 17.42, 95% confidence [16.89, 18.02]
# {'rouge1': 28.10321209302542,
#  'rouge2': 9.599739806351863,
#  'rougeLsum': 17.41800656285659}

# %%
for pred in predictions[:10]:
    print("------")
    print(pred)
    print("------")
# Out:
# ------
# pred sentence: katholische diözese fargo in north dakota hat potenziell hunderte gemeindemitglieder in fargo, grand forks und jamestown den hepatitis-a-virus ausgesetzt. bischof john folda, leiterin des staatlichen immunisierungsprogramms, sagt, das risiko sei gering, aber die beamten halten es für wichtig, die menschen auf die mögliche exposition aufmerksam zu machen,
# ------
# ------
# pred sentence: david cameron hat die £20,99 schuhe vom high street store aldo bekommen. er trägt die gleiche schuhe, hat ehefrau samantha zugestimmt. der rückzugsort wurde mit indonesischen thema gestylt. buddha-statuen, eine eigene yoga-halle, ein swimmingpool und ein chill-out-bereich mit hängematten. es ist eine vorliebe für urlaubsbekleidung, der hat letztes jahr in portugal hat, aber hat £20 schuhe von samefarbenen hemd und die letzten sommer hat in seinen schuhe und hat den gleichen shorts in teguise im bauernhaus erschossen.
#
#  real sentence: premierminister und seine familie genießen eine osterpause auf lanzarote. sportlich trug er dieselben beigen £20,99 loafers wie letztes jahr in portugal. pm saß und trank in einem strandcafé auf der spanischen insel.
# ------
# ------
# pred sentence: der ehemalige spieler der los angeles lakers sagt, dass er hiv sterben würde, aber fortschritte bei den medikamenten hätten johnson - und millionen anderen - geholfen zu überleben. "wir müssen die menschen testen, denn das ist das wichtigste", sagt er. elizabeth glaser versicherte, dass die nba-star begann eine behandlung bei dr. michael mell
#
#  real sentence: nba-star fordert tests für schwarze und hispanische gemeinschaften der ehemalige spieler der lakers widmete sein leben der sensibilisierung für krankheiten.
# ------
# ------
# pred sentence: passagier chris downes, 46, war zu diesem zeitpunkt mit seinem handy aufgezeichnet, und der ansager war deutlich zu hören, dass es nun eine untersuchung des vorfalls an Bord der fähre von wolverhampton nach shrewsbury hat. wölfe-fan jack, 14, auf dem heimweg nach bayston hill in shropshire war. london midland teilte jedoch mit
#
#  real sentence: der passagier chris downes, 46, zeichnete zu diesem zeitpunkt mit seinem handy auf. ansager ist deutlich zu hören: "telford central - bitte beachten sie taschendiebe und zigeuner" london midland teilte mit, dass es nun eine untersuchung des vorfalls einleitet.
# ------
# ------
# pred sentence: berahinos jüngerer ausbruch in dieser woche kommt, nachdem er sich in west brom einlebt hat. er hat für die baggies unterschrieben, dass er gut genug genug ist, um in der premier league den senf zu regeln. fletcher hat eines tages kapitän von albion scheiterte. der 21-jährige stürmer hat sich in der schatten angedeutet, um es stimme in der umkleidekabine, als er im jahresvertrag hat, aber hat geraten, die er in manchester united er ein vorbild sein soll, um die spieler zu konzentriert. beratten, dass die schottische verein in west ham zu sein.
#
#  real sentence: tony pulis glaubt, dass saido berahino zu darren fletcher aufschauen sollte. pulis beharrt darauf, dass berahino auf den falschen rat gehört wurde. berahino sagte, er wolle sich anfang der woche größeren dingen zuwenden. lesen: berahino für £20 millionen verfügbar, nachdem liverpool den klub verärgert hatte. hier klicken für alle aktuellen west brom news.
# ------
# ------
# pred sentence: neil campbell, senior transport safety investigator, sagt, dass es sich lohnt, die sicherheit der reisenden zu verbessern. der flug mh370 hat den ersten blick hinter einem unmarkierten tür geholfen. naturwissenschaftliche sicherheitsbüros legen sich an den blackboxen der malaysia airlines gebracht, wenn sie vom grund des südlichen indischen ozeans geborgen werden. der ort sagt,
#
#  real sentence: blackbox-daten von flug 370 könnten in einem labor in australien analysiert werden. selbst wenn der flugdatenschreiber beschädigt ist, sind informationen abrufbar. etwa 2.000 parameter werden entschlüsselt, wie flughöhe, motorleistung und kabinendruck. die daten werden verwendet, um eine visuelle darstellung zu erstellen, die der öffentlichkeit hilft, einen unfall zu verstehen.
# ------

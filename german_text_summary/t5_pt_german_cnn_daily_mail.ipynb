# %% [markdown]
# # German Text Summary with the tranlated CNN Daily Mail Dataset
# and T5 from Huggingface Pytorch

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
import torch
import re
import time

# %%
BATCH_SIZE = 16

SHUFFEL_SIZE = 1024

# device = "cpu"
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate = 3e-5

first_run = False

# %%
print(device)
# Out:
# cuda:0

# %%
def write_data(iter_dataset, name, path="data/"):
    
    articles_file = Path(path + name + "/article").open("w")
    highlights_file = Path(path + name + "/highlights").open("w")

    for item in iter_dataset:
        articles_file.write(item["article"].decode("utf-8") + "\n")
        articles_file.flush()
        highlights_file.write(item["highlights"].decode("utf-8").replace("\n", " ") + "\n")
        highlights_file.flush()

if first_run:
    cnn_dailymail = tfds.load(name="cnn_dailymail")
    
    train_tfds = cnn_dailymail['train']
    test_tfds = cnn_dailymail['test']
    val_tfds = cnn_dailymail['validation']
    
    train_ds_iter = tfds.as_numpy(train_tfds)
    val_ds_iter = tfds.as_numpy(val_tfds)
    test_ds_iter = tfds.as_numpy(test_tfds)
    
    write_data(train_ds_iter, "train")
    write_data(test_ds_iter, "test")
    write_data(val_ds_iter, "val")

# %% [markdown]
# ## Define Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small').to(device)

task_specific_params = model.config.task_specific_params
if task_specific_params is not None:
    model.config.update(task_specific_params.get("summarization", {}))
    

optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.0001)

# %% [markdown]
# ## Read the tranlated German Dataset

# %%
name = "train"

article_path = "../data/%s/articles_german" % name
highlights_path = "../data/%s/highlights_german" % name

articles = [x.rstrip() for x in open(article_path).readlines()]
highlights = [x.rstrip() for x in open(highlights_path).readlines()]

len_articles = len(articles)

def get_dict_data(list_input):
    ret_dict = {}
    for input_item in list_input:
        data_point = input_item.split(";")
        data_id = data_point[0]
        data = ""
        for item in data_point[1:]:
            data += item
        ret_dict[int(data_id)] = data.strip()
    return ret_dict
    
articles = get_dict_data(articles)
highlights = get_dict_data(highlights)

# %%
cleaned_articles = []
cleaned_highlights = []

for i in range(len_articles):
    if i in articles.keys() and i in highlights.keys():
        cleaned_articles.append(articles[i])
        cleaned_highlights.append(highlights[i])
#     else:
#         print(i)

# %%
assert len(cleaned_articles) == len(cleaned_highlights)

val_size = int(len(cleaned_articles)*0.1)
train_x = cleaned_articles[val_size:] 
train_y = cleaned_highlights[val_size:] 
val_x = cleaned_articles[:val_size] 
val_y = cleaned_highlights[:val_size]

# %% [markdown]
# ## Show some Dataset Example

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(train_x))
    print("\n--------")
    print(train_x[rand_int][:1500])
    print()
    print(train_y[rand_int])
# Out:
# --------
# Von Wills Robinson. Eine junge Chinesin steht im Mittelpunkt einer Online-Hasskampagne in China, nachdem sie scherzhaft Bilder von sich gepostet hat, wie sie eine Katze kocht und aus den Überresten Suppe kocht. Li Jinbang lud die verstörenden Bilder, wie sie das Haustier ihres Freundes tötete, auf Weibo hoch, die chinesische Version von Facebook. Doch schnell bekam sie Hassmails und Drohungen von anderen Nutzern, und bevor sie den Post löschen konnte, gingen die Bilder viral. Grausam: Die Frau, die in der chinesischen Provinz Guangdong lebt, postete die Fotos der Katze, die in einem Käfig gefangen war, bevor sie sie grausam kochte und aus den Teilen eine Suppe zubereitete. Anschließend postete sie die Bilder und erklärte, wie sie das Tier gekocht hatte, bevor sie ihm das Fell auszog und es in Stücke schnitt. Die Bilder zeigten die wehrlose Katze, die in einem Käfig kauerte, bevor sie aufgehängt und geschlachtet wurde. Es zeigte auch die junge Frau mit Pelzmantel und Brille, während sie die Suppe zubereitete. Nachdem sie mit E-Mails bombardiert worden war, einschließlich Hassbotschaften, versuchte sie sich zu verteidigen, indem sie sagte, dass die Katze, die auf den Bildern vorher vollkommen gesund aussah, bei einem Autounfall schwer verletzt worden war und sie es war. Sie sagte: "Es war eine vollkommen legale Tötung, und ich habe die Katze getötet und gegessen, ohne etwas Illegales zu tun". Einige Nutzer wiesen darauf hin, dass es keine Überraschung sei, dass sie aus dem südo
#
# Li Jinbang, aus der Provinz Guandong, lud Bilder in den sozialen Medien hoch. Erläuterte, wie sie die Katze kochte, bevor sie ihr Fell auszog und in Stücke schnitt. Wurde auf Weibo, Chinas Version von Facebook, mit Hassmails bombardiert. Versuchte sich zu verteidigen und sagte, Katze sei bei einem Autounfall schwer verletzt worden. Es wird geschätzt, dass etwa 4Millionen Katzen im Land jedes Jahr gefressen werden.
#
# --------
# Der Oberste Gerichtshof gab heute Morgen religiösen Konservativen einen Sieg und entschied zugunsten der christlichen Bastelladen Hobby Lobby in ihrer Klage gegen die Bundesregierung. In einem knappen 5-4-Urteil entschied das Gericht, dass "eng geführte" Unternehmen mit religiösen Verbindungen wie Hobby Lobby Anspruch auf Befreiung von einer Bestimmung in Obamacare haben, die private Unternehmen verpflichtet, ihren Mitarbeitern Gesundheitspläne zur Verfügung zu stellen, die Verhütung abdecken. Eine "eng gehaltene" Aktiengesellschaft ist eine, in der mehr als 50 Prozent der Unternehmensanteile von fünf oder weniger Personen gehalten werden. SCROLL DOWN FOR VIDEO. Demonstranten auf beiden Seiten des Themas Geburtenkontrolle Leah Hughes, links, und Students for Life Präsidentin Kristin Hawkins, rechts, skandieren heute Morgen vor dem Obersten Gerichtshof für ihre Seite. Hawkins und andere Aktivisten, die sich für das Leben einsetzen, strömten heute auf die Stufen des Obersten Gerichtshofs, um ihre Unterstützung für Hobby Lobby zu zeigen. Im Mittelpunkt des Falles stand die Frage, ob Obamacare mit seinem Verhütungsmandat gegen das Gesetz zur Wiederherstellung der Religionsfreiheit von 1993 verstößt, das besagt, dass die Regierung "die Ausübung der Religion einer Person nicht wesentlich belasten darf", es sei denn, sie hat einen zwingenden Grund dafür. Hobby-Lobby und ähnliche Gruppen argumentierten, dass die Bereitstellung bestimmter Verhütungsmittel wie der Pille danach einer Ab
#
# Das christliche Bastelgeschäft Hobby Lobby hat die Regierung wegen Obamacare 's Verhütungsmandat verklagt. Heute entschied der Oberste Gerichtshof, dass Hobby Lobby und andere "eng verbundene" Unternehmen aufgrund ihrer religiösen Überzeugungen eine Befreiung vom Mandat beantragen können. Republikaner feiern die Entscheidung als Sieg für die religiöse Freiheit, und Demokraten verurteilen sie als Rückschlag für die Gesundheit von Frauen.
#
# --------
# Von Damien Gayle. VERÖFFENTLICHT:. 09: 48 EST, 19. September 2013. |. UPDATED:. 12: 00 EST, 19. September 2013. Tragisch: Drake Smith Jr., vier, der starb, nachdem er von der Naegleria-Geflügelmikrobe infiziert wurde, während er auf einer Wasserrutsche in einem Haus in Louisiana spielte. Eine seltene hirnfressende Amöbe, die einen Vierjährigen in Louisiana tötete, könnte infolge des Hurrikans Katrina auf dem Vormarsch sein, haben Experten gesagt. Drake Smith Jr. aus Mississippi wurde vermutlich mit der Naegleria-Geflügelmikrobe infiziert, als er in einem Haus in der Gemeinde St. Bernard auf einem Slip 'N' Slide-Spielzeug spielte. Gewebetests des Centers for Disease Control ergaben später, dass er an einer Form von Enzephalitis starb, nachdem die Amöbe durch die Nase in seinen Körper eingedrungen war und sein Gehirn angegriffen hatte. Experten zufolge breitet sich die Amöbe N. fowleri in der Wasserversorgung des Gebiets aus, weil die Population nach Hurrikan Katrina drastisch zurückgegangen ist. Die Gemeinde St. Bernard südwestlich von New Orleans war eine der am schlimmsten von dem Hurrikan betroffenen Gegenden, der vor acht Jahren die US-Golfküste verwüstete. Jake Causey, Chefingenieur für das Gesundheitswesen und die Krankenhäuser Louisianas, sagte CNN: "Eine der Sorgen ist, dass es nach Katrina ein so drastischer Bevölkerungsrückgang war. Einfach mal in die Röhre gucken und auch mal einen Tropfen abbekommen. "Je schneller es [das Wasser] verbraucht ist, desto besser kann d
#
# Drake Smith starb, nachdem er sich mit der Naegleria Fowleri-Mikrobe infiziert hatte. Amöben sind auf dem Vormarsch, seit Hurrikan Katrina zur Entvölkerung der Gegend führte. Weniger Menschen bedeuten, dass mehr Trinkwasser stagniert und sich ausbreiten kann. Experten sagen, dass Wasser sicher zu trinken ist, aber warnen davor, sich damit die Nase zu rümpfen.
#
# --------
# Von. Luke Salkeld. VERÖFFENTLICHT:. 14: 12 EST, 14. September 2012. |. UPDATED:. 14: 12 EST, 14. September 2012. Eine naturwissenschaftliche Fakultät der Universität wird von der Polizei untersucht, nachdem ein Doktorand tödlichen Chemikalien ausgesetzt war. Der 25-Jährige, der die Universität Southampton besucht, erkrankte vor drei Wochen und wurde später mit Thallium und Arsen im Körper gefunden. Wie die Chemikalien in den Körper der Studentin gelangten, ist noch nicht bekannt. Im Uni-Labor enttarnt: Das Chemielabor der Universität Southampton wird von der Polizei durchsucht, nachdem ein 25-jähriger Student erkrankte, nachdem er tödlichen Chemikalien ausgesetzt war. Der Student, der nicht namentlich genannt wurde, wird in einer toxikologischen Spezialeinheit eines Krankenhauses in Cardiff, Wales, behandelt. "Es steht bereits fest, dass es sich nicht um ein Leck oder eine Emission aus der Luft aus den Gebäuden handelt und nicht übertragbar ist und möglicherweise überhaupt nicht mit der Universität in Verbindung steht", sagte ein Polizeisprecher. "Das wird als Einzelfall behandelt". Mitarbeiter und Studenten der Universität und andere Angehörige der Öffentlichkeit seien nicht gefährdet. Mitarbeiter und Studenten der Universität sollen nun die Möglichkeit erhalten, freiwillig zu überprüfen, ob auch sie gefährdet sind. Ermittlungen: Arsen und Thallium wurden im Körper der Studentin gefunden, und es ist noch nicht bekannt, wie die tödlichen Chemikalien in den Körper gelangten. K
#
# Die naturwissenschaftliche Fakultät der Universität Southampton wird untersucht, nachdem ein Student (25) tödlichen Chemikalien ausgesetzt war. Arsen und Thallium wurden im Körper des Studenten gefunden. Die Universität schloss einige Chemielabore, während Polizei und Gesundheitsbehörde ermitteln.
#
# --------
# Nun, da sich die Vereinigten Staaten formell mit dem ehemaligen Al-Kaida-Verbündeten treffen werden, werden harte Fragen über die Taliban in Afghanistan aufgeworfen. Warum engagiert die US-Regierung die islamisch-fundamentalistische Hardliner-Gruppe, ein Regime, das einst Osama bin Laden und sein Terrornetzwerk beherbergte und schließlich nach den Anschlägen vom 11. September 2001 durch eine US-Invasion aus Afghanistan vertrieben wurde? Derart harte Fragen wurden kurz nach der Ankündigung der bevorstehenden Gespräche der US-Taliban während einer Pressekonferenz am Dienstag durch die Sprecherin des US-Außenministeriums, Jen Psaki, aufgeworfen. Sie wurde klipp und klar gefragt: "Sind die Taliban in den Augen der USA eine terroristische Gruppe?" Darauf Psaki: "Nun, ich bin mir nicht sicher, wie sie in diesem Moment definiert werden". Fairerweise muss man sagen, dass Psaki die US-Friedensgespräche mit den Taliban - die der afghanische Präsident Hamid Karsai ablehnt - als einen ersten Schritt hin zu einem langen Heilungsprozess im kriegsgeschüttelten Afghanistan und zur Schaffung einer "Aussöhnung" innerhalb des Landes bezeichnete. In ihrem Büro in Doha nehmen die Taliban Änderungen vor. In der Zwischenzeit müssten noch viele Details über die Taliban ausgearbeitet werden, sagte Psaki. Am Mittwoch wies Psaki Berichte zurück, wonach das erste Treffen für Donnerstag geplant sei, und sagte, ein Termin stehe noch nicht fest. "Das Wichtige dabei ist, dass wir schon seit langem sagen, da
#
# Friedensgespräche zwischen den USA und den Taliban sind "ein erster Schritt im Prozess der Versöhnung". Details über die Abkehr der Taliban von al-Qaida müssen allerdings noch ausgearbeitet werden. "Na ja, ich weiß nicht, wie sie in diesem Moment definiert werden", antwortet sie.

# %% [markdown]
# ## Define Pytorch Dataset

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, articles, highlights):
        self.x = articles
        self.y = highlights
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index]), max_length=512, return_tensors="pt", pad_to_max_length=True)
        y = tokenizer.encode(self.transfrom(self.y[index]), max_length=150, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1), y.view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
train_ds, val_ds = MyDataset(articles, highlights), MyDataset(articles, highlights)

# %%
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE)
# test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE)

# %% [markdown]
# ## Define Step function

# %%
pad_token_id = tokenizer.pad_token_id
def step(inputs_ids, attention_mask, y):
    y_ids = y[:, :-1].contiguous()
    lm_labels = y[:, 1:].clone()
    lm_labels[y[:, 1:] == pad_token_id] = -100
    output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
    return output[0] # loss

# %% [markdown]
# ## Train

# %%
EPOCHS = 1
log_interval = 200
train_loss = []
val_loss = []
for epoch in range(EPOCHS):
    model.train() 
    start_time = time.time()
    for i, (inputs_ids, attention_mask, y) in enumerate(train_loader):
        inputs_ids = inputs_ids.to(device)
        attention_mask = attention_mask.to(device)
        y = y.to(device)
        
        
        optimizer.zero_grad()
        loss = step(inputs_ids, attention_mask, y)
        train_loss.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
            
        if (i + 1) % log_interval == 0:
            with torch.no_grad():
                x, x_mask, y = next(iter(val_loader))
                x = x.to(device)
                x_mask = x_mask.to(device)
                y = y.to(device)
                
                v_loss = step(x, x_mask, y)
                v_loss = v_loss.item()
                
                
                elapsed = time.time() - start_time
                print('| epoch {:3d} | [{:5d}/{:5d}] | '
                  'ms/batch {:5.2f} | '
                  'loss {:5.2f} | val loss {:5.2f}'.format(
                    epoch, i, len(train_loader),
                    elapsed * 1000 / log_interval,
                    loss.item(), v_loss))
                start_time = time.time()
                val_loss.append(v_loss)

# %% [markdown]
# ## Evaluate

# %%
from rouge_score import rouge_scorer
from rouge_score import scoring

class RougeScore:
    '''
    mostly from https://github.com/google-research/text-to-text-transfer-transformer/blob/master/t5/evaluation/metrics.py 
    '''
    
    def __init__(self, score_keys=None)-> None:
        super().__init__()
        if score_keys is None:  
            self.score_keys = ["rouge1", "rouge2", "rougeLsum"]
        
        self.scorer = rouge_scorer.RougeScorer(self.score_keys)
        self.aggregator = scoring.BootstrapAggregator()
        
        
    @staticmethod
    def prepare_summary(summary):
            # Make sure the summary is not bytes-type
            # Add newlines between sentences so that rougeLsum is computed correctly.
            summary = summary.replace(" . ", " .\n")
            return summary
    
    def __call__(self, target, prediction):
        """Computes rouge score.''
        Args:
        targets: string
        predictions: string
        """

        target = self.prepare_summary(target)
        prediction = self.prepare_summary(prediction)
        
        self.aggregator.add_scores(self.scorer.score(target=target, prediction=prediction))

        return 
    
    def reset_states(self):
        self.rouge_list = []

    def result(self):
        result = self.aggregator.aggregate()
        
        for key in self.score_keys:
            score_text = "%s = %.2f, 95%% confidence [%.2f, %.2f]"%(
                key,
                result[key].mid.fmeasure*100,
                result[key].low.fmeasure*100,
                result[key].high.fmeasure*100
            )
            print(score_text)
        
        return {key: result[key].mid.fmeasure*100 for key in self.score_keys}

# %%
rouge_score = RougeScore()
predictions = []
for i, (input_ids, attention_mask, y) in enumerate(val_loader):
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)
    y = y.to(device)
        
    summaries = model.generate(input_ids=input_ids, attention_mask=attention_mask)
    pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summaries]
    real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in y]
    for pred_sent, real_sent in zip(pred, real):
        rouge_score(pred_sent, real_sent)
        predictions.append(str("pred sentence: " + pred_sent + "\n\n real sentence: " + real_sent))
    if i > 40:
        break
    
rouge_score.result()

# %%
for pred in predictions[:10]:
    print("------")
    print(pred)
    print("------")

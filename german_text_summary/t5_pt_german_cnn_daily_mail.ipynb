# %% [markdown]
# # German Text Summary with the tranlated CNN Daily Mail Dataset
# and T5 from Huggingface Pytorch

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
import torch
import re
import time

# %%
BATCH_SIZE = 16

SHUFFEL_SIZE = 1024

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate = 3e-5

EPOCHS = 5

log_interval = 200

# %%
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Define Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small').to(device)

task_specific_params = model.config.task_specific_params
if task_specific_params is not None:
    model.config.update(task_specific_params.get("summarization", {}))
    

optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.0001)

# %% [markdown]
# ## Read the tranlated German Dataset

# %%
def get_dict_data(list_input):
    ret_dict = {}
    for input_item in list_input:
        data_point = input_item.split(";")
        data_id = data_point[0]
        data = ""
        for item in data_point[1:]:
            data += item
        ret_dict[int(data_id)] = data.strip()
    return ret_dict
    
def get_translated_ds(name):
    article_path = "../data/%s/articles_german" % name
    highlights_path = "../data/%s/highlights_german" % name

    articles = [x.rstrip() for x in open(article_path).readlines()]
    highlights = [x.rstrip() for x in open(highlights_path).readlines()]

    len_articles = len(articles)
    
    articles = get_dict_data(articles)
    highlights = get_dict_data(highlights)
    
    cleaned_articles = []
    cleaned_highlights = []

    for i in range(len_articles):
        if i in articles.keys() and i in highlights.keys():
            cleaned_articles.append(articles[i])
            cleaned_highlights.append(highlights[i])
        else:
            is_in_art = i in articles.keys()
            text = "is not in "
            if not is_in_art:
                text += "articles"
            else:
                text += "highlights"
            
            print(name, i, text)
            
    assert len(cleaned_articles) == len(cleaned_highlights)
    return cleaned_articles, cleaned_highlights

# %%
train_x, train_y = get_translated_ds("train")
test_x, test_y = get_translated_ds("test")
val_x, val_y = get_translated_ds("val")
# Out:
# train 287113 is not in articles
# train 287114 is not in articles
# train 287115 is not in articles
# train 287116 is not in articles
# train 287117 is not in articles
# train 287118 is not in articles
# train 287119 is not in articles
# train 287120 is not in articles
# train 287121 is not in articles
# train 287122 is not in articles
# train 287123 is not in articles
# train 287124 is not in articles
# train 287125 is not in articles
# train 287126 is not in articles
# test 11490 is not in highlights
# test 11491 is not in highlights
# test 11492 is not in highlights
# test 11493 is not in highlights
# test 11494 is not in highlights
# test 11495 is not in highlights
# test 11496 is not in highlights
# test 11497 is not in highlights
# test 11498 is not in highlights
# test 11499 is not in articles
# val 13368 is not in articles

# %% [markdown]
# ## Show some Dataset Example

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(train_x))
    print("\n--------")
    print(train_x[rand_int][:1500])
    print()
    print(train_y[rand_int])
# Out:
# --------
# Eine deutsche Oper wurde nach einem Sturm der Kritik abgesagt, nachdem darin Darsteller in Nazi-Uniform, eine massakrierte jüdische Familie und eine brutale Vergewaltigungsszene zu sehen waren. Schon nach 30 Minuten verließ das Publikum Burkhard C. Kosminskis Interpretation von Wagners Klassiker "Tannhäuser" und einige mussten wegen "psychologischer Traumata" ärztlich behandelt werden. Die Rheinoper in Düsseldorf sagte, sie habe zwar gewusst, dass das Konzert "kontrovers" sein würde, aber nicht mit einer derart extremen Reaktion gerechnet. Kritik: Die Oper verärgerte einige Zuschauer, weil darin Darsteller in Nazi-Uniform zu sehen waren. Kontrovers: In einer Szene vergewaltigt die Figur Wolfram, links, Elisabeth, rechts brutal. Kosminksi sagte, er habe die antisemitische Haltung von Komponisten wie Wagner, der als einer der Favoriten Adolf Hitlers galt, "thematisieren" wollen. In einer Szene kamen nackte Darsteller in verrauchten Gaskammern auf die Bühne, um die als SS-Offizier verkleidete Venus und eine jüdische Familie in einer Parodie auf ein Massaker des Zweiten Weltkriegs zu töten. In einem anderen wurde eine Figur namens Elisabeth von Tannhausers Nebenbuhler Wolfram brutal vergewaltigt und ging. Und schließlich wurden Mutter, Vater und Tochter von Wehrmachtsangehörigen vorgeführt - ihnen wurden die Kleider ausgezogen, sie rasiert und erschossen. Kosminski wurde Berichten zufolge am ersten Abend nach der Party von wütenden Kritikern konfrontiert, die ihm sagten, er habe
#
# Die Interpretation von Wagners Klassiker "Tannhäuser" sorgt für Furore: Das Publikum verlässt nach 30 Minuten die Bühne, einige werden wegen "Traumas" behandelt Intendant Kosminksi sagte, er wolle Antisemitismus "thematisieren".
#
# --------
# Eine entsetzliche Gruppenvergewaltigung von sechs Touristen im berühmten Ferienort Acapulco wurde von einer bewaffneten Bande verübt, die ihre Horroranschläge mit Mescal zelebrierte und eine Frau verschonte, weil sie den "Nationalitätstest" bestanden hatte. Die Spanierinnen waren in den frühen Morgenstunden des Montags an dem Urlaubsort von fünf maskierten Männern vergewaltigt worden - von ihren Angreifern mit Bikini-Trägern gefesselt, die auch ihre Partner fesselten, damit diese nicht eingreifen konnten. Weitere Details des Angriffs wurden bekannt, als Beamte den Opfern - alle aus Mexiko-Stadt - halfen, Acapulco zu verlassen und Berichten zufolge nach Hause zurückzukehren. Polizeieskorte: Ein Kleintransporter mit den zwölf spanischen Touristen kam vom Justizministerium. Sechs spanische Frauen wurden in ihrem gemieteten Bungalow in Acapulco vergewaltigt, während ihre Begleiter gefesselt wurden. Entschuldigung: Acapulcos Bürgermeister Luis Walton versprach, die Verantwortlichen für den Angriff zu fassen und entschuldigte sich dafür, dass er sagte, es geschehe überall. Acapulcos Bürgermeister Luis Walton verurteilte das Verbrechen und versprach, die Verantwortlichen zu fassen, sah sich aber auch gezwungen, sich heute zu entschuldigen, nachdem er gesagt hatte, dass derartige Übergriffe "überall auf der Welt" passieren. "Ich entschuldige mich, dass ich das gesagt habe", sagte er. "Natürlich. Das beunruhigt uns und wir wollen nicht, dass so etwas in Acapulco oder anderswo auf der
#
# Sechs Frauen wurden drei Stunden lang von der Männergruppe angegriffen, die mitten in der Nacht in ihre Wohnung eingebrochen war: Die fünf maskierten Männer fesselten die Partner des Opfers mit Telefonkabeln und tranken Mescal, als sie die spanische Gruppe vergewaltigten eine Mexikanerin, die sich in der Wohnung aufhielt, blieb "aufgrund ihrer Nationalität" verschont der Bürgermeister von Acapulco, Luis Walton, entschuldigt sich heute für die anfängliche Bemerkung, dass "es überall passiert", da Opfern geholfen wird, die Wohnung unter Polizeischutz zu verlassen.
#
# --------
# (CNN) - Der Portugiese Rui Costa fuhr am Dienstag in Gap zum Sieg, während Tour-de-France-Spitzenreiter Chris Froome von einem späten Hochgeschwindigkeitsgewirr mit seinem Erzrivalen Alberto Contador eingeholt wurde. Movistar-Fahrer Costa gehörte zu einer 26-köpfigen Ausreißergruppe, die auf der 16. Etappe freie Fahrt hatte, als sich Froome und die übrigen Anwärter auf das Gelbe Trikot ihren eigenen Privatkampf lieferten. Costa, der seine zweite Tour-Etappe gewann, überquerte die Ziellinie nach 168 km von Vaison-la-Romaine nach Gap nach drei Stunden 52 Minuten 45 Sekunden. Am letzten Anstieg der zweiten Kategorie eines Testtages attackierte er rechtzeitig und kam mit 42 Sekunden Vorsprung auf den zweitplatzierten Christophe Riblon aus Frankreich ins Ziel. Der Brite Froome wurde auf dem Schlussanstieg vom Spanier Contador immer wieder attackiert, aber mit Hilfe seines Sky-Teamkollegen Richie Porte abgewehrt. Auf der letzten kniffligen Abfahrt nach Gap unternahm Contador von Saxo Tinkoff weitere Versuche, dem Führenden lebenswichtige Zeit zurückzuholen, doch in einer scharfen Kurve, gut acht Kilometer vor dem Ziel, fuhr er auf den Asphalt. Auch Froome wurde behindert und musste kurz einen Fuß aus den Pedalen nehmen, blieb aber unversehrt. Porte führte das Duo zurück in die Spitzengruppe, zu der auch der zweitplatzierte Bauke Mollema, der Tscheche Roman Kreuziger und der Kolumbianer Nairo Quintana gehörten. Contador schien Verletzungen am Ellbogen zu untersuchen, fuhr aber ungeh
#
# Der Portugiese Rui Costa gewinnt die 16. Etappe der Tour de France. Costa Teil einer Ausreißergruppe, die klar blieb. Der Brite Chris Froome behält die Gesamtführung und das Gelbe Trikot. Alberto Contador stürzt auf der Schlussabfahrt, bleibt aber Dritter.
#
# --------
# Arsenal steht laut spanischen Medienberichten kurz vor der Verpflichtung von Mittelfeldspieler Mario Suarez von Atlético Madrid. Der 27-Jährige bestritt in der vergangenen Saison 22 Spiele, als Atlético La Liga gewann und ins Champions-League-Finale einzog, ist in dieser Saison aber in Ungnade gefallen. Mit Spielern wie Gabi, Tiago, Raul Garcia und Saul Niguez vor sich in der Hackordnung unter Diego Simeone will Suarez weitermachen. Mario Suarez (links) kämpft während eines Champions-League-Gruppenspiels gegen Roberto Pereyra von Juventus Turin. Suarez ist in Diego Simeones Plänen hinter Gabi, Tiago, Raul Garcia und Saul Niguez zurückgefallen. Laut dem angesehenen spanischen Journalisten Eduardo Inda, einem ehemaligen Herausgeber der Madrider Zeitung Marca, "wird Suarez mit ziemlicher Sicherheit ins Winter-Transferfenster gehen". Und Arsenal, dem es an Optionen in der Innenverteidigung mangelt, ist sein wahrscheinlichstes Ziel, wenn Wenger versucht, sich zum 17. Mal in Folge die Champions League zu sichern. Der Gunners-Boss enthüllte am Dienstag, dass er einen Mittelfeldakteur sucht, um Verletzungen im Kader auszugleichen, wobei Wenger Francis Coquelin von einem Leihgeschäft in Charlton zurückrufen muss, um neben Mathieu Flamini zu spielen. Suarez war ein Schlüsselspieler der Atlético-Mannschaft, die in der letzten Saison das Champions-League-Finale erreichte. Der Mittelfeldspieler ist ein lokaler Junge, der seit seinem zwölften Lebensjahr bei Atlético spielt, aber nun vor de
#
# Der 27-jährige spanische Mittelfeldakteur ist beim Champions-League-Sieger in Ungnade gefallen. Arsene Wenger will in der kommenden Transferperiode einen defensiven Mittelfeldspieler verpflichten. Mario Suarez hat zwei Länderspiele für Spanien gewonnen. Arsenal-Kapitän Mikel Arteta ist verletzt und belastet Mathieu Flamini.
#
# --------
# Ein ehemaliger Polizeibeamter in New York City ist verhaftet worden, weil er angeblich antisemitische Schmähungen auf Autos und Gebäude in einem überwiegend jüdischen Viertel von Brooklyn gesprüht haben soll, darunter die Eingangstüren einer religiösen Grundschule. Michael Setiawan wurde heute Morgen aufgegriffen, nachdem die Polizei am Samstagabend einen Anruf wegen Hakenkreuzen und anderer antisemitischer Graffiti im Borough Park erhalten hatte. Der 36-Jährige muss sich wegen fahrlässiger Tötung und erschwerter Belästigung als Hassverbrechen verantworten. Setiawan war bis 2007 Stadtbeamter und diente im 69. Bezirk von Brooklyn im Stadtteil Canarsie, wie die Polizei mitteilte. Auf frischer Tat ertappt: Auf einem Video ist zu sehen, wie ein Mann in der Nacht zum Samstag antisemitische Graffiti auf Autos und Gebäude im überwiegend jüdischen Stadtteil Brooklyn sprüht. Der ehemalige NYPD-Beamte Michael Setiawan, 36, wurde festgenommen. Die rot besprühten Worte wurden auf 15 Fahrzeuge und vier Gebäude in der Nähe der Synagoge und Schule von Bnos Zion der ultraorthodoxen Bobow-Gemeinde gesprüht. Zu den beunruhigenden Tiraden gehörten "f * * * ihr Juden" und "Jews ain 't s * *", meist entlang der Dahill Rd. und der 37. Straße sowie der 14. Ave. In der Nähe der 38. Straße filmte eine Überwachungskamera der Schule einen glatzköpfigen Mann mit blauem T-Shirt, der eine Tür besprühte. Das Filmmaterial wurde von JPUpdates.com veröffentlicht. Die Polizei wollte zunächst nicht bestätigen,
#
# Michael Setiawan, 36, wird beschuldigt, Hakenkreuze mit den Worten "f * * * ihr Juden" und "Juden seid nicht s * * *" auf Autos und Gebäude im Borough Park gesprüht zu haben. In der Nachbarschaft befindet sich eine große orthodoxe jüdische Gemeinde. Er soll in der vergangenen Nacht etwa 20 hasserfüllte Botschaften gekritzelt haben. Setiawan verließ 2007 die Polizei und lebt bei seinen Eltern in Queens. Seine Familie sagt, er sei psychisch krank und befinde sich in einem Krankenhaus und befinde sich außerhalb des Krankenhauses. Der Indonesier wurde wegen kriminellen Unfugs als Hassverbrechen und erschwerter Belästigung angeklagt.

# %% [markdown]
# ## Define Pytorch Dataset

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, articles, highlights):
        self.x = articles
        self.y = highlights
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index]), max_length=512, return_tensors="pt", pad_to_max_length=True)
        y = tokenizer.encode(self.transfrom(self.y[index]), max_length=150, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1), y.view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
train_ds = MyDataset(train_x, train_y) 
val_ds = MyDataset(val_x, val_y)
test_ds = MyDataset(test_x, test_y)

# %%
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
x, x_mask, y = next(iter(val_loader))
x.shape, x_mask.shape, y.shape
# Out:
# (torch.Size([16, 512]), torch.Size([16, 512]), torch.Size([16, 150]))

# %% [markdown]
# ## Define Step function

# %%
pad_token_id = tokenizer.pad_token_id
def step(inputs_ids, attention_mask, y):
    y_ids = y[:, :-1].contiguous()
    lm_labels = y[:, 1:].clone()
    lm_labels[y[:, 1:] == pad_token_id] = -100
    output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
    return output[0] # loss

# %% [markdown]
# ## Train

# %%
train_loss = []
val_loss = []
for epoch in range(EPOCHS):
    model.train() 
    start_time = time.time()
    for i, (inputs_ids, attention_mask, y) in enumerate(train_loader):
        inputs_ids = inputs_ids.to(device)
        attention_mask = attention_mask.to(device)
        y = y.to(device)
        
        
        optimizer.zero_grad()
        loss = step(inputs_ids, attention_mask, y)
        train_loss.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
            
        if (i + 1) % log_interval == 0:
            with torch.no_grad():
                x, x_mask, y = next(iter(val_loader))
                x = x.to(device)
                x_mask = x_mask.to(device)
                y = y.to(device)
                
                v_loss = step(x, x_mask, y)
                v_loss = v_loss.item()
                
                
                elapsed = time.time() - start_time
                print('| epoch {:3d} | [{:5d}/{:5d}] | '
                  'ms/batch {:5.2f} | '
                  'loss {:5.2f} | val loss {:5.2f}'.format(
                    epoch, i, len(train_loader),
                    elapsed * 1000 / log_interval,
                    loss.item(), v_loss))
                start_time = time.time()
                val_loss.append(v_loss)
# Out:
# | epoch   0 | [  199/17945] | ms/batch 408.75 | loss  3.19 | val loss  2.82
# | epoch   0 | [  399/17945] | ms/batch 404.60 | loss  3.05 | val loss  2.73
# | epoch   0 | [  599/17945] | ms/batch 403.42 | loss  3.15 | val loss  2.66
# | epoch   0 | [  799/17945] | ms/batch 405.32 | loss  2.73 | val loss  2.67
# | epoch   0 | [  999/17945] | ms/batch 403.11 | loss  2.93 | val loss  2.62
# | epoch   0 | [ 1199/17945] | ms/batch 405.05 | loss  2.61 | val loss  2.58
# | epoch   0 | [ 1399/17945] | ms/batch 404.82 | loss  2.62 | val loss  2.57
# | epoch   0 | [ 1599/17945] | ms/batch 407.41 | loss  2.73 | val loss  2.52
# | epoch   0 | [ 1799/17945] | ms/batch 401.32 | loss  2.59 | val loss  2.51
# | epoch   0 | [ 1999/17945] | ms/batch 403.44 | loss  2.63 | val loss  2.47
# | epoch   0 | [ 2199/17945] | ms/batch 407.13 | loss  2.44 | val loss  2.48
# | epoch   0 | [ 2399/17945] | ms/batch 409.26 | loss  2.90 | val loss  2.45
# | epoch   0 | [ 2599/17945] | ms/batch 407.93 | loss  2.51 | val loss  2.46
# | epoch   0 | [ 2799/17945] | ms/batch 409.37 | loss  2.58 | val loss  2.44
# | epoch   0 | [ 2999/17945] | ms/batch 402.67 | loss  2.20 | val loss  2.44
# | epoch   0 | [ 3199/17945] | ms/batch 403.91 | loss  2.82 | val loss  2.43
# | epoch   0 | [ 3399/17945] | ms/batch 406.38 | loss  2.57 | val loss  2.45
# | epoch   0 | [ 3599/17945] | ms/batch 403.23 | loss  2.67 | val loss  2.42
# | epoch   0 | [ 3799/17945] | ms/batch 403.72 | loss  2.39 | val loss  2.42
# | epoch   0 | [ 3999/17945] | ms/batch 407.12 | loss  2.57 | val loss  2.43
# | epoch   0 | [ 4199/17945] | ms/batch 408.06 | loss  2.49 | val loss  2.39
# | epoch   0 | [ 4399/17945] | ms/batch 411.96 | loss  2.64 | val loss  2.41
# | epoch   0 | [ 4599/17945] | ms/batch 401.90 | loss  2.58 | val loss  2.41
# | epoch   0 | [ 4799/17945] | ms/batch 404.29 | loss  2.49 | val loss  2.41
# | epoch   0 | [ 4999/17945] | ms/batch 404.67 | loss  2.67 | val loss  2.42
# | epoch   0 | [ 5199/17945] | ms/batch 403.28 | loss  2.71 | val loss  2.38
# | epoch   0 | [ 5399/17945] | ms/batch 404.08 | loss  2.48 | val loss  2.38
# | epoch   0 | [ 5599/17945] | ms/batch 405.37 | loss  2.34 | val loss  2.36
# | epoch   0 | [ 5799/17945] | ms/batch 405.09 | loss  2.65 | val loss  2.41
# | epoch   0 | [ 5999/17945] | ms/batch 404.96 | loss  2.77 | val loss  2.37
# | epoch   0 | [ 6199/17945] | ms/batch 403.71 | loss  2.40 | val loss  2.39
# | epoch   0 | [ 6399/17945] | ms/batch 402.92 | loss  2.54 | val loss  2.38
# | epoch   0 | [ 6599/17945] | ms/batch 403.53 | loss  2.34 | val loss  2.36
# | epoch   0 | [ 6799/17945] | ms/batch 402.33 | loss  2.55 | val loss  2.38
# | epoch   0 | [ 6999/17945] | ms/batch 403.35 | loss  2.10 | val loss  2.33
# | epoch   0 | [ 7199/17945] | ms/batch 405.37 | loss  2.53 | val loss  2.38
# | epoch   0 | [ 7399/17945] | ms/batch 402.86 | loss  2.47 | val loss  2.40
# | epoch   0 | [ 7599/17945] | ms/batch 400.07 | loss  2.53 | val loss  2.34
# | epoch   0 | [ 7799/17945] | ms/batch 405.50 | loss  2.76 | val loss  2.36
# | epoch   0 | [ 7999/17945] | ms/batch 405.18 | loss  2.60 | val loss  2.33
# | epoch   0 | [ 8199/17945] | ms/batch 405.03 | loss  2.57 | val loss  2.37
# | epoch   0 | [ 8399/17945] | ms/batch 402.91 | loss  2.84 | val loss  2.36
# | epoch   0 | [ 8599/17945] | ms/batch 404.37 | loss  2.54 | val loss  2.33
# | epoch   0 | [ 8799/17945] | ms/batch 404.45 | loss  2.24 | val loss  2.33
# | epoch   0 | [ 8999/17945] | ms/batch 403.43 | loss  2.54 | val loss  2.40
# | epoch   0 | [ 9199/17945] | ms/batch 406.52 | loss  2.59 | val loss  2.34
# | epoch   0 | [ 9399/17945] | ms/batch 403.57 | loss  2.38 | val loss  2.34
# | epoch   0 | [ 9599/17945] | ms/batch 402.59 | loss  2.46 | val loss  2.37
# | epoch   0 | [ 9799/17945] | ms/batch 405.34 | loss  2.43 | val loss  2.39
# | epoch   0 | [ 9999/17945] | ms/batch 403.74 | loss  2.36 | val loss  2.36
# | epoch   0 | [10199/17945] | ms/batch 401.96 | loss  2.63 | val loss  2.39
# | epoch   0 | [10399/17945] | ms/batch 402.04 | loss  2.49 | val loss  2.42
# | epoch   0 | [10599/17945] | ms/batch 406.77 | loss  2.64 | val loss  2.41
# | epoch   0 | [10799/17945] | ms/batch 399.56 | loss  2.40 | val loss  2.39
# | epoch   0 | [10999/17945] | ms/batch 402.58 | loss  2.75 | val loss  2.36
# | epoch   0 | [11199/17945] | ms/batch 401.97 | loss  2.45 | val loss  2.35
# | epoch   0 | [11399/17945] | ms/batch 404.42 | loss  2.46 | val loss  2.38
# | epoch   0 | [11599/17945] | ms/batch 407.06 | loss  2.68 | val loss  2.39
# | epoch   0 | [11799/17945] | ms/batch 406.91 | loss  2.37 | val loss  2.42
# | epoch   0 | [11999/17945] | ms/batch 405.39 | loss  2.23 | val loss  2.41
# | epoch   0 | [12199/17945] | ms/batch 404.47 | loss  2.64 | val loss  2.41
# | epoch   0 | [12399/17945] | ms/batch 403.32 | loss  2.65 | val loss  2.43
# | epoch   0 | [12599/17945] | ms/batch 404.24 | loss  2.49 | val loss  2.42
# | epoch   0 | [12799/17945] | ms/batch 403.29 | loss  2.58 | val loss  2.42
# | epoch   0 | [12999/17945] | ms/batch 403.96 | loss  2.52 | val loss  2.39
# | epoch   0 | [13199/17945] | ms/batch 399.81 | loss  2.57 | val loss  2.39
# | epoch   0 | [13399/17945] | ms/batch 402.91 | loss  2.71 | val loss  2.39
# | epoch   0 | [13599/17945] | ms/batch 402.87 | loss  2.82 | val loss  2.41
# | epoch   0 | [13799/17945] | ms/batch 403.01 | loss  2.72 | val loss  2.43
# | epoch   0 | [13999/17945] | ms/batch 400.50 | loss  2.21 | val loss  2.46
# | epoch   0 | [14199/17945] | ms/batch 402.82 | loss  2.58 | val loss  2.42
# | epoch   0 | [14399/17945] | ms/batch 403.40 | loss  2.85 | val loss  2.41
# | epoch   0 | [14599/17945] | ms/batch 403.92 | loss  2.68 | val loss  2.41
# | epoch   0 | [14799/17945] | ms/batch 404.73 | loss  2.80 | val loss  2.44
# | epoch   0 | [14999/17945] | ms/batch 403.41 | loss  2.75 | val loss  2.40
# | epoch   0 | [15199/17945] | ms/batch 401.16 | loss  2.44 | val loss  2.41
# | epoch   0 | [15399/17945] | ms/batch 406.17 | loss  2.66 | val loss  2.42
# | epoch   0 | [15599/17945] | ms/batch 402.90 | loss  2.78 | val loss  2.45
# | epoch   0 | [15799/17945] | ms/batch 402.73 | loss  2.37 | val loss  2.51
# | epoch   0 | [15999/17945] | ms/batch 404.92 | loss  2.56 | val loss  2.47
# | epoch   0 | [16199/17945] | ms/batch 401.94 | loss  2.68 | val loss  2.48
# | epoch   0 | [16399/17945] | ms/batch 400.37 | loss  2.43 | val loss  2.44
# | epoch   0 | [16599/17945] | ms/batch 405.99 | loss  2.66 | val loss  2.46
# | epoch   0 | [16799/17945] | ms/batch 403.76 | loss  2.93 | val loss  2.44
# | epoch   0 | [16999/17945] | ms/batch 401.23 | loss  2.91 | val loss  2.48
# | epoch   0 | [17199/17945] | ms/batch 398.16 | loss  2.48 | val loss  2.47
# | epoch   0 | [17399/17945] | ms/batch 400.90 | loss  2.89 | val loss  2.51
# | epoch   0 | [17599/17945] | ms/batch 406.42 | loss  2.67 | val loss  2.45
# | epoch   0 | [17799/17945] | ms/batch 404.04 | loss  3.09 | val loss  2.47
# | epoch   1 | [  199/17945] | ms/batch 404.69 | loss  2.81 | val loss  2.49
# | epoch   1 | [  399/17945] | ms/batch 403.19 | loss  2.82 | val loss  2.48
# | epoch   1 | [  599/17945] | ms/batch 399.97 | loss  2.99 | val loss  2.49
# | epoch   1 | [  799/17945] | ms/batch 401.33 | loss  2.67 | val loss  2.53
# | epoch   1 | [  999/17945] | ms/batch 403.10 | loss  2.92 | val loss  2.51
# | epoch   1 | [ 1199/17945] | ms/batch 403.79 | loss  2.61 | val loss  2.55
# | epoch   1 | [ 1399/17945] | ms/batch 404.60 | loss  2.56 | val loss  2.51
# | epoch   1 | [ 1599/17945] | ms/batch 401.76 | loss  2.79 | val loss  2.54
# | epoch   1 | [ 1799/17945] | ms/batch 401.50 | loss  2.64 | val loss  2.53
# | epoch   1 | [ 1999/17945] | ms/batch 402.73 | loss  2.73 | val loss  2.52
# | epoch   1 | [ 2199/17945] | ms/batch 404.61 | loss  2.57 | val loss  2.57
# | epoch   1 | [ 2399/17945] | ms/batch 404.31 | loss  3.07 | val loss  2.58
# | epoch   1 | [ 2599/17945] | ms/batch 402.51 | loss  2.67 | val loss  2.54
# | epoch   1 | [ 2799/17945] | ms/batch 399.23 | loss  2.72 | val loss  2.53
# | epoch   1 | [ 2999/17945] | ms/batch 399.96 | loss  2.28 | val loss  2.56
# | epoch   1 | [ 3199/17945] | ms/batch 399.47 | loss  2.92 | val loss  2.59
# | epoch   1 | [ 3399/17945] | ms/batch 401.63 | loss  2.67 | val loss  2.53
# | epoch   1 | [ 3599/17945] | ms/batch 400.04 | loss  2.92 | val loss  2.56
# | epoch   1 | [ 3799/17945] | ms/batch 401.00 | loss  2.54 | val loss  2.60
# | epoch   1 | [ 3999/17945] | ms/batch 400.61 | loss  2.81 | val loss  2.56
# | epoch   1 | [ 4199/17945] | ms/batch 402.63 | loss  2.76 | val loss  2.58
# | epoch   1 | [ 4399/17945] | ms/batch 403.30 | loss  2.86 | val loss  2.56
# | epoch   1 | [ 4599/17945] | ms/batch 403.00 | loss  2.79 | val loss  2.57
# | epoch   1 | [ 4799/17945] | ms/batch 401.96 | loss  2.74 | val loss  2.61
# | epoch   1 | [ 4999/17945] | ms/batch 403.38 | loss  2.83 | val loss  2.59
# | epoch   1 | [ 5199/17945] | ms/batch 402.37 | loss  3.05 | val loss  2.59
# | epoch   1 | [ 5399/17945] | ms/batch 403.24 | loss  2.77 | val loss  2.59
# | epoch   1 | [ 5599/17945] | ms/batch 405.12 | loss  2.57 | val loss  2.60
# | epoch   1 | [ 5799/17945] | ms/batch 417.72 | loss  2.86 | val loss  2.62
# | epoch   1 | [ 5999/17945] | ms/batch 407.31 | loss  3.12 | val loss  2.59
# | epoch   1 | [ 6199/17945] | ms/batch 406.59 | loss  2.63 | val loss  2.62
# | epoch   1 | [ 6399/17945] | ms/batch 403.91 | loss  2.82 | val loss  2.67
# | epoch   1 | [ 6599/17945] | ms/batch 405.58 | loss  2.60 | val loss  2.58
# | epoch   1 | [ 6799/17945] | ms/batch 402.56 | loss  2.78 | val loss  2.66
# | epoch   1 | [ 6999/17945] | ms/batch 402.51 | loss  2.42 | val loss  2.61
# | epoch   1 | [ 7199/17945] | ms/batch 407.03 | loss  2.85 | val loss  2.64
# | epoch   1 | [ 7399/17945] | ms/batch 406.20 | loss  2.76 | val loss  2.65
# | epoch   1 | [ 7599/17945] | ms/batch 404.15 | loss  2.87 | val loss  2.63
# | epoch   1 | [ 7799/17945] | ms/batch 402.06 | loss  3.08 | val loss  2.64
# | epoch   1 | [ 7999/17945] | ms/batch 404.70 | loss  2.91 | val loss  2.66
# | epoch   1 | [ 8199/17945] | ms/batch 403.53 | loss  2.89 | val loss  2.67
# | epoch   1 | [ 8399/17945] | ms/batch 399.74 | loss  3.08 | val loss  2.67
# | epoch   1 | [ 8599/17945] | ms/batch 402.19 | loss  2.93 | val loss  2.69
# | epoch   1 | [ 8799/17945] | ms/batch 402.32 | loss  2.48 | val loss  2.65
# | epoch   1 | [ 8999/17945] | ms/batch 403.79 | loss  2.84 | val loss  2.69
# | epoch   1 | [ 9199/17945] | ms/batch 406.76 | loss  2.94 | val loss  2.65
# | epoch   1 | [ 9399/17945] | ms/batch 403.58 | loss  2.72 | val loss  2.71
# | epoch   1 | [ 9599/17945] | ms/batch 402.88 | loss  2.70 | val loss  2.68
# | epoch   1 | [ 9799/17945] | ms/batch 405.14 | loss  2.77 | val loss  2.65
# | epoch   1 | [ 9999/17945] | ms/batch 406.34 | loss  2.66 | val loss  2.67
# | epoch   1 | [10199/17945] | ms/batch 405.73 | loss  2.94 | val loss  2.67
# | epoch   1 | [10399/17945] | ms/batch 406.39 | loss  2.84 | val loss  2.68
# | epoch   1 | [10599/17945] | ms/batch 407.90 | loss  2.97 | val loss  2.74
# | epoch   1 | [10799/17945] | ms/batch 402.74 | loss  2.64 | val loss  2.69
# | epoch   1 | [10999/17945] | ms/batch 405.33 | loss  3.09 | val loss  2.71
# | epoch   1 | [11199/17945] | ms/batch 403.42 | loss  2.75 | val loss  2.69
# | epoch   1 | [11399/17945] | ms/batch 403.60 | loss  2.78 | val loss  2.70
# | epoch   1 | [11599/17945] | ms/batch 403.56 | loss  2.98 | val loss  2.69
# | epoch   1 | [11799/17945] | ms/batch 404.74 | loss  2.68 | val loss  2.70
# | epoch   1 | [11999/17945] | ms/batch 401.52 | loss  2.57 | val loss  2.70
# | epoch   1 | [12199/17945] | ms/batch 404.54 | loss  2.90 | val loss  2.72
# | epoch   1 | [12399/17945] | ms/batch 404.28 | loss  3.02 | val loss  2.72
# | epoch   1 | [12599/17945] | ms/batch 406.49 | loss  2.75 | val loss  2.73
# | epoch   1 | [12799/17945] | ms/batch 401.42 | loss  2.90 | val loss  2.69
# | epoch   1 | [12999/17945] | ms/batch 404.83 | loss  2.91 | val loss  2.69
# | epoch   1 | [13199/17945] | ms/batch 403.40 | loss  2.88 | val loss  2.74
# | epoch   1 | [13399/17945] | ms/batch 402.18 | loss  3.05 | val loss  2.72
# | epoch   1 | [13599/17945] | ms/batch 403.19 | loss  3.18 | val loss  2.77
# | epoch   1 | [13799/17945] | ms/batch 406.75 | loss  3.08 | val loss  2.74
# | epoch   1 | [13999/17945] | ms/batch 400.17 | loss  2.47 | val loss  2.70
# | epoch   1 | [14199/17945] | ms/batch 401.64 | loss  2.90 | val loss  2.77
# | epoch   1 | [14399/17945] | ms/batch 402.50 | loss  3.17 | val loss  2.79
# | epoch   1 | [14599/17945] | ms/batch 402.65 | loss  3.03 | val loss  2.78
# | epoch   1 | [14799/17945] | ms/batch 400.97 | loss  3.12 | val loss  2.76
# | epoch   1 | [14999/17945] | ms/batch 399.02 | loss  3.09 | val loss  2.74
# | epoch   1 | [15199/17945] | ms/batch 400.83 | loss  2.80 | val loss  2.78
# | epoch   1 | [15399/17945] | ms/batch 400.80 | loss  2.93 | val loss  2.74
# | epoch   1 | [15599/17945] | ms/batch 401.48 | loss  3.07 | val loss  2.76
# | epoch   1 | [15799/17945] | ms/batch 399.46 | loss  2.64 | val loss  2.76
# | epoch   1 | [15999/17945] | ms/batch 403.88 | loss  2.87 | val loss  2.76
# | epoch   1 | [16199/17945] | ms/batch 402.89 | loss  2.96 | val loss  2.77
# | epoch   1 | [16399/17945] | ms/batch 398.39 | loss  2.78 | val loss  2.78
# | epoch   1 | [16599/17945] | ms/batch 403.85 | loss  2.97 | val loss  2.76
# | epoch   1 | [16799/17945] | ms/batch 400.25 | loss  3.23 | val loss  2.77
# | epoch   1 | [16999/17945] | ms/batch 400.02 | loss  3.27 | val loss  2.78
# | epoch   1 | [17199/17945] | ms/batch 398.71 | loss  2.75 | val loss  2.77
# | epoch   1 | [17399/17945] | ms/batch 400.36 | loss  3.26 | val loss  2.81
# | epoch   1 | [17599/17945] | ms/batch 403.83 | loss  3.01 | val loss  2.75
# | epoch   1 | [17799/17945] | ms/batch 402.41 | loss  3.35 | val loss  2.75
# | epoch   2 | [  199/17945] | ms/batch 403.60 | loss  3.10 | val loss  2.83
# | epoch   2 | [  399/17945] | ms/batch 403.56 | loss  3.17 | val loss  2.84
# | epoch   2 | [  599/17945] | ms/batch 400.48 | loss  3.31 | val loss  2.80
# | epoch   2 | [  799/17945] | ms/batch 401.79 | loss  2.96 | val loss  2.79
# | epoch   2 | [  999/17945] | ms/batch 402.25 | loss  3.25 | val loss  2.84
# | epoch   2 | [ 1199/17945] | ms/batch 403.95 | loss  2.92 | val loss  2.80
# | epoch   2 | [ 1399/17945] | ms/batch 404.14 | loss  2.83 | val loss  2.81
# | epoch   2 | [ 1599/17945] | ms/batch 403.36 | loss  3.07 | val loss  2.84
# | epoch   2 | [ 1799/17945] | ms/batch 400.68 | loss  2.95 | val loss  2.82
# | epoch   2 | [ 1999/17945] | ms/batch 402.46 | loss  3.03 | val loss  2.83
# | epoch   2 | [ 2199/17945] | ms/batch 403.33 | loss  2.86 | val loss  2.82
# | epoch   2 | [ 2399/17945] | ms/batch 402.94 | loss  3.31 | val loss  2.84
# | epoch   2 | [ 2599/17945] | ms/batch 403.16 | loss  2.96 | val loss  2.82
# | epoch   2 | [ 2799/17945] | ms/batch 403.43 | loss  2.97 | val loss  2.84
# | epoch   2 | [ 2999/17945] | ms/batch 401.07 | loss  2.57 | val loss  2.89
# | epoch   2 | [ 3199/17945] | ms/batch 399.14 | loss  3.19 | val loss  2.86
# | epoch   2 | [ 3399/17945] | ms/batch 403.89 | loss  2.95 | val loss  2.87
# | epoch   2 | [ 3599/17945] | ms/batch 406.17 | loss  3.20 | val loss  2.84
# | epoch   2 | [ 3799/17945] | ms/batch 404.99 | loss  2.81 | val loss  2.85
# | epoch   2 | [ 3999/17945] | ms/batch 403.62 | loss  3.10 | val loss  2.89
# | epoch   2 | [ 4199/17945] | ms/batch 403.93 | loss  3.01 | val loss  2.91
# | epoch   2 | [ 4399/17945] | ms/batch 403.75 | loss  3.18 | val loss  2.85
# | epoch   2 | [ 4599/17945] | ms/batch 403.98 | loss  3.09 | val loss  2.81
# | epoch   2 | [ 4799/17945] | ms/batch 402.21 | loss  3.03 | val loss  2.86
# | epoch   2 | [ 4999/17945] | ms/batch 405.22 | loss  3.09 | val loss  2.83
# | epoch   2 | [ 5199/17945] | ms/batch 401.71 | loss  3.38 | val loss  2.87
# | epoch   2 | [ 5399/17945] | ms/batch 401.80 | loss  3.02 | val loss  2.89
# | epoch   2 | [ 5599/17945] | ms/batch 406.07 | loss  2.83 | val loss  2.86
# | epoch   2 | [ 5799/17945] | ms/batch 404.32 | loss  3.12 | val loss  2.88
# | epoch   2 | [ 5999/17945] | ms/batch 407.69 | loss  3.40 | val loss  2.84
# | epoch   2 | [ 6199/17945] | ms/batch 404.49 | loss  2.83 | val loss  2.88
# | epoch   2 | [ 6399/17945] | ms/batch 403.52 | loss  3.07 | val loss  2.90
# | epoch   2 | [ 6599/17945] | ms/batch 404.54 | loss  2.88 | val loss  2.85
# | epoch   2 | [ 6799/17945] | ms/batch 403.56 | loss  3.01 | val loss  2.90
# | epoch   2 | [ 6999/17945] | ms/batch 403.29 | loss  2.71 | val loss  2.93
# | epoch   2 | [ 7199/17945] | ms/batch 404.95 | loss  3.08 | val loss  2.87
# | epoch   2 | [ 7399/17945] | ms/batch 405.59 | loss  2.94 | val loss  2.88
# | epoch   2 | [ 7599/17945] | ms/batch 404.97 | loss  3.08 | val loss  2.90
# | epoch   2 | [ 7799/17945] | ms/batch 404.14 | loss  3.34 | val loss  2.88
# | epoch   2 | [ 7999/17945] | ms/batch 403.84 | loss  3.12 | val loss  2.91
# | epoch   2 | [ 8199/17945] | ms/batch 403.05 | loss  3.13 | val loss  2.95
# | epoch   2 | [ 8399/17945] | ms/batch 399.09 | loss  3.35 | val loss  2.88
# | epoch   2 | [ 8599/17945] | ms/batch 404.01 | loss  3.12 | val loss  2.92
# | epoch   2 | [ 8799/17945] | ms/batch 403.11 | loss  2.73 | val loss  2.92
# | epoch   2 | [ 8999/17945] | ms/batch 401.30 | loss  3.07 | val loss  2.89
# | epoch   2 | [ 9199/17945] | ms/batch 404.62 | loss  3.21 | val loss  2.88
# | epoch   2 | [ 9399/17945] | ms/batch 402.01 | loss  2.91 | val loss  2.87
# | epoch   2 | [ 9599/17945] | ms/batch 402.04 | loss  2.93 | val loss  2.91
# | epoch   2 | [ 9799/17945] | ms/batch 403.43 | loss  3.01 | val loss  2.90
# | epoch   2 | [ 9999/17945] | ms/batch 403.10 | loss  2.89 | val loss  2.94
# | epoch   2 | [10199/17945] | ms/batch 403.67 | loss  3.20 | val loss  2.89
# | epoch   2 | [10399/17945] | ms/batch 401.80 | loss  3.03 | val loss  2.91
# | epoch   2 | [10599/17945] | ms/batch 404.74 | loss  3.31 | val loss  2.93
# | epoch   2 | [10799/17945] | ms/batch 400.20 | loss  2.84 | val loss  2.91
# | epoch   2 | [10999/17945] | ms/batch 402.07 | loss  3.23 | val loss  2.95
# | epoch   2 | [11199/17945] | ms/batch 402.17 | loss  3.03 | val loss  2.93
# | epoch   2 | [11399/17945] | ms/batch 404.49 | loss  2.98 | val loss  2.91
# | epoch   2 | [11599/17945] | ms/batch 404.79 | loss  3.17 | val loss  2.94
# | epoch   2 | [11799/17945] | ms/batch 404.53 | loss  2.92 | val loss  2.93
# | epoch   2 | [11999/17945] | ms/batch 403.61 | loss  2.76 | val loss  2.95
# | epoch   2 | [12199/17945] | ms/batch 402.47 | loss  3.08 | val loss  2.95
# | epoch   2 | [12399/17945] | ms/batch 402.20 | loss  3.20 | val loss  2.96
# | epoch   2 | [12599/17945] | ms/batch 403.98 | loss  3.02 | val loss  2.92
# | epoch   2 | [12799/17945] | ms/batch 401.86 | loss  3.07 | val loss  2.95
# | epoch   2 | [12999/17945] | ms/batch 403.04 | loss  3.08 | val loss  2.93
# | epoch   2 | [13199/17945] | ms/batch 401.39 | loss  3.11 | val loss  2.98
# | epoch   2 | [13399/17945] | ms/batch 401.56 | loss  3.25 | val loss  2.93
# | epoch   2 | [13599/17945] | ms/batch 401.99 | loss  3.40 | val loss  2.93
# | epoch   2 | [13799/17945] | ms/batch 404.43 | loss  3.25 | val loss  2.93
# | epoch   2 | [13999/17945] | ms/batch 400.11 | loss  2.62 | val loss  2.96
# | epoch   2 | [14199/17945] | ms/batch 403.82 | loss  3.07 | val loss  2.95
# | epoch   2 | [14399/17945] | ms/batch 404.69 | loss  3.35 | val loss  2.97
# | epoch   2 | [14599/17945] | ms/batch 402.61 | loss  3.26 | val loss  2.97
# | epoch   2 | [14799/17945] | ms/batch 402.50 | loss  3.29 | val loss  2.97
# | epoch   2 | [14999/17945] | ms/batch 399.56 | loss  3.27 | val loss  2.93
# | epoch   2 | [15199/17945] | ms/batch 398.37 | loss  2.96 | val loss  2.98
# | epoch   2 | [15399/17945] | ms/batch 399.19 | loss  3.06 | val loss  2.97
# | epoch   2 | [15599/17945] | ms/batch 403.65 | loss  3.29 | val loss  3.01
# | epoch   2 | [15799/17945] | ms/batch 405.06 | loss  2.77 | val loss  2.98
# | epoch   2 | [15999/17945] | ms/batch 407.57 | loss  3.02 | val loss  2.98
# | epoch   2 | [16199/17945] | ms/batch 404.75 | loss  3.14 | val loss  3.00
# | epoch   2 | [16399/17945] | ms/batch 400.90 | loss  2.93 | val loss  2.97
# | epoch   2 | [16599/17945] | ms/batch 406.41 | loss  3.18 | val loss  2.92
# | epoch   2 | [16799/17945] | ms/batch 403.27 | loss  3.37 | val loss  2.96
# | epoch   2 | [16999/17945] | ms/batch 405.79 | loss  3.44 | val loss  3.02
# | epoch   2 | [17199/17945] | ms/batch 401.47 | loss  2.92 | val loss  2.94
# | epoch   2 | [17399/17945] | ms/batch 401.84 | loss  3.42 | val loss  2.97
# | epoch   2 | [17599/17945] | ms/batch 405.90 | loss  3.11 | val loss  3.01
# | epoch   2 | [17799/17945] | ms/batch 404.31 | loss  3.53 | val loss  2.99
# | epoch   3 | [  199/17945] | ms/batch 403.84 | loss  3.22 | val loss  2.99
# | epoch   3 | [  399/17945] | ms/batch 404.16 | loss  3.32 | val loss  2.94
# | epoch   3 | [  599/17945] | ms/batch 402.14 | loss  3.53 | val loss  2.97
# | epoch   3 | [  799/17945] | ms/batch 403.59 | loss  3.12 | val loss  2.96
# | epoch   3 | [  999/17945] | ms/batch 406.34 | loss  3.35 | val loss  2.92
# | epoch   3 | [ 1199/17945] | ms/batch 405.80 | loss  3.06 | val loss  2.95
# | epoch   3 | [ 1399/17945] | ms/batch 404.18 | loss  2.97 | val loss  2.93
# | epoch   3 | [ 1599/17945] | ms/batch 403.58 | loss  3.22 | val loss  2.94
# | epoch   3 | [ 1799/17945] | ms/batch 402.06 | loss  3.07 | val loss  2.96
# | epoch   3 | [ 1999/17945] | ms/batch 403.43 | loss  3.17 | val loss  3.00
# | epoch   3 | [ 2199/17945] | ms/batch 405.65 | loss  2.93 | val loss  2.99
# | epoch   3 | [ 2399/17945] | ms/batch 403.91 | loss  3.43 | val loss  3.03
# | epoch   3 | [ 2599/17945] | ms/batch 405.18 | loss  3.06 | val loss  2.95
# | epoch   3 | [ 2799/17945] | ms/batch 402.71 | loss  3.13 | val loss  2.98
# | epoch   3 | [ 2999/17945] | ms/batch 403.33 | loss  2.69 | val loss  2.97
# | epoch   3 | [ 3199/17945] | ms/batch 401.51 | loss  3.35 | val loss  2.98
# | epoch   3 | [ 3399/17945] | ms/batch 403.83 | loss  3.07 | val loss  3.01
# | epoch   3 | [ 3599/17945] | ms/batch 402.58 | loss  3.29 | val loss  2.96
# | epoch   3 | [ 3799/17945] | ms/batch 401.68 | loss  2.99 | val loss  2.97
# | epoch   3 | [ 3999/17945] | ms/batch 403.16 | loss  3.20 | val loss  2.97
# | epoch   3 | [ 4199/17945] | ms/batch 404.31 | loss  3.21 | val loss  2.97
# | epoch   3 | [ 4399/17945] | ms/batch 404.91 | loss  3.27 | val loss  2.99
# | epoch   3 | [ 4599/17945] | ms/batch 401.96 | loss  3.20 | val loss  2.97
# | epoch   3 | [ 4799/17945] | ms/batch 402.00 | loss  3.15 | val loss  2.98
# | epoch   3 | [ 4999/17945] | ms/batch 403.29 | loss  3.21 | val loss  3.00
# | epoch   3 | [ 5199/17945] | ms/batch 402.54 | loss  3.46 | val loss  3.00
# | epoch   3 | [ 5399/17945] | ms/batch 400.89 | loss  3.16 | val loss  2.98
# | epoch   3 | [ 5599/17945] | ms/batch 402.89 | loss  2.92 | val loss  2.96
# | epoch   3 | [ 5799/17945] | ms/batch 403.65 | loss  3.21 | val loss  2.97
# | epoch   3 | [ 5999/17945] | ms/batch 403.99 | loss  3.56 | val loss  2.98
# | epoch   3 | [ 6199/17945] | ms/batch 404.01 | loss  2.87 | val loss  3.04
# | epoch   3 | [ 6399/17945] | ms/batch 403.81 | loss  3.18 | val loss  2.94
# | epoch   3 | [ 6599/17945] | ms/batch 404.13 | loss  2.95 | val loss  2.99
# | epoch   3 | [ 6799/17945] | ms/batch 402.98 | loss  3.16 | val loss  2.98
# | epoch   3 | [ 6999/17945] | ms/batch 401.90 | loss  2.74 | val loss  2.97
# | epoch   3 | [ 7199/17945] | ms/batch 405.95 | loss  3.23 | val loss  2.99
# | epoch   3 | [ 7399/17945] | ms/batch 406.99 | loss  3.09 | val loss  2.98
# | epoch   3 | [ 7599/17945] | ms/batch 403.39 | loss  3.25 | val loss  3.01
# | epoch   3 | [ 7799/17945] | ms/batch 403.54 | loss  3.42 | val loss  2.99
# | epoch   3 | [ 7999/17945] | ms/batch 405.43 | loss  3.27 | val loss  2.98
# | epoch   3 | [ 8199/17945] | ms/batch 403.21 | loss  3.25 | val loss  2.96
# | epoch   3 | [ 8399/17945] | ms/batch 402.27 | loss  3.41 | val loss  3.02
# | epoch   3 | [ 8599/17945] | ms/batch 402.70 | loss  3.22 | val loss  2.98
# | epoch   3 | [ 8799/17945] | ms/batch 403.54 | loss  2.81 | val loss  2.98
# | epoch   3 | [ 8999/17945] | ms/batch 400.91 | loss  3.14 | val loss  3.02
# | epoch   3 | [ 9199/17945] | ms/batch 403.40 | loss  3.29 | val loss  3.04
# | epoch   3 | [ 9399/17945] | ms/batch 404.29 | loss  3.02 | val loss  3.02
# | epoch   3 | [ 9599/17945] | ms/batch 403.63 | loss  2.96 | val loss  2.98
# | epoch   3 | [ 9799/17945] | ms/batch 405.00 | loss  3.06 | val loss  3.02
# | epoch   3 | [ 9999/17945] | ms/batch 403.73 | loss  3.01 | val loss  2.98
# | epoch   3 | [10199/17945] | ms/batch 402.42 | loss  3.25 | val loss  3.03
# | epoch   3 | [10399/17945] | ms/batch 402.16 | loss  3.09 | val loss  3.01
# | epoch   3 | [10599/17945] | ms/batch 404.59 | loss  3.39 | val loss  3.01
# | epoch   3 | [10799/17945] | ms/batch 400.19 | loss  2.99 | val loss  3.01
# | epoch   3 | [10999/17945] | ms/batch 402.76 | loss  3.37 | val loss  3.06
# | epoch   3 | [11199/17945] | ms/batch 404.23 | loss  3.05 | val loss  2.98
# | epoch   3 | [11399/17945] | ms/batch 403.23 | loss  3.06 | val loss  3.01
# | epoch   3 | [11599/17945] | ms/batch 404.77 | loss  3.28 | val loss  3.02
# | epoch   3 | [11799/17945] | ms/batch 406.24 | loss  2.97 | val loss  3.04
# | epoch   3 | [11999/17945] | ms/batch 402.52 | loss  2.87 | val loss  2.98
# | epoch   3 | [12199/17945] | ms/batch 403.72 | loss  3.19 | val loss  3.05
# | epoch   3 | [12399/17945] | ms/batch 403.16 | loss  3.30 | val loss  3.07
# | epoch   3 | [12599/17945] | ms/batch 405.17 | loss  3.03 | val loss  2.98
# | epoch   3 | [12799/17945] | ms/batch 404.35 | loss  3.14 | val loss  3.02
# | epoch   3 | [12999/17945] | ms/batch 410.91 | loss  3.17 | val loss  3.02
# | epoch   3 | [13199/17945] | ms/batch 402.60 | loss  3.18 | val loss  2.98
# | epoch   3 | [13399/17945] | ms/batch 402.95 | loss  3.33 | val loss  3.00
# | epoch   3 | [13599/17945] | ms/batch 402.59 | loss  3.48 | val loss  3.01
# | epoch   3 | [13799/17945] | ms/batch 403.45 | loss  3.34 | val loss  3.00
# | epoch   3 | [13999/17945] | ms/batch 403.32 | loss  2.73 | val loss  3.01
# | epoch   3 | [14199/17945] | ms/batch 402.87 | loss  3.14 | val loss  2.97
# | epoch   3 | [14399/17945] | ms/batch 404.31 | loss  3.42 | val loss  2.99
# | epoch   3 | [14599/17945] | ms/batch 402.77 | loss  3.26 | val loss  3.03
# | epoch   3 | [14799/17945] | ms/batch 404.18 | loss  3.38 | val loss  3.01
# | epoch   3 | [14999/17945] | ms/batch 403.65 | loss  3.29 | val loss  3.05
# | epoch   3 | [15199/17945] | ms/batch 402.73 | loss  3.02 | val loss  3.02
# | epoch   3 | [15399/17945] | ms/batch 403.29 | loss  3.15 | val loss  3.02
# | epoch   3 | [15599/17945] | ms/batch 405.30 | loss  3.36 | val loss  3.05
# | epoch   3 | [15799/17945] | ms/batch 403.67 | loss  2.82 | val loss  3.00
# | epoch   3 | [15999/17945] | ms/batch 403.92 | loss  3.13 | val loss  3.02
# | epoch   3 | [16199/17945] | ms/batch 401.25 | loss  3.21 | val loss  2.97
# | epoch   3 | [16399/17945] | ms/batch 397.39 | loss  2.96 | val loss  3.02
# | epoch   3 | [16599/17945] | ms/batch 401.41 | loss  3.22 | val loss  3.02
# | epoch   3 | [16799/17945] | ms/batch 399.59 | loss  3.40 | val loss  3.05
# | epoch   3 | [16999/17945] | ms/batch 400.77 | loss  3.41 | val loss  3.01
# | epoch   3 | [17199/17945] | ms/batch 396.90 | loss  2.96 | val loss  2.99
# | epoch   3 | [17399/17945] | ms/batch 402.55 | loss  3.44 | val loss  2.96
# | epoch   3 | [17599/17945] | ms/batch 404.90 | loss  3.13 | val loss  3.01
# | epoch   3 | [17799/17945] | ms/batch 403.09 | loss  3.56 | val loss  3.00
# | epoch   4 | [  199/17945] | ms/batch 402.89 | loss  3.32 | val loss  3.00
# | epoch   4 | [  399/17945] | ms/batch 400.96 | loss  3.41 | val loss  3.05
# | epoch   4 | [  599/17945] | ms/batch 399.43 | loss  3.56 | val loss  2.98
# | epoch   4 | [  799/17945] | ms/batch 402.04 | loss  3.13 | val loss  3.03
# | epoch   4 | [  999/17945] | ms/batch 403.74 | loss  3.42 | val loss  2.99
# | epoch   4 | [ 1199/17945] | ms/batch 402.34 | loss  3.12 | val loss  3.06
# | epoch   4 | [ 1399/17945] | ms/batch 402.19 | loss  3.03 | val loss  3.04
# | epoch   4 | [ 1599/17945] | ms/batch 402.64 | loss  3.32 | val loss  2.99
# | epoch   4 | [ 1799/17945] | ms/batch 400.09 | loss  3.15 | val loss  3.03
# | epoch   4 | [ 1999/17945] | ms/batch 401.39 | loss  3.24 | val loss  3.04
# | epoch   4 | [ 2199/17945] | ms/batch 401.16 | loss  3.01 | val loss  3.04
# | epoch   4 | [ 2399/17945] | ms/batch 401.40 | loss  3.49 | val loss  3.07
# | epoch   4 | [ 2599/17945] | ms/batch 401.71 | loss  3.16 | val loss  2.99
# | epoch   4 | [ 2799/17945] | ms/batch 401.69 | loss  3.16 | val loss  3.05
# | epoch   4 | [ 2999/17945] | ms/batch 400.60 | loss  2.67 | val loss  3.01
# | epoch   4 | [ 3199/17945] | ms/batch 397.52 | loss  3.44 | val loss  3.07
# | epoch   4 | [ 3399/17945] | ms/batch 401.42 | loss  3.09 | val loss  3.01
# | epoch   4 | [ 3599/17945] | ms/batch 401.21 | loss  3.28 | val loss  3.02
# | epoch   4 | [ 3799/17945] | ms/batch 401.66 | loss  3.02 | val loss  3.00
# | epoch   4 | [ 3999/17945] | ms/batch 401.58 | loss  3.31 | val loss  3.00
# | epoch   4 | [ 4199/17945] | ms/batch 401.17 | loss  3.25 | val loss  3.01
# | epoch   4 | [ 4399/17945] | ms/batch 402.16 | loss  3.35 | val loss  3.02
# | epoch   4 | [ 4599/17945] | ms/batch 400.43 | loss  3.22 | val loss  3.01
# | epoch   4 | [ 4799/17945] | ms/batch 400.33 | loss  3.21 | val loss  2.99
# | epoch   4 | [ 4999/17945] | ms/batch 401.23 | loss  3.25 | val loss  3.04
# | epoch   4 | [ 5199/17945] | ms/batch 399.87 | loss  3.47 | val loss  3.00
# | epoch   4 | [ 5399/17945] | ms/batch 402.03 | loss  3.20 | val loss  3.01
# | epoch   4 | [ 5599/17945] | ms/batch 405.14 | loss  3.00 | val loss  3.03
# | epoch   4 | [ 5799/17945] | ms/batch 403.71 | loss  3.26 | val loss  3.04
# | epoch   4 | [ 5999/17945] | ms/batch 402.98 | loss  3.62 | val loss  2.99
# | epoch   4 | [ 6199/17945] | ms/batch 402.58 | loss  2.97 | val loss  3.04
# | epoch   4 | [ 6399/17945] | ms/batch 401.32 | loss  3.22 | val loss  3.04
# | epoch   4 | [ 6599/17945] | ms/batch 401.39 | loss  3.03 | val loss  3.05
# | epoch   4 | [ 6799/17945] | ms/batch 401.48 | loss  3.19 | val loss  2.98
# | epoch   4 | [ 6999/17945] | ms/batch 401.88 | loss  2.77 | val loss  2.97
# | epoch   4 | [ 7199/17945] | ms/batch 403.70 | loss  3.24 | val loss  2.97
# | epoch   4 | [ 7399/17945] | ms/batch 404.08 | loss  3.18 | val loss  3.06
# | epoch   4 | [ 7599/17945] | ms/batch 415.71 | loss  3.24 | val loss  3.04
# | epoch   4 | [ 7799/17945] | ms/batch 420.76 | loss  3.44 | val loss  3.00
# | epoch   4 | [ 7999/17945] | ms/batch 415.02 | loss  3.28 | val loss  3.03
# | epoch   4 | [ 8199/17945] | ms/batch 403.10 | loss  3.23 | val loss  3.00
# | epoch   4 | [ 8399/17945] | ms/batch 399.86 | loss  3.47 | val loss  3.02
# | epoch   4 | [ 8599/17945] | ms/batch 399.98 | loss  3.28 | val loss  3.03
# | epoch   4 | [ 8799/17945] | ms/batch 401.30 | loss  2.84 | val loss  3.00
# | epoch   4 | [ 8999/17945] | ms/batch 401.38 | loss  3.19 | val loss  3.03
# | epoch   4 | [ 9199/17945] | ms/batch 403.54 | loss  3.34 | val loss  2.99
# | epoch   4 | [ 9399/17945] | ms/batch 402.04 | loss  3.02 | val loss  3.03
# | epoch   4 | [ 9599/17945] | ms/batch 400.70 | loss  2.99 | val loss  3.00
# | epoch   4 | [ 9799/17945] | ms/batch 403.10 | loss  3.11 | val loss  3.07
# | epoch   4 | [ 9999/17945] | ms/batch 401.33 | loss  3.04 | val loss  2.99
# | epoch   4 | [10199/17945] | ms/batch 401.41 | loss  3.25 | val loss  3.04
# | epoch   4 | [10399/17945] | ms/batch 401.33 | loss  3.08 | val loss  3.06
# | epoch   4 | [10599/17945] | ms/batch 399.37 | loss  3.39 | val loss  3.05
# | epoch   4 | [10799/17945] | ms/batch 397.25 | loss  2.99 | val loss  3.03
# | epoch   4 | [10999/17945] | ms/batch 401.85 | loss  3.37 | val loss  3.06
# | epoch   4 | [11199/17945] | ms/batch 400.87 | loss  3.07 | val loss  3.03
# | epoch   4 | [11399/17945] | ms/batch 401.94 | loss  3.10 | val loss  3.03
# | epoch   4 | [11599/17945] | ms/batch 402.15 | loss  3.26 | val loss  3.06
# | epoch   4 | [11799/17945] | ms/batch 403.07 | loss  2.95 | val loss  2.97
# | epoch   4 | [11999/17945] | ms/batch 400.79 | loss  2.96 | val loss  3.00
# | epoch   4 | [12199/17945] | ms/batch 402.59 | loss  3.18 | val loss  3.07
# | epoch   4 | [12399/17945] | ms/batch 403.29 | loss  3.34 | val loss  3.03
# | epoch   4 | [12599/17945] | ms/batch 405.27 | loss  3.07 | val loss  2.99
# | epoch   4 | [12799/17945] | ms/batch 403.47 | loss  3.17 | val loss  3.03
# | epoch   4 | [12999/17945] | ms/batch 407.38 | loss  3.17 | val loss  3.04
# | epoch   4 | [13199/17945] | ms/batch 402.48 | loss  3.20 | val loss  2.99
# | epoch   4 | [13399/17945] | ms/batch 400.83 | loss  3.33 | val loss  3.00
# | epoch   4 | [13599/17945] | ms/batch 402.25 | loss  3.45 | val loss  3.03
# | epoch   4 | [13799/17945] | ms/batch 407.26 | loss  3.34 | val loss  3.00
# | epoch   4 | [13999/17945] | ms/batch 401.77 | loss  2.69 | val loss  3.05
# | epoch   4 | [14199/17945] | ms/batch 403.00 | loss  3.19 | val loss  2.99
# | epoch   4 | [14399/17945] | ms/batch 403.56 | loss  3.41 | val loss  3.03
# | epoch   4 | [14599/17945] | ms/batch 403.27 | loss  3.29 | val loss  2.99
# | epoch   4 | [14799/17945] | ms/batch 403.24 | loss  3.36 | val loss  3.02
# | epoch   4 | [14999/17945] | ms/batch 402.20 | loss  3.25 | val loss  2.99
# | epoch   4 | [15199/17945] | ms/batch 401.81 | loss  3.01 | val loss  3.04
# | epoch   4 | [15399/17945] | ms/batch 401.65 | loss  3.16 | val loss  3.03
# | epoch   4 | [15599/17945] | ms/batch 404.04 | loss  3.33 | val loss  3.01
# | epoch   4 | [15799/17945] | ms/batch 402.67 | loss  2.86 | val loss  3.00
# | epoch   4 | [15999/17945] | ms/batch 403.41 | loss  3.10 | val loss  3.04
# | epoch   4 | [16199/17945] | ms/batch 399.90 | loss  3.21 | val loss  3.02
# | epoch   4 | [16399/17945] | ms/batch 399.19 | loss  2.99 | val loss  3.02
# | epoch   4 | [16599/17945] | ms/batch 402.67 | loss  3.21 | val loss  3.04
# | epoch   4 | [16799/17945] | ms/batch 400.43 | loss  3.42 | val loss  3.05
# | epoch   4 | [16999/17945] | ms/batch 401.25 | loss  3.48 | val loss  3.03
# | epoch   4 | [17199/17945] | ms/batch 398.50 | loss  3.00 | val loss  3.02
# | epoch   4 | [17399/17945] | ms/batch 402.09 | loss  3.45 | val loss  2.98
# | epoch   4 | [17599/17945] | ms/batch 406.05 | loss  3.10 | val loss  3.01
# | epoch   4 | [17799/17945] | ms/batch 406.62 | loss  3.57 | val loss  3.05

# %% [markdown]
# ## Evaluate

# %%
from rouge_score import rouge_scorer
from rouge_score import scoring

class RougeScore:
    '''
    mostly from https://github.com/google-research/text-to-text-transfer-transformer/blob/master/t5/evaluation/metrics.py 
    '''
    
    def __init__(self, score_keys=None)-> None:
        super().__init__()
        if score_keys is None:  
            self.score_keys = ["rouge1", "rouge2", "rougeLsum"]
        
        self.scorer = rouge_scorer.RougeScorer(self.score_keys)
        self.aggregator = scoring.BootstrapAggregator()
        
        
    @staticmethod
    def prepare_summary(summary):
            # Make sure the summary is not bytes-type
            # Add newlines between sentences so that rougeLsum is computed correctly.
            summary = summary.replace(" . ", " .\n")
            return summary
    
    def __call__(self, target, prediction):
        """Computes rouge score.''
        Args:
        targets: string
        predictions: string
        """

        target = self.prepare_summary(target)
        prediction = self.prepare_summary(prediction)
        
        self.aggregator.add_scores(self.scorer.score(target=target, prediction=prediction))

        return 
    
    def reset_states(self):
        self.rouge_list = []

    def result(self):
        result = self.aggregator.aggregate()
        
        for key in self.score_keys:
            score_text = "%s = %.2f, 95%% confidence [%.2f, %.2f]"%(
                key,
                result[key].mid.fmeasure*100,
                result[key].low.fmeasure*100,
                result[key].high.fmeasure*100
            )
            print(score_text)
        
        return {key: result[key].mid.fmeasure*100 for key in self.score_keys}

# %%
rouge_score = RougeScore()
predictions = []
for i, (input_ids, attention_mask, y) in enumerate(test_loader):
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)
    y = y.to(device)
        
    summaries = model.generate(input_ids=input_ids, attention_mask=attention_mask)
    pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summaries]
    real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in y]
    for pred_sent, real_sent in zip(pred, real):
        rouge_score(pred_sent, real_sent)
        predictions.append(str("pred sentence: " + pred_sent + "\n\n real sentence: " + real_sent))
    if i > 40:
        break
    
rouge_score.result()
# Out:
# rouge1 = 25.95, 95% confidence [25.37, 26.58]
# rouge2 = 7.55, 95% confidence [7.15, 7.92]
# rougeLsum = 14.76, 95% confidence [14.40, 15.09]
# {'rouge1': 25.953370416274623,
#  'rouge2': 7.5470369582583405,
#  'rougeLsum': 14.763113105472748}

# %%
for pred in predictions[:10]:
    print("------")
    print(pred)
    print("------")
# Out:
# ------
# pred sentence: flugzeugzeuge, ob ein der schrumpfenpfende platz in sicherheit gefährdet hat. cynthia corbertt, forscherin, krachenden zoll, sagt, dass es sei, wie schnell passagiere ein fluggesellschaften hat, sagt er. faa für eine humane faktoren, der bei einigen giere in rückenlehne, während eine behandlung der gesundheit und sicherheit, aber keine mind mindestestmaßmaße auf raum und nahrungsgruppe. ernsteren. viele flugflugzeugen. charlie leochacorcorbertt die kosten von 31 zolllen, fußußußernnsterstersteren problemen, aber die detroit news,, hat die
#
#  real sentence: experten bezweifeln, ob überfüllte flugzeuge passagiere gefährden. die us-verbraucherberatungsgruppe sagt, dass mindestabstände vorgeschrieben werden müssen. sicherheitstests in flugzeugen mit mehr beinfreiheit als von fluggesellschaften angeboten, werden durchgeführt.
# ------
# ------
# pred sentence: rahul kumar, 17, kletterte in das löwengehehehege in ahmedabad und rannte auf die tiere. der berauschte, er hätte eine gute chance chance" gegen die raubtiere, schrie, als er nach dem kamla nehrte gerettet werden. es sei betrunken gewesen, als sie töte und schschrie. herr kubert zoos er schürte, dass er in den zweiten wassergräben. er sagt, dass sie die löte. "wir haben ihn ihn einholen und herausbringen konnte er sich auf den zaun des geheheges schließt, als die trutruse, wie er auf lölö
#
#  real sentence: betrunkener teenager kletterte in löwengehege eines zoos in westindien: rahul kumar, 17, lief auf tiere zu und schrie: "heute töte ich einen löwen!" glücklicherweise stürzte er in einen wassergraben, bevor er die löwen erreichte und wurde gerettet.
# ------
# ------
# pred sentence: dman hat einen neuen vertrag bei nottingham forest. freedman steht kurz davor, seit er stuart pearce abgelöst hat. forest 's eigentum hat ein versuch auf den play-off-plätzen unternommen, um freidman einen spielzeiten zu sichern. dougie freedam hat eine kühnen versuch im februar ersetzte, aber in den wochen abgesprungen, um freedmen. die arbeit am city ground hat kultheld stuart Pearce ersetzte und arbeit. hat sich zufrieden mit seiner arbeit hat forest zu einigen. die clubbebesitzer ist zufrieden mit seinem versuch, während hat, aber aber in die nächsten beiden spielspielspielzeitenzeiten zu gesichertn. eigetum nicht spielzeit zu sicher sichern, um
#
#  real sentence: nottingham forest steht kurz vor der vertragsverlängerung von dougie freedman, der im februar die nachfolge des ehemaligen managers stuart pearce angetreten hatte und den club seitdem auf den neunten tabellenplatz geführt hat.
# ------
# ------
# pred sentence: stefano rettet in spanien, chadli: "es gibt viele europäische klubs, die ihm auf der spur sind. neto tvv-torentina-müter neto: es gab eine mündliche juventus anzuschließen, aber sein agent hat noch keine entscheidung über seine zukunft getroffen. die stürmt, dass neto eine vereinbarung getroffen hatte, er ccc. er sagt, dass er einen schritt in der märz auf höchsten schritt, die an an net neto, die er eine auswahl von gazzlubs auf der schritten getroffen haben. real madrid hat, dass die ees stört, ra-teuereuers auf höchstem niveau.
#
#  real sentence: fiorentina-torhüter neto wurde mit liverpool und arsenal in verbindung gebracht. neto kam 2011 vom brasilianischen erstligisten atletico paranaense zu fiorentina und wird laut seinem agenten auch von psg und spanischen clubs gesucht.
# ------
# ------
# pred sentence: kardashian-frauen für "20 / 20" sprechen, wie abc news sagt, dass sie bruce stehlen werden werden. diane sawyer, 65, wird am freitag, 24. april, in einem "weitreichenden" interview interview mit sawyer für eine sonderausgabe gesprochen. es wird am montag mit einem jahrzehnte alten jahren schweigen hormontherapie unterzogen. er sagt, er begannte abc, als er sich während er er auftauchtete. innerhalb des jahres abragel, kündigte eigen zu machen. die olympionike und reality-tv-star, adam s iiien, wenn er die hormonhormonhormontherapie zu eige
#
#  real sentence: das interview mit dem reality-tv-star, 69, wird am freitag, den 24. april ausgestrahlt, inmitten anhaltender spekulationen über seinen wechsel zu einer frau und nach seiner verwicklung in einen tödlichen autounfall im februar. das interview wird auch einer von diane sawyers ersten fernsehauftritten nach dem plötzlichen tod ihres mannes im vergangenen jahr sein.
# ------
# ------
# pred sentence: s schwein aus dem kleinen pool ziehen. die besatzung von schwimmmmbecken war ins wasser, stürzte, als die tiertiertiere schwammbadwasser zu ziehen, um es aus pool zu zieht. "einmal anwesend, das in einem unerwarteten ringwood, hampshire, zog. schwete sich mit ihm einen spaziergang durch den tierrettungsteams. die schwschwein, um die an anruf zu einem pferd ruf zu zogen. "estern hat die feuerfeuerwehrleuten, schwinen und schwimimmen gerettet werden mussten. feuerwehrwehrleute forderte die anwesenheit rettete das tieren und eine spezialeinheit der schw
#
#  real sentence: riesenschwein fiel in den swimmingpool seines hauses in ringwood, hampshire. es bedurfte der anstrengungen eines teams von feuerwehrleuten, um es aus dem wasser zu ziehen. auch ein eigensinniges pferd musste aus einem swimmingpool in sussex gerettet werden.
# ------
# ------
# pred sentence: bbc-radiosradio hörte in den letzten drei monaten des jahres 2014 zehnt weniger als ein jahren, als die hörer durchschnittlich 11,6 stunden pro woche. die menschen hören, ist auf den niedrigsten stand aller stand aller zeiten. es hörten die zeit des sitzungsrates, die die einschaltquoten hören. quellen machten für den abwärtswärtstrend, wenn apple seinen seit langem kollege zahlen. er sagt: "es, dass eh und hört, aber viel kürzer zu hörenhören, aber die stundenstunden hört. zeit, die zahlen verbrachte, dass die kalte, wenn er jahrzehnte zahlen, aber stunden hören zahlen werden, während er der zeit
#
#  real sentence: in den letzten drei monaten des jahres 2014 verbrachte der durchschnittliche hörer zehn stunden pro woche mit tuning. das waren 14% weniger als zehn jahre zuvor, als die menschen 11,6 stunden lang einschalteten. der bbc trust hat firmen den weg geebnet, sich in einem product-placement-experiment in lifestyleprogramme auf dem world news-kanal einzukaufen. zum beispiel könnten verlage dafür bezahlen, dass ihre bücher auf talking books rezensiert werden. der bbc trust wird das programm in einem jahr überprüfen.
# ------
# ------
# pred sentence: tanner in der originalserie - als kürzlich verwitwete mutter von drei jungen d.j. der serie wird in der serie wurde von 1987 bis 1995 bis 1995 ausgestrahlt. die älteste tochter d sein, als es ist ist, ist die kumpel zu kimmel. tas beste freundin bob kimmy gib gib gibbler verkörperte netflixlix mit, die daß. sie sagt, dass die störte, teilte die serie wird. der türzte. sstannianniannienen, die die jungen zu haus", sagte, er, während der sonne, sagete stephanie und lori loughlinin töchtchter verkörpern. er
#
#  real sentence: die show werde mit einem einstündigen special zurückkehren, gefolgt von einem spin-off, sagte star john stamos, der die show am montagabend auf "jimmy kimmel live" ankündigte.
# ------
# ------
# pred sentence: evans kritisiert die frauen im sport ohne gewinner. die snooker und mutter seines lebens ist eine gewinnerin. doherty, der 1997 den wm-qualifikationsspiel in ponds fürgegnerin an den seilen hatte. es war ein gnädigeriger doherherherin an der ex-champion und holty und buchmachermacher, die die teilnahme während ihrer landandty. er besiegte die spielerin. april neben 127 männliche spieler in der weltmeistermeister erlöschte den ersten frame mit 10: 8-titeltiteln, bevor sie sich am 18. apagne hat, erlitte. krikrity zu einem schrecken seine
#
#  real sentence: reanne evans traf in der wm-qualifikation auf ken doherty. doherty gewann 1997 die weltmeisterschaft. evans verlor den ersten frame 71-15 gegen doherty. doch der gebürtige dudley kämpfte sich zurück und führte 4-3. ken doherty gelang es jedoch, einen packenden wettkampf mit 10-8 zu beenden.
# ------
# ------
# pred sentence: san-sule, 22, wurde zu neun jahren verurteilt. ahmed saleh, 22,, wurde für vier jahre und neun monate in den wohnungen des märz. die mädchen wurde von der bande, 21, genannt genannt, und opfer genommen. es wird von 2009 bis 2014 missbraucht und verwandter der angeklagten ereigneten sich in sozialen medien lockten, oxfordford crown court wurde angeklagt. sie schuldig. die bande und hat errichtete sich in der sexuell zu haftstrafen ins visier genommen, dass die männer wurden ins fußballverein zu haftestrafe haft verurteilen. er wurde entschied, dass sie ssulule
#
#  real sentence: wegen sexuellen missbrauchs von kindern muss die bande insgesamt 31 jahre ins gefängnis. die taten ereigneten sich in autos, wäldern oder in den wohnungen der angeklagten in banbury. opfer wurden zu partys gelockt, die über soziale medien organisiert wurden, und dann missbraucht. mädchen im alter zwischen 13 und 16 jahren wurden von der bande zwischen 2009 und 2014 ausgebeutet.
# ------

# %%
result_path = "../data/result_german.txt"
for pred in predictions:
    with open(result_path, "a") as file:
        file.write(pred + "\n")

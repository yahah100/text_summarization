# %% [markdown]
# # German Text Summary with the tranlated CNN Daily Mail Dataset
# and T5 from Huggingface Pytorch

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
import torch
import re
import time

# %%
BATCH_SIZE = 16

SHUFFEL_SIZE = 1024

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate = 3e-5

EPOCHS = 5

log_interval = 200

# %%
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Define Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained('t5-small')
model = T5ForConditionalGeneration.from_pretrained('t5-small').to(device)

task_specific_params = model.config.task_specific_params
if task_specific_params is not None:
    model.config.update(task_specific_params.get("summarization", {}))
    

optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.0001)

# %%
model.config.prefix
# Out:
# 'summarize: '

# %% [markdown]
# ## Read the tranlated German Dataset

# %%
def get_translated_ds(name):
    article_path = "../data/%s/articles_german" % name
    highlights_path = "../data/%s/highlights_german" % name

    articles = [x.rstrip() for x in open(article_path).readlines()]
    highlights = [x.rstrip() for x in open(highlights_path).readlines()]
    
    assert len(articles) == len(highlights)
    return articles, highlights

# %%
train_x, train_y = get_translated_ds("train")
test_x, test_y = get_translated_ds("test")
val_x, val_y = get_translated_ds("val")

# %% [markdown]
# ## Show some Dataset Example

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(train_x))
    print("\n--------")
    print(train_x[rand_int][:1500])
    print()
    print(train_y[rand_int])
# Out:
# --------
# 94358; Los Angeles, Kalifornien (CNN) - Conan O 'Briens Rückkehr ins Fernsehen am Montagabend blieb nah am üblichen Late-Night-Talkshow-Format und -Set, aber er konnte sich einer Innovation rühmen. "Ich glaube, wir sind die erste Talkshow, die einen Blick auf den Ozean hat", sagte O 'Brien. "Man kann die Salzwasserluft riechen". O 'Brien und Ansager-Sidekick Andy Richter demonstrierten ein weiteres neues Hintergrundmerkmal - einen überdimensionalen Mond, den sie mit einer Fernbedienung über den Himmel bewegen können. Exklusiv: Sehen Sie sich Conans Opener an. Ansonsten gibt es in der einstündigen TBS-Show Schreibtisch, Couch, Sidekick, Band und einen Gast, der für einen Film wirbt, der dem Late-Night-Publikum seit Jahrzehnten vertraut ist. O 'Briens notwendiger Eröffnungsmonolog machte deutlich, dass "gefeuerte" Witze für Conan das sind, was Scheidungswitze für Johnny Carson waren. "Die Leute fragen mich, warum ich die Serie" Conan "genannt habe", sagte er. "Ich habe es so gemacht, dass ich schwerer zu ersetzen wäre". Eine weitere Quelle des Humors für die Debütshow war sein Schritt von der großen NBC "Tonight Show" in einem Senderverbund in die sparsame Welt des einfachen Kabels. "Ich werde ehrlich sein", sagte O 'Brien. "Es ist nicht einfach, eine Late-Night-Show auf einem Kanal ohne viel Geld zu machen und dass die Zuschauer Schwierigkeiten haben, das zu finden. Deshalb habe ich NBC verlassen ". O 'Brien parodierte seine NBC-Entlassung in einem vorproduzierten Eröffnungsse
#
# 94358; Die neue "Conan" -Show folgt einem Format, das den Late-Night-Zuschauern vertraut ist. Witze über die Entlassung und die Arbeit an grundlegenden Kabeln dominierten O 'Briens Debüt. Conans neues Set zeigt eine Meereskulisse und einen ferngesteuerten Mond.
#
# --------
# 173311; Von: Ruth Styles Seit mehr als 22 Jahren Fan von Take That, konnte Mandy Emerson, 44, aus Gateshead ihr Glück kaum fassen, als sie endlich die Chance bekam, Gary Barlow zu treffen. Doch als sie die Fotos des Augenblicks sah, wurde Frau Emerson, die mit gerade einmal 1,80 m die Waage bei 1,70 m gekippt hatte, durch den Anblick ihres weniger schlanken Rahmens gedemütigt. Angestachelt durch das Bild, wiegt sie nun 11 bis 10 Pfund und sagt, sie hoffe, die Sängerin wiederzusehen, um ihre neu schlanke Figur zur Schau zu stellen. Peinlich: Frau Emerson wurde auf diesem Foto von ihr und dem Star von ihrem weniger schmalen Rahmen gedemütigt. Sieht gut aus: Mandy Emerson hat nach einem Treffen mit Gary Barlow fast die Hälfte ihres Körpergewichts verloren. "Ich konnte es nicht glauben, als ich ausgewählt wurde, Gary zu treffen", sagte Frau Emerson. "Als ich aufstand, war alles, woran ich denken konnte, dass mein Traum in Erfüllung ging - und ich sah völlig durcheinander aus, und ich sah auf dem Foto schrecklich aus. Barlow, der im Laufe der Jahre auch mit seinem Gewicht zu kämpfen hatte, filmte The X-Factor in Manchester, als Frau Emerson vorgestellt wurde. "Ich wollte Gary seit 22 Jahren treffen, also war es erstaunlich, ausgewählt zu werden, um ihn endlich zu treffen", fügt sie hinzu. "Aber als ich auf das Bild zurückblickte, war ich aufgebracht über die Art und Weise, wie ich aussah, und es schockierte mich". Emersons Probleme begannen im Alter von 21 Jahren nach der Geburt i
#
# 173311; Mandy Emerson, 44, aus Gateshead, hat die Hälfte ihres Körpergewichts verloren. Die fettleibige Schwiegermutter war entsetzt über das wenig schmeichelhafte Foto mit Gary Barlow. Hatte 22 Jahre auf ein Treffen gewartet, wurde aber von einem wenig schmeichelhaften Schnappschuss am Boden zerstört. Sie ist jetzt von Größe 28 auf Größe 14 gefallen und hat Diabetes besiegt.
#
# --------
# 274282; Von David Kent. Neben Brendan Rodgers erwiesen auch die Liverpool-Legenden Kenny Dalglish und Ian Rush den Opfern der Bombenanschläge von Boston ihre Reverenz. Rodgers legte in der Boylston Street einen Kranz zum Gedenken an die Opfer der Bombenanschläge auf den Boston-Marathon 2013 nieder. Der Manager der Reds wurde auch von John Henry und Linda Pizzuti unterstützt. Der Liverpool-Manager machte sich dann an die Arbeit, als Liverpool an der Harvard University ausgebildet wurde. VIDEO Scrollen Sie nach unten, um zu sehen, wie Brendan Rodgers der Opfer des Bombenanschlags von Boston gedenkt. Brendan Rodgers legt in der Boylston Street einen Kranz zum Gedenken an die Opfer des Bombenanschlags von Boston nieder. Jordan Henderson und Lazar Markovic jagen dem Ball während des Trainings hinterher. Stürmer Daniel Sturridge schirmt den Ball vor Daniel Agger ab, der bei der Niederlage gegen Roma ein Eigentor geschossen hat.Es war die erste Einheit seit dem 1: 0 der Reds gegen Roma am Mittwochabend. Daniel Aggers spätes Eigentor bewies den Unterschied an diesem Abend, aber Rodgers nahm viel Positives aus dem Spiel mit, nicht zuletzt die Leistung von Philippe Coutinho, der sein Gehäuse auflegte, um die Lücke zu füllen, die Luis Suarez hinterlassen hatte. Die einzige wirkliche Sorge für Rodgers kam schon früh, als Fabio Borini mit einer Schulterverletzung aus dem Spiel musste. Die Liverpool-Spieler wurden auf Herz und Nieren geprüft, darunter auch Torhüter Pepe Reina, dessen Zukun
#
# 274282; Liverpool-Boss legt Kranz zum Gedenken an die Opfer der Bombenanschläge von 2013 nieder. Spieler prüften sich im Training an der Harvard University auf Herz und Nieren. Die Reds verloren am Mittwoch 1: 0 gegen Roma, aber Philippe Coutinho beeindruckte. Fabio Borini fällt in der ersten Halbzeit nach einem unglücklichen Sturz mit der Schulter aus.
#
# --------
# 15522; (CNN) - In der Welt der Schmerzmittel wirken Oxycodon und Naloxon wie seltsame Bettgenossen. Oxycodon ist ein starkes Schmerzmittel, während Naloxon verwendet wird, um die Überdosis des Schmerzmittels umzukehren. Am Mittwoch genehmigte die Food and Drug Administration ein Medikament, das beide kombiniert, Targiniq ER. Der Hersteller des Medikaments, Purdue Pharma, sagte, die Kombination solle "Schmerzen lindern und zugleich eine neue Methode einführen, um Missbrauch und Missbrauch abzuschrecken". Oxycodon gehört zu einer Gruppe starker Schmerzmittel - Opioid-Analgetika genannt - zu denen Hydrocodon, Morphium und Hydromorphon gehören. Es sorgt für Schmerzlinderung, indem es an Rezeptoren im Gehirn bindet, die das Schmerzempfinden dämpfen. Warum also mit Naloxon heiraten? Einfach ausgedrückt: Naloxon kann Oxycodon an eben diesen Gehirnrezeptoren lösen und so seine Fähigkeit zur Schmerzlinderung blockieren. Im Falle von Targiniq geschieht dies erst, wenn die Pille zerquetscht wird. Bleibt die Pille intakt, schlummert Naloxon, wodurch Oxycodon seine Arbeit verrichten kann. Die Zulassung eines missbrauchsabschreckenden Schmerzmittels wie Targiniq erscheint angesichts des ausufernden Drogenkonsums in den Vereinigten Staaten willkommen. Laut einem Bericht des International Narcotics Control Board aus dem Jahr 2010 konsumieren die Vereinigten Staaten 83% des weltweiten Oxycodons und 99% des Hydrocodons. 46 Menschen sterben nach Angaben der Centers for Disease Control and Preve
#
# 15522; Die Food and Drug Administration genehmigt Targiniq ER. Medikament lindert Schmerzen und schreckt gleichzeitig vor Missbrauch ab. Suchtexperten befürchten, dass Targiniq noch immer leicht missbraucht werden könnte.
#
# --------
# 186835; Joe Hart dementierte, dass er sich für die Revanche motivieren werde, wenn England im ersten WM-Spiel auf Italien trifft, nachdem ihn Andrea Pirlo bei der EM 2012 mit einem <unk> Panenka <unk> -Elfmeter ausgetrickst hatte. Der italienische Spielmacher stellte das Viertelfinal-Elfmeterschießen auf den Kopf, als er nach einem Fehlpass von Riccardo Montolivo mit einem Seitfallzieher zum 2: 1 traf, während Steven Gerrard und Wayne Rooney beide für England getroffen hatten. Pirlo behauptete, dass ihn der Anblick von Hart, der alles Mögliche auf der Linie tat, ermutigt habe, den Ball über Hart hinweg direkt in die Mitte des Netzes zu befördern, so wie es Antonin Panenka für die Tschechoslowakei im Finale der Europameisterschaft 1976 gegen Westdeutschland geschaffen hatte. Scrollen Sie nach unten für Videos... In sicheren Händen: Joe Hart hat keine Angst vor einem weiteren Elfer von Andrea Pirlo bei der WM. Panenka: Italiens Andrea Pirlo (l.) setzte sich bei der EM 2012 mit einem frechen Chip-Elfer gegen Joe Hart durch. Hart war wiederholt auf seine Linie gesprungen und hatte die Elfmeterschützen angeschrien, um sie zum Toreschießen zu bewegen. "Ich habe meine Entscheidung in letzter Sekunde getroffen, als ich Joe Hart, den englischen Torwart, auf seiner Linie gesehen habe", sagte Pirlo in seiner Autobiografie. Als ich mit meiner Vorbereitung begann, wusste ich noch nicht, was ich tun sollte. Und dann bewegte er sich, und meine Gedanken waren frei. Es war alles improvisiert
#
# 186835; Joe Hart hat keine Angst vor einem Elfer von Andrea Pirlo bei der Weltmeisterschaft in Brasilien. Der Italiener täuschte ihn mit einem frechen Panenka, als Italien England bei der EM 2012 im Elferschießen besiegte. Englands Nr. 1 hat Demut gelernt, nachdem er von Manchester City abgehängt wurde. Hart nimmt nichts als selbstverständlich hin, nachdem er Rob Green bei der WM 2010 nach seinem Heuler gegen die USA seinen Platz verlor.

# %%
import numpy as np
for i in range(5):
    rand_int = np.random.randint(len(test_x))
    print("\n--------")
    print(test_x[rand_int][:1500])
    print()
    print(test_y[rand_int])
# Out:
# --------
# 4381; Eine Frau aus Arizona erlebte eine frühe Osterüberraschung, als sie bei einer Untersuchung im letzten Monat das Bild von Jesus Christus in ihrem Zahnröntgenbild sah. Kym Ackerman sah den Sohn Gottes im Röntgenbild eines ihrer linken Backenzähne, als sie am 25. März zu einer Zahnuntersuchung nach Flagstaff ging. Ackermann, 32, entdeckte das Bild und zeigte es sowohl dem Zahnarzt als auch dem Hygieniker. Blättern Sie nach unten für ein Video. Kym Ackerman sah Jesus auf einem Röntgenbild ihrer Backenzähne, als sie sich in Flagstaff, Arizona, einer zahnärztlichen Untersuchung unterzog. Ackerman, 32, plant, das Röntgenbild zu rahmen und den speziellen Backenzahn und ihren Mund in Zukunft frei von Hohlräumen zu halten. Obwohl der Hygieniker der geheiligten Form zustimmte, war der Zahnarzt wesentlich weniger aufgeregt und "begann, auf meine Zähne zu schauen", erzählte Ackerman der Huffington Post. Sie sagte: "Bei meinem Zahnarzt zeigt der Computer die Röntgenbilder an, sobald sie gemacht werden. "Ich sagte zum Hygieniker:" Das sieht verrückt aus! Siehst du, was ich sehe? " "Meine Mutter starb an Brustkrebs, als ich 17 war, und als ich das sah, dachte ich:" Das ist mein Schutzengel "." Der Zahnarzt hat bei der Untersuchung keine Hohlräume gefunden und Ackerman hat geschworen, ihren Mund und vor allem diesen heiligen Backenzahn gesund zu halten. Außerdem plant sie, das Röntgenbild zu rahmen. Es ist nicht das erste Mal, dass Jesus angeblich in Röntgenform zurückgekehrt ist. Eine
#
# 4381; Kym Ackerman sah Jesus im Röntgenbild des linken Backenzahns beim Zahnarzt in Flagstaff. Ackerman, 32, zeigte den speziellen Zahn sowohl dem Zahnarzt als auch der Hygienikerin. Sie plant, das Röntgenbild zu rahmen und den Backenzahn und ihre Mundhöhle frei zu halten.
#
# --------
# 9925; Der trotzige Stuart McCall forderte die Rangers am Donnerstagabend auf, eine sofortige Reaktion auf die erste Niederlage seiner Amtszeit zu zeigen und den Glauben an den Aufstieg aufrechtzuerhalten. Die Ibrox-Mannschaft kassierte in Palmerston die zweite Saisonniederlage, als Derek Lyle, Gavin Reilly und ein Lee-Wallace-Eigentor den Play-off-Hoffnungen der "Queen of the South" einen enormen Schub gaben. McCall beharrt jedoch darauf, dass das Vertrauen durch das Ausmaß der Niederlage nicht getrübt wird und erwartet, dass seine Spieler beim Heimspiel am Sonntag gegen die Raith Rovers wieder auf die Beine kommen. Stuart McCall drängte die Rangers zu einer sofortigen Reaktion auf die erste Niederlage seiner Amtszeit. Die Ibrox-Mannschaft stürzte in Palmerston zur zweiten Saisonniederlage ab. "Wir haben bereits darüber gesprochen, mit gutem Schwung in die Play-offs zu gehen", sagte McCall. <unk> Heute Abend ist ein Rückschlag, aber wir müssen am Sonntag aufpassen, dass wir keinen weiteren Rückschlag haben, sonst kann es zum Problem werden. Wir werden am Sonntag voll fokussiert sein und die drei Punkte anstreben. "Es wird am Sonntag keinen Vertrauensfaktor geben", kann ich Ihnen versichern. Manchmal wird man geschlagen, und man muss nur die Hände hochhalten und der Opposition Anerkennung zollen. <unk> Ich habe mich über gewisse Dinge gefreut, die zum ersten Tor geführt haben. Ich dachte, es geht uns gut. Ich habe den Jungs gesagt, dass wir einen Schlussstrich ziehen werden. J
#
# 9925; Die Rangers verloren am Donnerstagabend 3: 0 gegen die Königin des Südens. Stuart McCall: "Wir müssen am Sonntag sicherstellen, dass wir keinen weiteren Rückschlag haben, sonst kann es zu einem Problem werden". McCall ist unerschütterlich zuversichtlich, dass die 3: 0-Niederlage die Zuversicht nicht trüben wird.
#
# --------
# 9529; Shay Given hat enthüllt, welche Schmerzen Ruud Gullit immer noch nach seiner Entscheidung hat, ihn für das FA-Cup-Finale 1999 zwischen Newcastle und Manchester United zu brüskieren. Der Nationaltorwart der Republik Irland spielte jede Runde Newcastle <unk> s Lauf, wurde aber zugunsten von Steve Harper für das Wembley-Prunkstück, das von Sir Alex Ferguson 2: 0 gewonnen wurde, fallen gelassen. Einen wirklich erfüllenden Besuch im Nationalstadion hat Given noch nicht erlebt. Shay Given wird für Aston Villa im FA-Cup-Halbfinale am Sonntag in Wembley gegen Liverpool beginnen. Er hat eine FA-Cup-Sieger <unk> medaille von 2011, war aber ein ungewohnter Ersatz für das Finale gegen Stoke mit Joe Hart im Tor. Er will gegen Liverpool Wiedergutmachung betreiben. "Es war schön, Teil des Sieges mit Man City zu sein, aber wenn man nicht spielt, hat es nicht den gleichen Wert", sagte er. Ich weiß ehrlich gesagt nicht, wo meine Medaille ist. <unk> 1999 war ein Schlag ins Gesicht. Werden Sie das wohl jemals überstehen? Das ist nicht einfach. Ruud Gullit hat es mir nicht einmal gesagt, er hat mich von Torwarttrainer Terry Gennoe wissen lassen, dass ich nicht spiele. <unk> Aber man kann im Fußball nicht zurückblicken, man muss nur nach vorne schauen. Ich würde gerne eine Trophäe gewinnen und bei Aston Villa ein bisschen Geschichte schreiben. Der 38-Jährige hat in dieser Saison an allen vier FA-Cup-Spielen von Villa teilgenommen und zwei weiße Laken behalten. Villas Manager Tim Sherwood bes
#
# 9529; Shay Given startet gegen Liverpool im FA Cup einen Tag vor seinem 39. Geburtstag. Tim Sherwood bestätigte die Nachricht, während er sich auf das Halbfinale am Sonntag vorbereitet. Given hat in dieser Legislaturperiode in allen vier FA-Cup-Spielen von Aston Villa gespielt.
#
# --------
# 10996; Chelsea-Trainer Jose Mourinho überschüttete Loic Remy mit Lob, nachdem der Stürmer am Samstag beim 2: 1-Sieg über Stoke seinen zweiten Treffer in Folge erzielt hatte. Remys Tor bedeutete, dass Mourinhos Mannschaft trotz der Verletzung von Diego Costa einen weiteren Schritt in Richtung Titelgewinn in der Premier League mit drei Punkten machte. Costa humpelte zehn Minuten nach seiner Auswechslung zur Halbzeit wegen Achillessehnenproblemen vom Platz und stand im Abseits. Remy erzielte am Samstag im Spiel an der Stamford Bridge den Siegtreffer für Chelsea gegen Stoke. Remys Bedeutung für Chelsea könnte wachsen, da Diego Costa verletzt das Spiel in Stoke verließ. Chelsea-Manager Jose Mourinho lobte die Professionalität und Torgefährlichkeit von Remy. Doch Mourinho weigerte sich, die Bedeutung des Sieges durch die Verletzung schmälern zu lassen und lobte stattdessen Remys Torinstinkt, nachdem der Stürmer auch den entscheidenden Treffer erzielt hatte, als Chelsea Hull im letzten Spiel vor der Länderspielpause 3: 2 besiegte. "Als Eden (Hazard) den Ball aus einem freien Wurf von Asmir Begovic zurückeroberte, sah man sofort, dass Remy sprintete, um das zu erzielen, was ich ein leichtes Tor nenne, aber ich liebe Stürmer, die einfache Tore schießen", sagte Mourinho. "Wenn der Torwart einen unvollständigen Save hat, den Ball über ein tiefes Kreuz angreift, Rebounds holt - ich liebe die einfachen Tore eines Stürmers. Remy (M.) netzte auch noch vor der Länderspielpause zum 1: 0 für C
#
# 10996; Loic Remy erzielte das entscheidende Tor beim 2: 1-Sieg von Chelsea gegen Stoke am Samstag und erzielte auch das letzte Tor beim 3: 2-Sieg von Chelsea in Hull. Jose Mourinho lobte Remy 's Torinstinkt und Professionalität.
#
# --------
# 696; Mehr als 10.000 Australier und Neuseeländer sitzen ehrfurchtsvoll an den Ufern der Halbinsel Gallipoli, als eine feierliche Zeremonie beginnt, um die Ausgräber zu ehren, die dort vor einem Jahrhundert gekämpft und gefallen sind. Anlässlich des 100. Jahrestages der blutigen Landung von Gallipoli hat sich ein riesiges Meer von Pilgern aus beiden Nationen am Gedenkort Anzac versammelt. Der australische Premierminister Tony Abbott, sein neuseeländischer Amtskollege John Key, Prinz Charles und Prinz Harry sind unter den Teilnehmern. Verteidigungsminister Mark Binskin erzählte den Tausenden, die sich dort versammelt hatten, von dem Grauen, dem die Anzacs an dem Tag ausgesetzt waren, als sie vor einem Jahrhundert in der Türkei an Land kamen. "Die ruhige Stille der Morgendämmerung und das sanfte Rauschen der Wellen an diesem Strand wich dem Blitz und Gebrüll der Schüsse über den schmerzhaften Schreien der Verwundeten", sagte er. "Für so viele wäre die aufgehende Sonne an diesem Tag ihr letzter". Ein Dudelsackspieler der australischen Armee salutiert während einer Zeremonie im Morgengrauen anlässlich des 100. Jahrestages der Schlacht von Gallipoli. Als die Morgendämmerung anbrach, versammelten sich Familien von Soldaten, Führern und Besuchern in der Nähe ehemaliger Schlachtfelder und ehren Tausende Australier und Neuseeländer, die im Ersten Weltkrieg in Gallipoli gekämpft haben. In seiner Ansprache an die Tausenden, die am Morgengrauen-Gottesdienst in Gallipoli teilnahmen, sagte
#
# 696; Der Morgengottesdienst in Anzac Cove beginnt, als sich mehr als 10.000 Australier und Neuseeländer zu einer feierlichen Zeremonie versammeln. Tausende nahmen an der Gedenkstätte in Anzac anlässlich des 100. Jahrestages der Landung in Gallipoli teil. Unter den Anwesenden sind auch der australische Premierminister Tony Abbott und sein neuseeländischer Amtskollege John Key. Prinz Charles und Prinz Harry saßen ebenfalls neben den Premierministern beim Morgengottesdienst in Gallipoli. Abbott sagte, die Truppen seien mehr als nur Soldaten geworden, da sie die "Gründungshelden des modernen Australiens" seien.

# %% [markdown]
# ## Define Pytorch Dataset

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, articles, highlights):
        self.x = articles
        self.y = highlights
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index][3:]), max_length=512, return_tensors="pt", pad_to_max_length=True)
        y = tokenizer.encode(self.transfrom(self.y[index][3:]), max_length=150, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1), y.view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
train_ds = MyDataset(train_x, train_y) 
val_ds = MyDataset(val_x, val_y)
test_ds = MyDataset(test_x, test_y)

# %%
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
x, x_mask, y = next(iter(val_loader))
x.shape, x_mask.shape, y.shape
# Out:
# (torch.Size([16, 512]), torch.Size([16, 512]), torch.Size([16, 150]))

# %%
start_time = time.time()
for i in range(100):
    x, x_mask, y = next(iter(val_loader))
elapsed = time.time() - start_time
elapsed
# Out:
# 8.418677568435669

# %% [markdown]
# ## Define Step function

# %%
pad_token_id = tokenizer.pad_token_id
def step(inputs_ids, attention_mask, y):
    y_ids = y[:, :-1].contiguous()
    lm_labels = y[:, 1:].clone()
    lm_labels[y[:, 1:] == pad_token_id] = -100
    output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
    return output[0] # loss

# %% [markdown]
# ## Train

# %%
train_loss = []
val_loss = []
for epoch in range(EPOCHS):
    model.train() 
    start_time = time.time()
    for i, (inputs_ids, attention_mask, y) in enumerate(train_loader):
        inputs_ids = inputs_ids.to(device)
        attention_mask = attention_mask.to(device)
        y = y.to(device)
        
        
        optimizer.zero_grad()
        loss = step(inputs_ids, attention_mask, y)
        train_loss.append(loss.item())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
            
        if (i + 1) % log_interval == 0:
            with torch.no_grad():
                x, x_mask, y = next(iter(val_loader))
                x = x.to(device)
                x_mask = x_mask.to(device)
                y = y.to(device)
                
                v_loss = step(x, x_mask, y)
                v_loss = v_loss.item()
                
                
                elapsed = time.time() - start_time
                print('| epoch {:3d} | [{:5d}/{:5d}] | '
                  'ms/batch {:5.2f} | '
                  'loss {:5.2f} | val loss {:5.2f}'.format(
                    epoch, i, len(train_loader),
                    elapsed * 1000 / log_interval,
                    loss.item(), v_loss))
                start_time = time.time()
                val_loss.append(v_loss)
# Out:
# | epoch   0 | [  199/17945] | ms/batch 403.61 | loss  3.03 | val loss  2.91
# | epoch   0 | [  399/17945] | ms/batch 399.79 | loss  2.92 | val loss  2.81
# | epoch   0 | [  599/17945] | ms/batch 398.31 | loss  3.00 | val loss  2.91
# | epoch   0 | [  799/17945] | ms/batch 399.74 | loss  2.58 | val loss  2.80
# | epoch   0 | [  999/17945] | ms/batch 402.75 | loss  2.81 | val loss  2.83
# | epoch   0 | [ 1199/17945] | ms/batch 402.89 | loss  2.48 | val loss  2.86
# | epoch   0 | [ 1399/17945] | ms/batch 403.91 | loss  2.44 | val loss  2.83
# | epoch   0 | [ 1599/17945] | ms/batch 408.64 | loss  2.60 | val loss  2.90
# | epoch   0 | [ 1799/17945] | ms/batch 402.08 | loss  2.49 | val loss  2.88
# | epoch   0 | [ 1999/17945] | ms/batch 407.34 | loss  2.53 | val loss  2.90
# | epoch   0 | [ 2199/17945] | ms/batch 404.00 | loss  2.33 | val loss  2.86
# | epoch   0 | [ 2399/17945] | ms/batch 407.81 | loss  2.76 | val loss  2.93
# | epoch   0 | [ 2599/17945] | ms/batch 405.31 | loss  2.36 | val loss  2.89
# | epoch   0 | [ 2799/17945] | ms/batch 384.52 | loss  2.43 | val loss  2.93
# | epoch   0 | [ 2999/17945] | ms/batch 383.45 | loss  2.03 | val loss  2.90
# | epoch   0 | [ 3199/17945] | ms/batch 384.14 | loss  2.67 | val loss  2.88
# | epoch   0 | [ 3399/17945] | ms/batch 381.90 | loss  2.44 | val loss  2.93
# | epoch   0 | [ 3599/17945] | ms/batch 381.63 | loss  2.53 | val loss  2.92
# | epoch   0 | [ 3799/17945] | ms/batch 383.80 | loss  2.23 | val loss  2.93
# | epoch   0 | [ 3999/17945] | ms/batch 383.07 | loss  2.45 | val loss  2.95
# | epoch   0 | [ 4199/17945] | ms/batch 383.44 | loss  2.34 | val loss  2.97
# | epoch   0 | [ 4399/17945] | ms/batch 385.62 | loss  2.53 | val loss  2.94
# | epoch   0 | [ 4599/17945] | ms/batch 382.56 | loss  2.46 | val loss  3.02
# | epoch   0 | [ 4799/17945] | ms/batch 383.76 | loss  2.40 | val loss  2.98
# | epoch   0 | [ 4999/17945] | ms/batch 387.37 | loss  2.44 | val loss  2.94
# | epoch   0 | [ 5199/17945] | ms/batch 382.28 | loss  2.59 | val loss  2.96
# | epoch   0 | [ 5399/17945] | ms/batch 384.14 | loss  2.35 | val loss  2.96
# | epoch   0 | [ 5599/17945] | ms/batch 386.00 | loss  2.22 | val loss  3.01
# | epoch   0 | [ 5799/17945] | ms/batch 386.10 | loss  2.42 | val loss  3.04
# | epoch   0 | [ 5999/17945] | ms/batch 384.81 | loss  2.66 | val loss  3.02
# | epoch   0 | [ 6199/17945] | ms/batch 384.10 | loss  2.29 | val loss  3.06
# | epoch   0 | [ 6399/17945] | ms/batch 384.50 | loss  2.43 | val loss  3.02
# | epoch   0 | [ 6599/17945] | ms/batch 385.92 | loss  2.21 | val loss  3.08
# | epoch   0 | [ 6799/17945] | ms/batch 384.90 | loss  2.38 | val loss  3.06
# | epoch   0 | [ 6999/17945] | ms/batch 382.71 | loss  1.96 | val loss  3.08
# | epoch   0 | [ 7199/17945] | ms/batch 388.31 | loss  2.40 | val loss  3.04
# | epoch   0 | [ 7399/17945] | ms/batch 387.78 | loss  2.33 | val loss  3.10
# | epoch   0 | [ 7599/17945] | ms/batch 382.60 | loss  2.42 | val loss  3.07
# | epoch   0 | [ 7799/17945] | ms/batch 384.59 | loss  2.58 | val loss  3.10
# | epoch   0 | [ 7999/17945] | ms/batch 385.84 | loss  2.47 | val loss  3.13
# | epoch   0 | [ 8199/17945] | ms/batch 390.05 | loss  2.41 | val loss  3.10
# | epoch   0 | [ 8399/17945] | ms/batch 385.39 | loss  2.68 | val loss  3.07
# | epoch   0 | [ 8599/17945] | ms/batch 390.67 | loss  2.42 | val loss  3.14
# | epoch   0 | [ 8799/17945] | ms/batch 391.98 | loss  2.16 | val loss  3.14
# | epoch   0 | [ 8999/17945] | ms/batch 393.69 | loss  2.38 | val loss  3.15
# | epoch   0 | [ 9199/17945] | ms/batch 410.05 | loss  2.47 | val loss  3.15
# | epoch   0 | [ 9399/17945] | ms/batch 409.71 | loss  2.28 | val loss  3.20
# | epoch   0 | [ 9599/17945] | ms/batch 404.41 | loss  2.32 | val loss  3.20
# | epoch   0 | [ 9799/17945] | ms/batch 408.07 | loss  2.30 | val loss  3.22
# | epoch   0 | [ 9999/17945] | ms/batch 409.92 | loss  2.21 | val loss  3.21
# | epoch   0 | [10199/17945] | ms/batch 411.96 | loss  2.48 | val loss  3.17
# | epoch   0 | [10399/17945] | ms/batch 412.85 | loss  2.39 | val loss  3.20
# | epoch   0 | [10599/17945] | ms/batch 413.55 | loss  2.51 | val loss  3.32
# | epoch   0 | [10799/17945] | ms/batch 405.98 | loss  2.29 | val loss  3.20
# | epoch   0 | [10999/17945] | ms/batch 409.95 | loss  2.58 | val loss  3.24
# | epoch   0 | [11199/17945] | ms/batch 410.05 | loss  2.31 | val loss  3.27
# | epoch   0 | [11399/17945] | ms/batch 411.01 | loss  2.35 | val loss  3.22
# | epoch   0 | [11599/17945] | ms/batch 410.12 | loss  2.51 | val loss  3.32
# | epoch   0 | [11799/17945] | ms/batch 410.12 | loss  2.19 | val loss  3.31
# | epoch   0 | [11999/17945] | ms/batch 411.23 | loss  2.17 | val loss  3.32
# | epoch   0 | [12199/17945] | ms/batch 411.83 | loss  2.47 | val loss  3.35
# | epoch   0 | [12399/17945] | ms/batch 412.94 | loss  2.55 | val loss  3.35
# | epoch   0 | [12599/17945] | ms/batch 413.68 | loss  2.32 | val loss  3.39
# | epoch   0 | [12799/17945] | ms/batch 415.10 | loss  2.40 | val loss  3.36
# | epoch   0 | [12999/17945] | ms/batch 413.08 | loss  2.42 | val loss  3.33
# | epoch   0 | [13199/17945] | ms/batch 409.95 | loss  2.46 | val loss  3.50
# | epoch   0 | [13399/17945] | ms/batch 409.47 | loss  2.61 | val loss  3.45
# | epoch   0 | [13599/17945] | ms/batch 405.80 | loss  2.80 | val loss  3.42
# | epoch   0 | [13799/17945] | ms/batch 410.35 | loss  2.62 | val loss  3.50
# | epoch   0 | [13999/17945] | ms/batch 410.89 | loss  2.11 | val loss  3.44
# | epoch   0 | [14199/17945] | ms/batch 409.90 | loss  2.45 | val loss  3.49
# | epoch   0 | [14399/17945] | ms/batch 405.26 | loss  2.69 | val loss  3.49
# | epoch   0 | [14599/17945] | ms/batch 409.60 | loss  2.57 | val loss  3.51
# | epoch   0 | [14799/17945] | ms/batch 409.12 | loss  2.64 | val loss  3.48
# | epoch   0 | [14999/17945] | ms/batch 410.50 | loss  2.63 | val loss  3.50
# | epoch   0 | [15199/17945] | ms/batch 410.53 | loss  2.29 | val loss  3.55
# | epoch   0 | [15399/17945] | ms/batch 411.20 | loss  2.56 | val loss  3.55
# | epoch   0 | [15599/17945] | ms/batch 409.50 | loss  2.69 | val loss  3.53
# | epoch   0 | [15799/17945] | ms/batch 407.46 | loss  2.26 | val loss  3.63
# | epoch   0 | [15999/17945] | ms/batch 410.79 | loss  2.44 | val loss  3.59
# | epoch   0 | [16199/17945] | ms/batch 409.18 | loss  2.50 | val loss  3.57
# | epoch   0 | [16399/17945] | ms/batch 408.61 | loss  2.30 | val loss  3.64
# | epoch   0 | [16599/17945] | ms/batch 413.95 | loss  2.54 | val loss  3.61
# | epoch   0 | [16799/17945] | ms/batch 407.94 | loss  2.75 | val loss  3.63
# | epoch   0 | [16999/17945] | ms/batch 392.74 | loss  2.82 | val loss  3.66
# | epoch   0 | [17199/17945] | ms/batch 383.17 | loss  2.37 | val loss  3.60
# | epoch   0 | [17399/17945] | ms/batch 391.45 | loss  2.78 | val loss  3.67
# | epoch   0 | [17599/17945] | ms/batch 410.57 | loss  2.57 | val loss  3.70
# | epoch   0 | [17799/17945] | ms/batch 410.81 | loss  2.89 | val loss  3.71
# | epoch   1 | [  199/17945] | ms/batch 408.00 | loss  2.73 | val loss  3.48
# | epoch   1 | [  399/17945] | ms/batch 407.01 | loss  2.74 | val loss  3.59
# | epoch   1 | [  599/17945] | ms/batch 401.85 | loss  2.93 | val loss  3.57
# | epoch   1 | [  799/17945] | ms/batch 407.77 | loss  2.60 | val loss  3.64
# | epoch   1 | [  999/17945] | ms/batch 409.43 | loss  2.82 | val loss  3.61
# | epoch   1 | [ 1199/17945] | ms/batch 409.20 | loss  2.52 | val loss  3.74
# | epoch   1 | [ 1399/17945] | ms/batch 405.63 | loss  2.46 | val loss  3.66
# | epoch   1 | [ 1599/17945] | ms/batch 386.06 | loss  2.69 | val loss  3.74
# | epoch   1 | [ 1799/17945] | ms/batch 397.03 | loss  2.58 | val loss  3.78
# | epoch   1 | [ 1999/17945] | ms/batch 383.79 | loss  2.65 | val loss  3.74
# | epoch   1 | [ 2199/17945] | ms/batch 387.66 | loss  2.45 | val loss  3.74
# | epoch   1 | [ 2399/17945] | ms/batch 386.21 | loss  2.91 | val loss  3.74
# | epoch   1 | [ 2599/17945] | ms/batch 413.79 | loss  2.53 | val loss  3.84
# | epoch   1 | [ 2799/17945] | ms/batch 407.31 | loss  2.60 | val loss  3.78
# | epoch   1 | [ 2999/17945] | ms/batch 407.15 | loss  2.19 | val loss  3.89
# | epoch   1 | [ 3199/17945] | ms/batch 402.63 | loss  2.83 | val loss  3.86
# | epoch   1 | [ 3399/17945] | ms/batch 406.21 | loss  2.65 | val loss  3.83
# | epoch   1 | [ 3599/17945] | ms/batch 409.80 | loss  2.85 | val loss  3.85
# | epoch   1 | [ 3799/17945] | ms/batch 406.79 | loss  2.44 | val loss  3.89
# | epoch   1 | [ 3999/17945] | ms/batch 410.35 | loss  2.69 | val loss  3.93
# | epoch   1 | [ 4199/17945] | ms/batch 410.20 | loss  2.64 | val loss  3.83
# | epoch   1 | [ 4399/17945] | ms/batch 391.29 | loss  2.78 | val loss  3.89
# | epoch   1 | [ 4599/17945] | ms/batch 381.55 | loss  2.71 | val loss  3.97
# | epoch   1 | [ 4799/17945] | ms/batch 381.39 | loss  2.67 | val loss  3.92
# | epoch   1 | [ 4999/17945] | ms/batch 384.19 | loss  2.77 | val loss  3.91
# | epoch   1 | [ 5199/17945] | ms/batch 383.98 | loss  2.94 | val loss  3.96
# | epoch   1 | [ 5399/17945] | ms/batch 382.51 | loss  2.65 | val loss  3.98
# | epoch   1 | [ 5599/17945] | ms/batch 384.37 | loss  2.49 | val loss  3.91
# | epoch   1 | [ 5799/17945] | ms/batch 385.36 | loss  2.73 | val loss  3.96
# | epoch   1 | [ 5999/17945] | ms/batch 385.77 | loss  3.04 | val loss  3.95
# | epoch   1 | [ 6199/17945] | ms/batch 388.01 | loss  2.53 | val loss  3.98
# | epoch   1 | [ 6399/17945] | ms/batch 384.48 | loss  2.75 | val loss  3.98
# | epoch   1 | [ 6599/17945] | ms/batch 385.63 | loss  2.50 | val loss  3.98
# | epoch   1 | [ 6799/17945] | ms/batch 382.44 | loss  2.66 | val loss  4.02
# | epoch   1 | [ 6999/17945] | ms/batch 384.29 | loss  2.30 | val loss  3.98
# | epoch   1 | [ 7199/17945] | ms/batch 384.26 | loss  2.73 | val loss  3.97
# | epoch   1 | [ 7399/17945] | ms/batch 388.94 | loss  2.61 | val loss  3.99
# | epoch   1 | [ 7599/17945] | ms/batch 386.80 | loss  2.72 | val loss  3.92
# | epoch   1 | [ 7799/17945] | ms/batch 388.57 | loss  2.94 | val loss  3.99
# | epoch   1 | [ 7999/17945] | ms/batch 389.46 | loss  2.75 | val loss  4.13
# | epoch   1 | [ 8199/17945] | ms/batch 390.48 | loss  2.75 | val loss  4.04
# | epoch   1 | [ 8399/17945] | ms/batch 382.90 | loss  2.98 | val loss  4.01
# | epoch   1 | [ 8599/17945] | ms/batch 385.82 | loss  2.76 | val loss  4.07
# | epoch   1 | [ 8799/17945] | ms/batch 386.00 | loss  2.48 | val loss  4.10
# | epoch   1 | [ 8999/17945] | ms/batch 386.33 | loss  2.73 | val loss  4.02
# | epoch   1 | [ 9199/17945] | ms/batch 390.93 | loss  2.83 | val loss  4.10
# | epoch   1 | [ 9399/17945] | ms/batch 385.33 | loss  2.57 | val loss  4.11
# | epoch   1 | [ 9599/17945] | ms/batch 385.46 | loss  2.59 | val loss  4.16
# | epoch   1 | [ 9799/17945] | ms/batch 386.45 | loss  2.67 | val loss  4.06
# | epoch   1 | [ 9999/17945] | ms/batch 385.48 | loss  2.58 | val loss  4.17
# | epoch   1 | [10199/17945] | ms/batch 387.04 | loss  2.86 | val loss  4.11
# | epoch   1 | [10399/17945] | ms/batch 386.85 | loss  2.66 | val loss  4.07
# | epoch   1 | [10599/17945] | ms/batch 392.03 | loss  2.91 | val loss  4.17
# | epoch   1 | [10799/17945] | ms/batch 385.18 | loss  2.54 | val loss  4.21
# | epoch   1 | [10999/17945] | ms/batch 385.07 | loss  2.96 | val loss  4.10
# | epoch   1 | [11199/17945] | ms/batch 385.77 | loss  2.62 | val loss  4.26
# | epoch   1 | [11399/17945] | ms/batch 384.13 | loss  2.66 | val loss  4.12
# | epoch   1 | [11599/17945] | ms/batch 387.74 | loss  2.84 | val loss  4.14
# | epoch   1 | [11799/17945] | ms/batch 386.28 | loss  2.58 | val loss  4.23
# | epoch   1 | [11999/17945] | ms/batch 385.56 | loss  2.50 | val loss  4.20
# | epoch   1 | [12199/17945] | ms/batch 386.39 | loss  2.82 | val loss  4.20
# | epoch   1 | [12399/17945] | ms/batch 387.33 | loss  2.87 | val loss  4.13
# | epoch   1 | [12599/17945] | ms/batch 387.17 | loss  2.68 | val loss  4.19
# | epoch   1 | [12799/17945] | ms/batch 389.07 | loss  2.78 | val loss  4.16
# | epoch   1 | [12999/17945] | ms/batch 389.39 | loss  2.82 | val loss  4.16
# | epoch   1 | [13199/17945] | ms/batch 385.80 | loss  2.80 | val loss  4.21
# | epoch   1 | [13399/17945] | ms/batch 385.65 | loss  2.93 | val loss  4.19
# | epoch   1 | [13599/17945] | ms/batch 386.70 | loss  3.10 | val loss  4.15
# | epoch   1 | [13799/17945] | ms/batch 388.46 | loss  2.95 | val loss  4.20
# | epoch   1 | [13999/17945] | ms/batch 386.03 | loss  2.36 | val loss  4.11
# | epoch   1 | [14199/17945] | ms/batch 386.60 | loss  2.79 | val loss  4.25
# | epoch   1 | [14399/17945] | ms/batch 389.34 | loss  2.99 | val loss  4.16
# | epoch   1 | [14599/17945] | ms/batch 382.75 | loss  2.91 | val loss  4.15
# | epoch   1 | [14799/17945] | ms/batch 384.35 | loss  2.97 | val loss  4.18
# | epoch   1 | [14999/17945] | ms/batch 384.62 | loss  2.93 | val loss  4.16
# | epoch   1 | [15199/17945] | ms/batch 385.48 | loss  2.63 | val loss  4.22
# | epoch   1 | [15399/17945] | ms/batch 386.92 | loss  2.79 | val loss  4.21
# | epoch   1 | [15599/17945] | ms/batch 385.59 | loss  3.01 | val loss  4.09
# | epoch   1 | [15799/17945] | ms/batch 383.59 | loss  2.53 | val loss  4.13
# | epoch   1 | [15999/17945] | ms/batch 389.99 | loss  2.70 | val loss  4.18
# | epoch   1 | [16199/17945] | ms/batch 385.76 | loss  2.82 | val loss  4.18
# | epoch   1 | [16399/17945] | ms/batch 381.04 | loss  2.60 | val loss  4.17
# | epoch   1 | [16599/17945] | ms/batch 386.97 | loss  2.85 | val loss  4.11
# | epoch   1 | [16799/17945] | ms/batch 383.49 | loss  3.11 | val loss  4.23
# | epoch   1 | [16999/17945] | ms/batch 386.18 | loss  3.09 | val loss  4.18
# | epoch   1 | [17199/17945] | ms/batch 383.23 | loss  2.64 | val loss  4.08
# | epoch   1 | [17399/17945] | ms/batch 384.89 | loss  3.12 | val loss  4.08
# | epoch   1 | [17599/17945] | ms/batch 390.67 | loss  2.88 | val loss  4.14
# | epoch   1 | [17799/17945] | ms/batch 388.18 | loss  3.21 | val loss  4.17
# | epoch   2 | [  199/17945] | ms/batch 387.97 | loss  2.96 | val loss  3.93
# | epoch   2 | [  399/17945] | ms/batch 385.02 | loss  3.07 | val loss  3.93
# | epoch   2 | [  599/17945] | ms/batch 380.03 | loss  3.23 | val loss  3.97
# | epoch   2 | [  799/17945] | ms/batch 384.41 | loss  2.91 | val loss  4.00
# | epoch   2 | [  999/17945] | ms/batch 384.21 | loss  3.11 | val loss  3.97
# | epoch   2 | [ 1199/17945] | ms/batch 382.23 | loss  2.81 | val loss  4.05
# | epoch   2 | [ 1399/17945] | ms/batch 383.85 | loss  2.73 | val loss  4.00
# | epoch   2 | [ 1599/17945] | ms/batch 384.52 | loss  2.94 | val loss  3.95
# | epoch   2 | [ 1799/17945] | ms/batch 380.98 | loss  2.79 | val loss  4.08
# | epoch   2 | [ 1999/17945] | ms/batch 384.68 | loss  2.87 | val loss  4.01
# | epoch   2 | [ 2199/17945] | ms/batch 386.34 | loss  2.75 | val loss  3.98
# | epoch   2 | [ 2399/17945] | ms/batch 386.39 | loss  3.17 | val loss  4.10
# | epoch   2 | [ 2599/17945] | ms/batch 385.14 | loss  2.80 | val loss  4.01
# | epoch   2 | [ 2799/17945] | ms/batch 383.35 | loss  2.84 | val loss  4.04
# | epoch   2 | [ 2999/17945] | ms/batch 386.38 | loss  2.43 | val loss  4.05
# | epoch   2 | [ 3199/17945] | ms/batch 383.28 | loss  3.11 | val loss  3.95
# | epoch   2 | [ 3399/17945] | ms/batch 387.31 | loss  2.86 | val loss  4.03
# | epoch   2 | [ 3599/17945] | ms/batch 388.42 | loss  3.04 | val loss  4.06
# | epoch   2 | [ 3799/17945] | ms/batch 386.68 | loss  2.69 | val loss  3.97
# | epoch   2 | [ 3999/17945] | ms/batch 388.98 | loss  2.98 | val loss  4.01
# | epoch   2 | [ 4199/17945] | ms/batch 386.74 | loss  2.93 | val loss  4.09
# | epoch   2 | [ 4399/17945] | ms/batch 386.45 | loss  3.04 | val loss  3.96
# | epoch   2 | [ 4599/17945] | ms/batch 385.89 | loss  2.96 | val loss  4.03
# | epoch   2 | [ 4799/17945] | ms/batch 385.15 | loss  2.91 | val loss  4.04
# | epoch   2 | [ 4999/17945] | ms/batch 386.38 | loss  3.02 | val loss  4.04
# | epoch   2 | [ 5199/17945] | ms/batch 383.96 | loss  3.20 | val loss  4.12
# | epoch   2 | [ 5399/17945] | ms/batch 384.69 | loss  2.86 | val loss  4.05
# | epoch   2 | [ 5599/17945] | ms/batch 385.80 | loss  2.75 | val loss  4.04
# | epoch   2 | [ 5799/17945] | ms/batch 386.24 | loss  3.00 | val loss  4.02
# | epoch   2 | [ 5999/17945] | ms/batch 385.66 | loss  3.30 | val loss  3.97
# | epoch   2 | [ 6199/17945] | ms/batch 386.08 | loss  2.74 | val loss  4.02
# | epoch   2 | [ 6399/17945] | ms/batch 386.62 | loss  3.01 | val loss  4.03
# | epoch   2 | [ 6599/17945] | ms/batch 384.62 | loss  2.80 | val loss  3.95
# | epoch   2 | [ 6799/17945] | ms/batch 381.67 | loss  2.92 | val loss  4.02
# | epoch   2 | [ 6999/17945] | ms/batch 382.74 | loss  2.59 | val loss  4.12
# | epoch   2 | [ 7199/17945] | ms/batch 386.01 | loss  2.94 | val loss  3.95
# | epoch   2 | [ 7399/17945] | ms/batch 384.88 | loss  2.85 | val loss  3.95
# | epoch   2 | [ 7599/17945] | ms/batch 385.23 | loss  2.97 | val loss  3.95
# | epoch   2 | [ 7799/17945] | ms/batch 384.85 | loss  3.18 | val loss  3.99
# | epoch   2 | [ 7999/17945] | ms/batch 384.26 | loss  2.99 | val loss  3.93
# | epoch   2 | [ 8199/17945] | ms/batch 387.59 | loss  3.04 | val loss  4.00
# | epoch   2 | [ 8399/17945] | ms/batch 383.27 | loss  3.22 | val loss  3.94
# | epoch   2 | [ 8599/17945] | ms/batch 385.03 | loss  2.96 | val loss  3.97
# | epoch   2 | [ 8799/17945] | ms/batch 383.46 | loss  2.61 | val loss  3.98
# | epoch   2 | [ 8999/17945] | ms/batch 383.67 | loss  2.96 | val loss  4.01
# | epoch   2 | [ 9199/17945] | ms/batch 383.93 | loss  3.05 | val loss  3.93
# | epoch   2 | [ 9399/17945] | ms/batch 383.23 | loss  2.80 | val loss  4.06
# | epoch   2 | [ 9599/17945] | ms/batch 386.59 | loss  2.79 | val loss  4.00
# | epoch   2 | [ 9799/17945] | ms/batch 385.45 | loss  2.87 | val loss  3.89
# | epoch   2 | [ 9999/17945] | ms/batch 387.14 | loss  2.82 | val loss  3.89
# | epoch   2 | [10199/17945] | ms/batch 387.77 | loss  3.04 | val loss  3.95
# | epoch   2 | [10399/17945] | ms/batch 387.35 | loss  2.90 | val loss  3.94
# | epoch   2 | [10599/17945] | ms/batch 389.94 | loss  3.16 | val loss  3.93
# | epoch   2 | [10799/17945] | ms/batch 383.40 | loss  2.77 | val loss  3.90
# | epoch   2 | [10999/17945] | ms/batch 387.94 | loss  3.12 | val loss  3.94
# | epoch   2 | [11199/17945] | ms/batch 385.42 | loss  2.84 | val loss  3.91
# | epoch   2 | [11399/17945] | ms/batch 383.43 | loss  2.84 | val loss  4.04
# | epoch   2 | [11599/17945] | ms/batch 384.78 | loss  3.04 | val loss  3.91
# | epoch   2 | [11799/17945] | ms/batch 386.02 | loss  2.77 | val loss  3.88
# | epoch   2 | [11999/17945] | ms/batch 384.06 | loss  2.70 | val loss  3.89
# | epoch   2 | [12199/17945] | ms/batch 386.94 | loss  2.98 | val loss  3.88
# | epoch   2 | [12399/17945] | ms/batch 385.47 | loss  3.12 | val loss  3.91
# | epoch   2 | [12599/17945] | ms/batch 387.37 | loss  2.83 | val loss  3.92
# | epoch   2 | [12799/17945] | ms/batch 388.97 | loss  2.97 | val loss  3.92
# | epoch   2 | [12999/17945] | ms/batch 390.70 | loss  2.93 | val loss  3.85
# | epoch   2 | [13199/17945] | ms/batch 388.74 | loss  3.00 | val loss  3.85
# | epoch   2 | [13399/17945] | ms/batch 389.99 | loss  3.13 | val loss  3.86
# | epoch   2 | [13599/17945] | ms/batch 388.70 | loss  3.26 | val loss  3.89
# | epoch   2 | [13799/17945] | ms/batch 388.34 | loss  3.15 | val loss  3.85
# | epoch   2 | [13999/17945] | ms/batch 386.85 | loss  2.57 | val loss  3.87
# | epoch   2 | [14199/17945] | ms/batch 388.79 | loss  3.00 | val loss  3.91
# | epoch   2 | [14399/17945] | ms/batch 389.00 | loss  3.20 | val loss  3.84
# | epoch   2 | [14599/17945] | ms/batch 389.57 | loss  3.11 | val loss  3.81
# | epoch   2 | [14799/17945] | ms/batch 389.68 | loss  3.16 | val loss  3.84
# | epoch   2 | [14999/17945] | ms/batch 386.07 | loss  3.05 | val loss  3.85
# | epoch   2 | [15199/17945] | ms/batch 387.58 | loss  2.88 | val loss  3.86
# | epoch   2 | [15399/17945] | ms/batch 388.82 | loss  2.98 | val loss  3.86
# | epoch   2 | [15599/17945] | ms/batch 389.09 | loss  3.18 | val loss  3.84
# | epoch   2 | [15799/17945] | ms/batch 386.16 | loss  2.67 | val loss  3.87
# | epoch   2 | [15999/17945] | ms/batch 391.16 | loss  2.92 | val loss  3.84
# | epoch   2 | [16199/17945] | ms/batch 385.80 | loss  3.08 | val loss  3.76
# | epoch   2 | [16399/17945] | ms/batch 382.77 | loss  2.78 | val loss  3.76
# | epoch   2 | [16599/17945] | ms/batch 388.56 | loss  3.05 | val loss  3.79
# | epoch   2 | [16799/17945] | ms/batch 383.92 | loss  3.28 | val loss  3.80
# | epoch   2 | [16999/17945] | ms/batch 387.80 | loss  3.25 | val loss  3.79
# | epoch   2 | [17199/17945] | ms/batch 384.48 | loss  2.77 | val loss  3.80
# | epoch   2 | [17399/17945] | ms/batch 387.83 | loss  3.25 | val loss  3.77
# | epoch   2 | [17599/17945] | ms/batch 387.19 | loss  3.00 | val loss  3.76
# | epoch   2 | [17799/17945] | ms/batch 388.12 | loss  3.35 | val loss  3.74
# | epoch   3 | [  199/17945] | ms/batch 387.66 | loss  3.17 | val loss  3.65
# | epoch   3 | [  399/17945] | ms/batch 389.22 | loss  3.22 | val loss  3.54
# | epoch   3 | [  599/17945] | ms/batch 382.88 | loss  3.38 | val loss  3.63
# | epoch   3 | [  799/17945] | ms/batch 384.60 | loss  3.04 | val loss  3.64
# | epoch   3 | [  999/17945] | ms/batch 388.62 | loss  3.25 | val loss  3.62
# | epoch   3 | [ 1199/17945] | ms/batch 387.46 | loss  2.93 | val loss  3.60
# | epoch   3 | [ 1399/17945] | ms/batch 386.28 | loss  2.85 | val loss  3.67
# | epoch   3 | [ 1599/17945] | ms/batch 393.25 | loss  3.12 | val loss  3.67
# | epoch   3 | [ 1799/17945] | ms/batch 384.91 | loss  2.99 | val loss  3.66
# | epoch   3 | [ 1999/17945] | ms/batch 385.64 | loss  3.04 | val loss  3.68
# | epoch   3 | [ 2199/17945] | ms/batch 386.96 | loss  2.86 | val loss  3.69
# | epoch   3 | [ 2399/17945] | ms/batch 386.36 | loss  3.32 | val loss  3.59
# | epoch   3 | [ 2599/17945] | ms/batch 383.31 | loss  2.95 | val loss  3.57
# | epoch   3 | [ 2799/17945] | ms/batch 383.25 | loss  3.04 | val loss  3.63
# | epoch   3 | [ 2999/17945] | ms/batch 384.61 | loss  2.56 | val loss  3.69
# | epoch   3 | [ 3199/17945] | ms/batch 382.13 | loss  3.31 | val loss  3.63
# | epoch   3 | [ 3399/17945] | ms/batch 405.31 | loss  2.99 | val loss  3.58
# | epoch   3 | [ 3599/17945] | ms/batch 416.11 | loss  3.19 | val loss  3.64
# | epoch   3 | [ 3799/17945] | ms/batch 420.84 | loss  2.83 | val loss  3.64
# | epoch   3 | [ 3999/17945] | ms/batch 417.40 | loss  3.12 | val loss  3.63
# | epoch   3 | [ 4199/17945] | ms/batch 416.78 | loss  3.04 | val loss  3.61
# | epoch   3 | [ 4399/17945] | ms/batch 415.28 | loss  3.16 | val loss  3.66
# | epoch   3 | [ 4599/17945] | ms/batch 417.84 | loss  3.01 | val loss  3.63
# | epoch   3 | [ 4799/17945] | ms/batch 412.94 | loss  3.05 | val loss  3.62
# | epoch   3 | [ 4999/17945] | ms/batch 423.29 | loss  3.08 | val loss  3.65
# | epoch   3 | [ 5199/17945] | ms/batch 424.60 | loss  3.34 | val loss  3.63
# | epoch   3 | [ 5399/17945] | ms/batch 419.35 | loss  3.03 | val loss  3.65
# | epoch   3 | [ 5599/17945] | ms/batch 422.70 | loss  2.84 | val loss  3.64
# | epoch   3 | [ 5799/17945] | ms/batch 419.22 | loss  3.07 | val loss  3.65
# | epoch   3 | [ 5999/17945] | ms/batch 423.93 | loss  3.43 | val loss  3.59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1bcc326f2abf> in <module>
#      11
#      12         optimizer.zero_grad()
# ---> 13         loss = step(inputs_ids, attention_mask, y)
#      14         train_loss.append(loss.item())
#      15         loss.backward()
#
# <ipython-input-13-bebc04e33992> in step(inputs_ids, attention_mask, y)
#       4     lm_labels = y[:, 1:].clone()
#       5     lm_labels[y[:, 1:] == pad_token_id] = -100
# ----> 6     output = model(inputs_ids, attention_mask=attention_mask, decoder_input_ids=y_ids, lm_labels=lm_labels)
#       7     return output[0] # loss
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/transformers/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_outputs, decoder_input_ids, decoder_attention_mask, decoder_past_key_value_states, use_cache, lm_labels, inputs_embeds, decoder_inputs_embeds, head_mask)
#    1073
#    1074         # Decode
# -> 1075         decoder_outputs = self.decoder(
#    1076             input_ids=decoder_input_ids,
#    1077             attention_mask=decoder_attention_mask,
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/Dokumente/text_summarization/venv/lib/python3.8/site-packages/transformers/modeling_t5.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, past_key_value_states, use_cache)
#     689
#     690         if attention_mask is None:
# --> 691             attention_mask = torch.ones(batch_size, mask_seq_length).to(inputs_embeds.device)
#     692         if self.is_decoder and encoder_attention_mask is None and encoder_hidden_states is not None:
#     693             encoder_seq_length = encoder_hidden_states.shape[1]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate

# %%
from rouge_score import rouge_scorer
from rouge_score import scoring

class RougeScore:
    '''
    mostly from https://github.com/google-research/text-to-text-transfer-transformer/blob/master/t5/evaluation/metrics.py 
    '''
    
    def __init__(self, score_keys=None)-> None:
        super().__init__()
        if score_keys is None:  
            self.score_keys = ["rouge1", "rouge2", "rougeLsum"]
        
        self.scorer = rouge_scorer.RougeScorer(self.score_keys)
        self.aggregator = scoring.BootstrapAggregator()
        
        
    @staticmethod
    def prepare_summary(summary):
            # Make sure the summary is not bytes-type
            # Add newlines between sentences so that rougeLsum is computed correctly.
            summary = summary.replace(" . ", " .\n")
            return summary
    
    def __call__(self, target, prediction):
        """Computes rouge score.''
        Args:
        targets: string
        predictions: string
        """

        target = self.prepare_summary(target)
        prediction = self.prepare_summary(prediction)
        
        self.aggregator.add_scores(self.scorer.score(target=target, prediction=prediction))

        return 
    
    def reset_states(self):
        self.rouge_list = []

    def result(self):
        result = self.aggregator.aggregate()
        
        for key in self.score_keys:
            score_text = "%s = %.2f, 95%% confidence [%.2f, %.2f]"%(
                key,
                result[key].mid.fmeasure*100,
                result[key].low.fmeasure*100,
                result[key].high.fmeasure*100
            )
            print(score_text)
        
        return {key: result[key].mid.fmeasure*100 for key in self.score_keys}

# %%
rouge_score = RougeScore()
predictions = []
for i, (input_ids, attention_mask, y) in enumerate(test_loader):
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)
    y = y.to(device)
        
    summaries = model.generate(input_ids=input_ids, attention_mask=attention_mask)
    pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summaries]
    real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in y]
    for pred_sent, real_sent in zip(pred, real):
        rouge_score(pred_sent, real_sent)
        predictions.append(str("pred sentence: " + pred_sent + "\n\n real sentence: " + real_sent))
    if i > 40:
        break
    
rouge_score.result()
# Out:
# rouge1 = 26.67, 95% confidence [26.08, 27.29]
# rouge2 = 8.33, 95% confidence [7.86, 8.73]
# rougeLsum = 15.57, 95% confidence [15.18, 15.92]
# {'rouge1': 26.668475437578245,
#  'rouge2': 8.333081382416019,
#  'rougeLsum': 15.566398570250495}

# %%
for pred in predictions[:10]:
    print("------")
    print(pred)
    print("------")
# Out:
# ------
# pred sentence: flugzeuge, ob ein derart vollvollgepacke immer kleiner werden. die us-verbraucherberatungsgruppe, die die gesundheit und sicherheit gefährdet? sie sagt, dass der schrumpfende platz für tiere im platz in sicherheit. mehr als die armlehne, platzmangel im verkehrsministerium. cynthia corbertt, dass er eine behandlung der passagiere ein standard, der bei der faa durchgeführt werden werden können. viele zoll platz fehlen fehlen, dass die fluggesellschaften mit einem sitz bis bis zum gleichen flugflugzeugen führen, während der welt. es sagte, dass eine gesundheit gesundheit für sicherheitsgruppe ernsterstert. er sagt, er fußußtritten. viele economy-sitze
#
#  real sentence: experten bezweifeln, ob überfüllte flugzeuge passagiere gefährden. die us-verbraucherberatungsgruppe sagt, dass mindestabstände vorgeschrieben werden müssen. sicherheitstests in flugzeugen mit mehr beinfreiheit als von fluggesellschaften angeboten, werden durchgeführt.
# ------
# ------
# pred sentence: rahul kumar, 17, kletterte über den zaun des kamla nnte auf die tiere zu und schrie, er würde töten. er sagte, dass er die löwen über die zooaufsicht überraschte, bevor er in ahmedabad und ranntte. es sei betrunken und er ermormormorte sich in einem schschschrie: "heuteute etöte empfmpfmpfte, als er betreten wollte wollte, dass die polizei. der berauschte er seien ihn ein gute gute chance" sobte ihn ein löbraben und eheheben müssen ihn einholen, bevor man während er auf die
#
#  real sentence: betrunkener teenager kletterte in löwengehege eines zoos in westindien: rahul kumar, 17, lief auf tiere zu und schrie: "heute töte ich einen löwen!" glücklicherweise stürzte er in einen wassergraben, bevor er die löwen erreichte und wurde gerettet.
# ------
# ------
# pred sentence: dougie freedman hat forest stabilisiert, seit er stuart pearce im februar ersetzte. freidman steht kurz davor, die clubbesitzer sind zufrieden mit seiner arbeit mit nottingham forest. er kult forest hat einen neuen vertrag auf den play-off-offoff-plätzen unternommen versuch auf den Play-offsoff-platz für die nächsten beiden spielzeiten zu sichern. freedmann steht auf den letzten wochen abgesprung studman, freed man steht auf einen zweijahresvertrag für den play der nächsten zweijahren vertrag bei nottt forest fest, sich auf einen vertrag für die beiden unterzeichnen. das freedmen, die arbeit am city ground einigen davorvor, sich sich mit dem city ground. es eigentum, um freeddmanman
#
#  real sentence: nottingham forest steht kurz vor der vertragsverlängerung von dougie freedman, der im februar die nachfolge des ehemaligen managers stuart pearce angetreten hatte und den club seitdem auf den neunten tabellenplatz geführt hat.
# ------
# ------
# pred sentence: die reds wurden mit einem wechsel des 25-jährigen, klubs in spanien gesucht. stefano castagna behauptet, dass neto eine vereinvereinbarung über seine zukunft getroffen getroffen wurde. es wurde beim wechsel der saison in verbindung gestellt, als simon mignolet vom platz gestellt wurde. der ehemalige keeper von atlético paran iturbe juventus anzuschließen, aber sein agent hat noch keine entscheidung über die vereinbarbarung von tottenhams chadli: "wir haben noch keine endgültiggültige straftrafe. retteettete, dass er die raa-tororentina-storte schottete sich am ende der serie-a-vereinbarungen über den
#
#  real sentence: fiorentina-torhüter neto wurde mit liverpool und arsenal in verbindung gebracht. neto kam 2011 vom brasilianischen erstligisten atletico paranaense zu fiorentina und wird laut seinem agenten auch von psg und spanischen clubs gesucht.
# ------
# ------
# pred sentence: der ehemalige olympionike und reality-tv-star, 65, wird am freitag in einem zweistündigen interview mit diane sawyer sein brechen. das interview findet inmitten wachsender spekulationen über den übergang des sechsfachen vaters zu stehen, steht steht unmittelbar hinter seiner verwicklung in einem kalifornien im februar. die karce jenner, die kürzlich den verlust ihres mannes betrauert wird, wird er sich ein frau er krisidentität. er sagt, er wird für das interview mit einem "weitreichenden" interview interview mit sawyer, als er aus kündigte. april, rasierte sich in diesem monat mit apfel in einer tödlichen klinik in letzten jahren jahre alten
#
#  real sentence: das interview mit dem reality-tv-star, 69, wird am freitag, den 24. april ausgestrahlt, inmitten anhaltender spekulationen über seinen wechsel zu einer frau und nach seiner verwicklung in einen tödlichen autounfall im februar. das interview wird auch einer von diane sawyers ersten fernsehauftritten nach dem plötzlichen tod ihres mannes im vergangenen jahr sein.
# ------
# ------
# pred sentence: schwein aus dem schwimmbad. schweineschwein und stürzte in ringwood, hampshire, in den pool gefallen. die besatzung von dorset fire fire and rescue mühte sich, das riesige schwarze schwschwein, als die tiertiere schürzte und nicht mehr herauskommen. schiebebrettern und ein spezialisiertes tierrettern, steinen und leinen, um es mit stropfenpfen. feuerwehrleute wurde er gerettetterte die anwesenheit aus pool ringringwood mobilisiert. halbhalbhalbe zerstützützung von schwimmen. crews ins wassersex, feuerfeuerwehrmannmannschaften und frauen das schwammbadbadwasser und stumpen
#
#  real sentence: riesenschwein fiel in den swimmingpool seines hauses in ringwood, hampshire. es bedurfte der anstrengungen eines teams von feuerwehrleuten, um es aus dem wasser zu ziehen. auch ein eigensinniges pferd musste aus einem swimmingpool in sussex gerettet werden.
# ------
# ------
# pred sentence: der bbc-radio hörte zeit, als die hörer durchschnittlich 11,6 stunden pro woche hören. die zeit des jahres hörten für den letzten drei monaten von 2014 lediglich zehn prozent weniger als ein jahrjahren. die menschen hört, dass es in der vergangenheit der sitzung des bc radiosender hören hören, wenn er gefangen hat. quellen die musik an online-dienste wie spotify tony hall auf den fall aufmerksam gemacht. viele menschen, die zahl der teil der zeit hört sich noch noch einschalten, während die jahren hören des zeitzeits von februars in den dokumenten teilte, dass die ententschuldigung der hörersers hörenhören,
#
#  real sentence: in den letzten drei monaten des jahres 2014 verbrachte der durchschnittliche hörer zehn stunden pro woche mit tuning. das waren 14% weniger als zehn jahre zuvor, als die menschen 11,6 stunden lang einschalteten. der bbc trust hat firmen den weg geebnet, sich in einem product-placement-experiment in lifestyleprogramme auf dem world news-kanal einzukaufen. zum beispiel könnten verlage dafür bezahlen, dass ihre bücher auf talking books rezensiert werden. der bbc trust wird das programm in einem jahr überprüfen.
# ------
# ------
# pred sentence: der originalserie namens "full house". "fulfull live" sagt, es sei "fuller house". john stamos wird teilte netflix olsen, dave coulier und stephanie saget und lori loughlin, san francisco mit. tanner, die d.j.. 's ist eine neue generation von tansansans und sanger, die mit dem original aufgewachsen sind, sagt, dass die neue generation generation hat. samams hat die reihe von der teilteiltin - die stanger hat eine neue serie-off-serie spielte. die serie wird im nächsten jahr mit dem tanknnn, die die neue geschichte hat, ra sonnenn.
#
#  real sentence: die show werde mit einem einstündigen special zurückkehren, gefolgt von einem spin-off, sagte star john stamos, der die show am montagabend auf "jimmy kimmel live" ankündigte.
# ------
# ------
# pred sentence: der ehemalige weltmeister ken doherty, die erste weibliche spielerin in der snookerweltmeisterschaft spielt. evans gewinnte die sache der lnookerverband mutter gewinnerin. revans spielte den ersten weltmeisterschaftmeisterschaftmeisterschaft. er hat eine frauen in einem packenden und zermürbenty - etwas mehr aufzuholen. frau erlitte während der wm-qualifikationsspiels gegen den spiel. kritiker und erlaubte, dass er mit 10: 8 beugty besiegt, bevor er die fraufrau erreichte. doherstagstags erlöschte den traum von rerety zu teilnahme an der blue-chip-titels gegen 71.20 sieg
#
#  real sentence: reanne evans traf in der wm-qualifikation auf ken doherty. doherty gewann 1997 die weltmeisterschaft. evans verlor den ersten frame 71-15 gegen doherty. doch der gebürtige dudley kämpfte sich zurück und führte 4-3. ken doherty gelang es jedoch, einen packenden wettkampf mit 10-8 zu beenden.
# ------
# ------
# pred sentence: ahmed saleh, 21, wurde für vier jahren haft verurteilt. oxford crown court wurde im märz schuldig und schuldig gesprochen und nun zu haftstrafen zwischen drei und neun lockten, sie sexuell zu missbrauchen. die mädchen wurde in sozialen medien lockt, ereigneten sich in den angeklagten in banbury. er wurde zu neun haft schuldig. es wurde von der bande genommen. die bande, 21, sule und opfer, 21, wurden zu erschossen, um geld für die jungen inhaftiert. ddd zoe smith verwandte die fußballverein zu gefangenen gefangene bande von der gerichtstrafstraftrafen. männer
#
#  real sentence: wegen sexuellen missbrauchs von kindern muss die bande insgesamt 31 jahre ins gefängnis. die taten ereigneten sich in autos, wäldern oder in den wohnungen der angeklagten in banbury. opfer wurden zu partys gelockt, die über soziale medien organisiert wurden, und dann missbraucht. mädchen im alter zwischen 13 und 16 jahren wurden von der bande zwischen 2009 und 2014 ausgebeutet.
# ------

# %%
result_path = "../data/result_german.txt"
for pred in predictions:
    with open(result_path, "a") as file:
        file.write(pred + "\n")

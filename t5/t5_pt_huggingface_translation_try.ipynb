# %% [markdown]
# # Text Summary with T5 from Huggingface Pytorch

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
import torch
import re
import time

# %%
BATCH_SIZE = 16

SHUFFEL_SIZE = 1024

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

learning_rate = 3e-5

# %%
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Define Model

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# model_size = "t5-small"
model_size = "t5-base"

tokenizer = T5Tokenizer.from_pretrained(model_size)
model = T5ForConditionalGeneration.from_pretrained(model_size).to(device)

task_specific_params = model.config.task_specific_params
if task_specific_params is not None:
    model.config.update(task_specific_params.get("translation_en_to_de", {}))
    

optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate, weight_decay=0.0001)

# %%
task_specific_params.get("translation_en_to_de", {}).get("max_length"), model.config.prefix
# Out:
# (300, 'translate English to German: ')

# %%
model.config
# Out:
# T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "early_stopping": true,
#   "eos_token_id": 1,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "max_length": 300,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_beams": 4,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "prefix": "translate English to German: ",
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "vocab_size": 32128
# }

# %% [markdown]
# ## Define Pytorch Dataset

# %%
def read_files(name):
    article_path = "data/%s/article" % name
    highlights_path = "data/%s/highlights" % name
    
    articles = [x.rstrip() for x in open(article_path).readlines()]
    highlights = [x.rstrip() for x in open(highlights_path).readlines()]
    
    assert len(articles) == len(highlights)
    return articles, highlights

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, articles):
        self.x = articles
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index]), max_length=300, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
from segtok.segmenter import split_single
def split_in_sentences(text):
    return split_single(text)

# %%
def get_dataset(name):
    articles, highlights = read_files(name)
    
    a_sent = split_in_sentences(articles[0]) 
    return MyDataset(a_sent)

# %%
train_ds = get_dataset("train")
# test_ds = get_dataset("test")
# val_ds = get_dataset("val")
# Out:
# 7 By . Associated Press . PUBLISHED: . 14:11 EST, 25 October 2013 . | . UPDATED: . 15:36 EST, 25 October 2013 . The bishop of the Fargo Catholic Diocese in North Dakota has exposed potentially hundreds of church members in Fargo, Grand Forks and Jamestown to the hepatitis A virus in late September and early October.

# %%
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=5)
# val_loader = torch.utils.data.DataLoader(val_ds, batch_size=BATCH_SIZE)
# test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE)

# %%
x, x_mask = next(iter(train_loader))

x
# Out:
# tensor([[13959,  1566,    12,  ...,     0,     0,     0],
#         [13959,  1566,    12,  ...,     0,     0,     0],
#         [13959,  1566,    12,  ...,     0,     0,     0],
#         [13959,  1566,    12,  ...,     0,     0,     0],
#         [13959,  1566,    12,  ...,     0,     0,     0]])

# %%
x = x.to(device)
x_mask = x_mask.to(device)

# %%
translations = model.generate(input_ids=x, attention_mask=x_mask)

# %%
pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in translations]
real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in x]
predictions = []   
for pred_sent, real_sent in zip(pred, real):
    predictions.append(str("German: " + pred_sent + "\n\nEnglish: " + real_sent))
    
for item in predictions:
    print(item)
    print("\n------------\n")
# Out:
# German: by . associated press . published: . 14:11 est, 25 october 2013 . | . updated: . 15:36 est, 25 october 2013 . the bishop of the fargo catholic diocese in north dakota has exposed potentially hundreds of church members in fargo, grand forks and jamestown to the hepatitis a virus in late september and early october.
#
# English: translate English to German: by . associated press . published: . 14:11 est, 25 october 2013 . | . updated: . 15:36 est, 25 october 2013 . the bishop of the fargo catholic diocese in north dakota has exposed potentially hundreds of church members in fargo, grand forks and jamestown to the hepatitis a virus in late september and early october.
#
# ------------
#
# German: Das staatliche Gesundheitsministerium hat ein Gutachten über die Exposition für alle veröffentlicht, die fünf Kirchen besuchten und Kommunion nahmen.
#
# English: translate English to German: the state health department has issued an advisory of exposure for anyone who attended five churches and took communion.
#
# ------------
#
# German: Die amerikanischen Behörden haben die hepatitis A (Hepatitis B)-Infektionskrankheit erkannt. Die hepatitis A (Hepatitis B)-Infektionskrankheit erregte in der amerikanischen Bundesrepublik die Aufmerksamkeit der Bundesrepublik.
#
# English: translate English to German: bishop john folda (pictured) of the fargo catholic diocese in north dakota has exposed potentially hundreds of church members in fargo, grand forks and jamestown to the hepatitis a . state immunization program manager molly howell says the risk is low, but officials feel it's important to alert people to the possible exposure.
#
# ------------
#
# German: die diözese kündigte am monday an, dass Bischof john folda Zeit nimmt, nachdem er mit Hepatitis a diagnostiziert wurde.
#
# English: translate English to German: the diocese announced on monday that bishop john folda is taking time off after being diagnosed with hepatitis a.
#
# ------------
#
# German: Die Diözese sagt, er habe die Infektion durch kontaminierte Lebensmittel erkannt, während er im vergangenen Monat an einer Konferenz für neu ordinierte Bischöfe in Italien teilnahm.
#
# English: translate English to German: the diocese says he contracted the infection through contaminated food while attending a conference for newly ordained bishops in italy last month.
#
# ------------

# %% [markdown]
# ## Load Ger/Eng Dataset

# %%
def open_translation_file():
    path = "../data/translate_en_de/"
    en_file = open(str(path + "newstest2014.en"), "r")
    de_file = open(str(path + "newstest2014.de"), "r")
    
    en_list = []
    for line in en_file:
        en_list.append(line)
    de_list = []
    for line in de_file:    
        de_list.append(line)
    return en_list, de_list

en, de = open_translation_file()

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, en, de):
        self.x = en
        self.y = de
        
    def __getitem__(self, index):
        x = tokenizer.encode_plus(model.config.prefix + self.transfrom(self.x[index]), max_length=300, return_tensors="pt", pad_to_max_length=True)
        y = tokenizer.encode(self.transfrom(self.y[index]), max_length=300, return_tensors="pt", pad_to_max_length=True)
        return x['input_ids'].view(-1), x['attention_mask'].view(-1), y.view(-1)
    
    @staticmethod
    def transfrom(x):
        x = x.lower()
        x = re.sub("'(.*)'", r"\1", x)
        return x
    
    def __len__(self):
        return len(self.x)

# %%
translation_dataset = MyDataset(en, de)
translation_loader = torch.utils.data.DataLoader(translation_dataset, batch_size=BATCH_SIZE)

# %%
x, x_mask, _ = next(iter(translation_loader))

# %%
x.shape
# Out:
# torch.Size([16, 300])

# %%
x = x.to(device)
x_mask = x_mask.to(device)

# %%
translations = model.generate(input_ids=x, attention_mask=x_mask)

# %%
pred = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in translations]
real = [tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in x]
predictions = []   
for pred_sent, real_sent in zip(pred, real):
    predictions.append(str("German: " + pred_sent + "\n\nEnglish: " + real_sent))
    
for item in predictions:
    print(item)
    print("\n------------\n")
# Out:
# German: orlando bloom und miranda kerr lieben sich immer noch.
#
# English: translate English to German: orlando bloom and miranda kerr still love each other
#
# ------------
#
# German: Schauspieler orlando bloom und Model miranda kerr wollen getrennte Wege gehen .
#
# English: translate English to German: actors orlando bloom and model miranda kerr want to go their separate ways .
#
# ------------
#
# German: kerr ist ein US-amerikanischer Schauspieler .
#
# English: translate English to German: however , in an interview , bloom has said that he and kerr still love each other .
#
# ------------
#
# German: miranda kerr und orlando bloom sind Eltern von zwei ##at##-##at## Jahr ##at##-##at## alten flynn .
#
# English: translate English to German: miranda kerr and orlando bloom are parents to two ##at##-##at## year ##at##-##at## old flynn .
#
# ------------
#
# German: orlando bloom kündigte seine Trennung von seiner Frau, Supermodel miranda kerr an.
#
# English: translate English to German: actor orlando bloom announced his separation from his wife , supermodel miranda kerr .
#
# ------------
#
# German: In einem Interview mit uns Journalistin katie couric , das am friday ( Ortszeit ) ausgestrahlt werden soll, sagte bloom , &quot;manchmal geht das Leben nicht genau so, wie wir es planen oder hoffen &quot; .
#
# English: translate English to German: in an interview with us journalist katie couric , which is to be broadcast on friday ( local time ) , bloom said , &quot; sometimes life doesn &apos;t go exactly as we plan or hope for &quot; .
#
# ------------
#
# German: er und kerr lieben sich immer noch , betonte das 36 ##at##-##at## Jahr ##at##-##at## alt .
#
# English: translate English to German: he and kerr still love each other , emphasised the 36 ##at##-##at## year ##at##-##at## old .
#
# ------------
#
# German: „Wir werden uns gegenseitig unterstützen und uns als Eltern für Flynn lieben.“
#
# English: translate English to German: &quot; we &apos;re going to support one another and love each other as parents to flynn &quot; .
#
# ------------
#
# German: kerr und bloom sind seit 2010 verheiratet und ihr Sohn flynn wurde 2011 geboren.
#
# English: translate English to German: kerr and bloom have been married since 2010 . their son flynn was born in 2011 .
#
# ------------
#
# German: Jet-Hersteller streiten sich um die Sitzbreite, wobei große Aufträge auf dem Spiel stehen.
#
# English: translate English to German: jet makers feud over seat width with big orders at stake
#
# ------------
#
# German: Die deutsche Luftfahrtindustrie hat sich in den letzten Jahren in den Bereichen Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt, Luftfahrt
#
# English: translate English to German: a row has flared up between leading plane makers over the width of tourist ##at##-##at## class seats on long ##at##-##at## distance flights , setting the tone for a bitter confrontation at this month &apos;s dubai airshow .
#
# ------------
#
# German: Der größte Teil der Fluggesellschaften fliegt von Frankfurt aus, wobei die meisten Fluggesellschaften aus Deutschland , Frankreich und Spanien fliegen.
#
# English: translate English to German: the dispute focuses on the width of seats provided on long ##at##-##at## haul flights for economy passengers - not always the ones most courted by airlines , but whose allocated space holds the key to efficiency claims for the latest jets offered by airbus sas and boeing co .
#
# ------------
#
# German: Airbus forderte in dieser Woche einen Industriestandard, der für einen Sitz von mindestens 46 cm Breite in Economy-Kabinen sorgen würde, aber sein US-Konkurrent Boeing sagt, dass es Sache der Fluggesellschaften sein sollte, darüber zu entscheiden.
#
# English: translate English to German: airbus this week called for an industry standard that would provide for a seat at least 18 inches ( 46 cm ) wide in economy cabins , but its u.s. arch ##at##-##at## rival boeing says it should be for airlines to decide .
#
# ------------
#
# German: Während es sich bei den Flugzeugherstellern um ##at##-##at## größere Versionen ihrer beiden ##at##-##at## engined long ##at##-##at## Distanzflugzeuge handelt, werden bei der 17. November ##at##-##at## 21 Veranstaltung potenziell Rekordaufträge erwartet.
#
# English: translate English to German: the dispute comes as plane makers vie to sell ever ##at##-##at## larger versions of their twin ##at##-##at## engined long ##at##-##at## distance aircraft , with potentially record orders expected at the november 17 ##at##-##at## 21 event .
#
# ------------
#
# German: Während der letzten Jahre hat sich die amerikanische Luftfahrtindustrie in den letzten Jahren immer stärker entwickelt.
#
# English: translate English to German: how the back of the plane is laid out - particularly whether seating is 9 or 10 abreast - is central to the economic performance claims being made for new &quot; mini ##at##-##at## jumbo &quot; jet designs .
#
# ------------
#
# German: Die 777x ist eine Variante der 777-Serie, die es geschafft hat, die ersten 777-Linien zu bauen. Die 777x ist eine Variante der 777x .
#
# English: translate English to German: boeing says its revamped &quot; 777x &quot; will hold 406 people based on economy seats more than 17 inches wide and set out 10 in each row .
#
# ------------
